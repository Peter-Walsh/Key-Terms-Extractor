# %% [markdown]
# # Key Terms Extractor
# This is a short NLP project I did through JetBrains academy. One common problem in NLP is identifing the subject or subjects of a text. In this mini-project I'm going to attempt to extract the top-5 key terms that are related to the subject of several texts in a few different ways. To start off I'll just get the counts of each of the words, and to end we'll attempt to calculate the TF-IDF score for each of the words in each of our texts.

# %% [markdown]
# ## First, a little exploration
# Before I start digging into Python's nltk library the tools it offers. I want to do a little text processing and playing around on my own, just to feel things out.

# %% [markdown]
# ### The test files
# The texts I'm going to be working with are buried in the news.xml file. So, to start off, I'm going to extract each of the texts from the file. I'll do this using Python's nifty lxml library. From here I'll put the texts into a list of tuples called ```articles```. Each tuple will contain the name of the piece of text and the raw text.

# %%
from lxml import etree

filename = "news.xml"
f = open(filename, "rb")

xml_tree = etree.fromstring(f.read())
articles = [(article[0].text, article[1].text) for article in xml_tree[0]]
articles
# Out:
# [('Brain Disconnects During Sleep',
#   "Scientists may have gained an important insight into the age-old mystery of why consciousness fades as we nod off to sleep.\n          Lines of communication between various parts of cerebral cortex - which buzz with activity during wakefulness - break down during slumber, researchers report today in Science.\n          Early neuroscientists assumed that consciousness wanes during sleep because the cortex simply shuts off.\n          But electroencephalography (EEG) and other modern methods have since ruled out that explanation, showing that the electrical chatter and metabolism of neurons in the cortex continues unabated during sleep.\n          That left neuroscientists with a puzzle: If the brain is still active, why does consciousness wane?\n          Giulio Tononi of the University of Wisconsin, Madison, suspected that a communication breakdown might be the reason.\n          Tononi has spent years developing a theory that equates consciousness with the integration of information.\n          Communication between regions of the cortex might be one sign of this integration - and of consciousness, Tononi says.\n          To test that idea, he and his team recorded electrical activity in the brains of six sleepy volunteers using high density EEG.\n          Before the subjects nodded off, the researchers stimulated a small patch of right frontal cortex with transcranial magnetic stimulation (TMS), a method that uses magnetic pulses to induce an electrical current inside the head.\n          When the subjects were awake, TMS elicited waves of neural activity that spread through neighboring areas of right frontal and parietal cortex and to corresponding regions on the left side of the brain.\n          During non-rapid eye movement (non-REM) sleep, the same TMS stimulus only elicited neural activity at the site of stimulation.\n          Tononi says the findings suggest that different areas of cortex do indeed stop talking to each other during non-REM sleep - a stage in which people often report little or no conscious experience on waking.\n          An important follow-up, he says, will be to repeat the experiments during late-night REM sleep, when people often report consciouslike experiences in the form of dreams.\n          'We would predict a pattern which is much more similar to wakefulness,' he says.\n          The research 'definitely tells us something about sleep and may have important implications for understanding the neural correlates of consciousness,' says Christof Koch, a cognitive neuroscientist at the California Institute of Technology in Pasadena."),
#  ('New Portuguese skull may be an early relative of Neandertals',
#   'Half a million years ago, several different members of our genus, Homo, had spread throughout Europe and Asia, where some would eventually evolve into Neandertals.\n          But which ones has been the subject of intense debate.\n          A newly discovered partial skull is offering another clue to help solve the mystery of the ancestry of Neandertals.\n          Found in 2014 in the Gruta da Aroeira cave in central Portugal with ancient stone hand axes, the skull (3D reconstruction pictured) is firmly dated to 400,000 years old and an archaic member of our genus, according to a study published today in the Proceedings of the National Academy of Sciences.\n          The skull shows a new mix of features not seen before in fossil humans-it has traits that link it to Neandertals, such as a fused brow ridge, as well as some primitive traits that resemble other extinct fossils in Europe.\n          This new combination of features on a well-dated skull may help researchers sort out how different fossils in Europe are related to each other-and which ones eventually evolved into Neandertals.'),
#  ('Living by the coast could improve mental health',
#   "People who live close to the sea have better mental health than those who live further away, regardless of their household income, a new study suggests.\n          According to scientists, living near the sea could support better mental health in England's poorest communities.\n          Researchers from the University of Exeter used survey data from 25,963 respondents in their investigations into the wellbeing effects of being by the coast.\n          After taking other related factors into account, they found that living in large towns and cities near the coastline is linked with better mental health for those in the lowest earning households.\n          The research suggests those who live less than a kilometre from the coast are around 22 per cent less likely to have symptoms of a mental health disorder than those who live 50km or more away.\n          Those from low income households less than a kilometre from the coast are around 40 per cent less likely to have symptoms, compared to those earning the same amount living more than 50km away.\n          Around one in six adults in England suffer from mental health disorders such as anxiety and depression, and these are far more likely in people from poorer backgrounds.\n          Published in the Health and Place journal, the findings suggest access to the coast could help to reduce these health inequalities in towns and cities close to the sea.\n          The research used data from the Health Survey for England and compared people's health to their proximity to the coast.\n          Researchers say their findings add to the growing evidence that access to blue spaces-particularly coastal environments-might improve health and wellbeing.\n          Dr Jo Garrett, who led the study, said: 'Our research suggests, for the first time, that people in poorer households living close to the coast experience fewer symptoms of mental health disorders.\n          When it comes to mental health, this 'protective' zone could play a useful role in helping to level the playing field between those on high and low income.'\n          Dr Mathew White, environmental psychologist at the University of Exeter, said: 'This kind of research into blue health is vital to convincing governments to protect, create and encourage the use of coastal spaces.\n          'We need to help policy makers understand how to maximise the wellbeing benefits of 'blue' spaces in towns and cities and ensure that access is fair and inclusive for everyone, while not damaging our fragile coastal environments.'"),
#  ('Did you knowingly commit a crime? Brain scans could tell',
#   "The number of years someone spends behind bars can hinge on whether they were clearly aware that they were committing a crime.\n          But how is a judge or jury to know for sure?\n          A new study suggests brain scans can distinguish between hardcore criminal intent and simple reckless behavior, but the approach is far from being ready for the courtroom.\n          The study is unusual because it looks directly at the brains of people while they are engaged in illicit activity, says Liane Young, a Boston College psychologist who was not involved in the work.\n          Earlier research, including work by her, has instead generally looked at the brains of people only observing immoral activity.\n          Researchers led by Read Montague, a neuroscientist at Virginia Tech Carilion Research Insitute in Roanoke and at University College London,  used functional magnetic resonance imaging (fMRI), which can measure brain activity based on blood flow.\n          They analyzed the brains of 40 people-a mix of men and women mostly in their 20s and 30s-as they went through scenarios that simulated trying to smuggle something through a security checkpoint.\n          In some cases, the people knew for certain they had contraband in a suitcase.\n          In other cases, they chose from between two and five suitcases, with only one containing contraband (and thus they weren't sure they were carrying contraband).\n          The risk of getting caught also varied based on how many of the 10 security checkpoints had a guard stationed there.\n          The results showed distinctive patterns of brain activity for when the person knew for certain the suitcase had contraband and when they only knew there was a chance of it, the team reports today in the Proceedings of the National Academy of Sciences.\n          But there was an unexpected twist.\n          Those differing brain patterns only showed up when people were first shown how many security checkpoints were guarded, and then offered the suitcases.\n          In that case, a computer analysis of the fMRI images correctly classified people as knowing or reckless between 71% and 80% of the time.\n          Montague isn't sure why the results hinged on the order in which the scenario unfolded.\n          It's possible there is some threshold for the amount of information the brain needed before a distinctive thought process connected to recklessness kicked in, he says.\n          In the laboratory, he says, perhaps the information about both the risk of grabbing a 'hot' suitcase and of encountering a security guard 'had to be all on board before we could see this difference.'\n          'I see this as a proof of principle that raises more questions than it answers,' says Montague, who notes that his team repeated the experiment several times with the same results.\n          The lawyers working on the study recoiled at the idea that the results depended on the sequencing of the events, because people were engaged in risky behavior no matter the order.\n          'I'm a scientist, so I was like, 'This is the most interesting part of what we've found.\n          We don't know what to do with this,'' Montague says.\n          But another researcher who has used brain imaging to study criminal behavior questioned whether the differences found in the study really revealed a meaningful difference between the two mental states.\n          Ruben Gur, a psychologist and director of the Brain Behavior Laboratory at the University of Pennsylvania's medical school, says that with just 40 participants, a study may not be able to account for all the variables at play in brain scans.\n          'To me, it proves that when you apply a statistical method on small samples you come up with interesting results, and some that make less sense.'\n          Study author Gideon Yaffe, a philosopher at Yale Law School, notes there are some limitations of the research.\n          It's not known whether t ...
#  ('Computer learns to detect skin cancer more accurately than doctors',
#   "A computer was better than human dermatologists at detecting skin cancer in a study that pitted people against machines in the quest for better, faster diagnostics, researchers said on Tuesday.\n          A team from Germany, the United States and France taught an artificial intelligence system to distinguish dangerous skin lesions from benign ones, showing it more than 100,000 images.\n          The machine - a deep learning convolutional neural network or CNN - was then tested against 58 dermatologists from 17 countries, shown photos of malignant melanomas and benign moles.\n          Just over half the dermatologists were at expert level with more than five years of experience, 19% had between two and five years' experience, and 29% were beginners with less than two years under their belt.\n          'Most dermatologists were outperformed by the CNN, the research team wrote in a paper published in the journal Annals of Oncology.\n          On average,human dermatologists accurately detected 86.6% of skin cancers from the images, compared to 95% for the CNN.\n          'The CNN missed fewer melanomas, meaning it had a higher sensitivity than the dermatologists,' the study's first author Holger Haenssle of the University of Heidelberg said in a statement.\n          It also 'misdiagnosed fewer benign moles as malignant melanoma ... this would result in less unnecessary surgery.'\n          The dermatologists' performance improved when they were given more information of the patients and their skin lesions.\n          The team said AI may be a useful tool for faster, easier diagnosis of skin cancer, allowing surgical removal before it spreads.\n          There are about 232,000 new cases of melanoma, and 55,500 deaths, in the world each year, they added.\n          Melanoma in some parts of the body, such as the fingers, toes and scalp, are difficult to image, and AI may have difficulty recognising atypical lesions or ones that patients themselves are unaware of.\n          Currently, there is no substitute for a thorough clinical examination,' experts Victoria Mar from Monash University in Melbourne and Peter Soyer of the University of Queensland wrote in an editorial published with the study."),
#  ('US economic growth stronger than expected despite weak demand',
#   "US economic growth surged in the first three months of the year to 3.2% as the threat of a trade war with China forced businesses to stockpile at the fastest rate since 2015.\n          Figures from the Department of Commerce showed that a jump in hoarding raw materials and finished goods and an increase in government investment overcame weak consumer spending, a drop in housebuilding and low business investment to send GDP growth well ahead of the 2.2% in the last quarter of 2018.\n          Exports, which have proved volatile in recent quarters in response to threats of a trade war between the US and China, surged and imports declined to add 1.03 percentage points to GDP after being neutral in the fourth quarter.\n          The improvement dispelled concerns the US economy was heading into recession as early as the summer, as some analysts had feared,after a slowdown last year.\n          But analysts said the Federal Reserve, which has put interest rate hikes on hold, was unlikely to view the figures as the beginning of an economic boom and reverse its current policy.\n          In January, the US central bank suspended its three-year push to tighten monetary policy, saying it would pause further rate hikes this year. The Fed increased borrowing costs four times to a range of 2.25 to 2.5% in 2018, well above the level of base rates for most other major economies.\n          The central bank is more likely to focus on a measure of domestic demand, which increased by only 1.3%, the slowest since the second quarter of 2013, after increasing by 2.6% in the last quarter.\n          Growth in consumer spending, which accounts for more than two-thirds of US economic activity, was also weak, growing by just 1.2% from the previous 2.5%. Business investment slowed sharply, rising at only at a 0.2% rate, the slowest since the third quarter of 2016.\n          Reports from China show that the world's second largest economy has arrested last year's decline, though many analysts believe the better outlook will prove temporary and growth will be lower this year than in 2018.\n          European manufacturing has slumped in recent months and Japanese output has slowed, marking the US out as the only major economy maintaining high levels of output growth.\n          The effect of stockpiling in the US has also buoyed activity in the UK, where the uncertainty over Brexit negotiations has unnerved businesses and encouraged them to hoard raw materials.\n          In April, British factories have stockpiled at the fastest pace since records began in the 1950s amid reports they were increasingly downbeat about their prospects.\n          A survey by the Confederation of British Industry found expectations for export orders in the next three months fell to their lowest level since mid-2009."),
#  ('Microsoft becomes third listed US firm to be valued at $1tn',
#   "Microsoft has become the third publicly listed US company, after Apple and Amazon, to boast a market value of more than $1tn after bumper quarterly results boosted its share price.\n          The company beat sales and profits expectations in the three months to 31 March, thanks in part to its cloud computing business, which signed up major corporate clients over the period.\n          Microsoft shares rose as much as 5% in early trading on Thursday, briefly pushing its market value above $1tn for the first time before dipping back below again when the shares price gain eased.\n          It was the latest tech firm to join the prestigious club, after rival Apple and then Amazon topped the $1tn mark last year.\n          Since then, the shares of both companies have fallen back and Microsoft now has the biggest market capitalisation of any US stock market listed company.\n          Shares in Facebook were also trading higher, up 6%, after it easily beat forecasts with a 26% jump in quarterly revenues to more than $15bn and an 8% rise in active users.\n          The better-than-expected results from Microsoft and Facebook helped to push the tech-focused Nasdaq share index in New York to over 8,118 points at its close.\n          The boost for Microsoft came after it reported a 14% increase in revenue in its third quarter to $30.6bn. Net income rose 19% to $8.8bn. Revenues in its cloud computing division jumped 14%, with US grocery firm Kroger and Walgreens Boots Alliance among the big client wins.\n          Satya Nadella, the chief executive of Microsoft, said: 'Leading organisations of every size in every industry trust the Microsoft cloud. We are accelerating our innovation across the cloud and edge so our customers can build the digital capability increasingly required to compete and grow.'\n          Shares in Microsoft were up 3.4% at $129 at close of trading in New York, giving it a market value of about $995bn. Apple is worth around $970bn and Amazon is close behind at $940bn.\n          Brad Reback of stockbrokers Stifel said Microsoft has a bright future: 'We continue to believe the shift to the cloud will be additive to Microsoft given a broader portfolio of products with deeper functionality as well as Microsoft's ability to enter new categories where it did not compete previously.'\n          Stifel has raised its price target for Microsoft to $150 from $130.\n          Cloud is clearly the way forward for Microsoft and demand for these services is expected to remain strong,' said Jasper Lawler, the head of research at London Capital Group."),
#  ("Apple's Siri is a better rapper than you",
#   "Siri, Apple's voice-controlled virtual assistant, is not just useful for hands-free texting, dictation and pizza place recommendations - it turns out she is also a skilled rapper.\n          Last month, Judith Newman wrote in the New York Times how Siri had befriended her autistic son, and now it seems that Siri's talents go even further.\n          London-based producers Skeewiff, aka Alex Rizzo and Elliot Ireland, have uploaded a remix of Young MC's Know How that features Siri.\n          Siri's flow is reminiscent of Nicki Minaj's best work on Monster; she has cadence just as smooth as Angel Haze; and a potty mouth worthy of Azealia Banks.\n          As well as name-checking Spotify and Google, Siri's enunciation of Young's rapid-fire lyrics are near-perfect, rapping: I'm tough like a bone / sly like Stallone / rocking and clocking on the microphone / smooth like a mirror / in hearts I strike terror / rhymes like runs / and rhymes with no errors.\n          The producers who worked with Siri said they were thrilled with her performance.\n          Rizzo told the Guardian how the collaboration came about: She's set to British Female.\n          I asked her to dial up the lyrics of one of my favourite boasting hip hop tracks of all time, Young MC's Know How.\n          When I asked her to read them out, well that was when the real ROFL-ing started.\n          Tears and everything. Something about that posh English, mechanical accent busting rhymes was just irresistible.\n          At that moment I knew what needed to be done, the rest was just recording, replaying and a whole lot of editing.'\n          This is not the first time Siri has taken to the mic though.\n          She has previously covered Eminem's Lose Yourself (not a great effort), and, to better effect, Notorious BIG's Hypnotize.\n          X Factor, watch out."),
#  ('Netflix viewers like comedy for breakfast and drama at lunch',
#   "Netflix viewers prefer a diet of comedy at breakfast, a portion of drama on their lunch break and a midnight snack of documentaries.\n          Netflix, which has more than 100 million subscribers worldwide, said analysis of viewing data found that users of its service were keen to start the day with a laugh by watching comedies such as , Fuller House and.\n          At 6am members are 34% more likely to watch a comedy than at any other time of the day, the data, gathered from users across 22 countries, shows.\n          Sneaking in an episode of a drama at lunchtime has emerged as a popular pastime with shows in the genre, such as Mad Men, Bloodline or Orange is the New Black, accounting for 47% of all viewing between noon and 2pm.\n          Evening viewing is peppered with a range of usual suspects, including Breaking Bad and Stranger Things, as viewership of the thriller genre increases by more than a quarter by 9pm.\n          It is back to comedies just before lights out with It's Always Sunny in Philadelphia, Master of None and BoJack Horseman taking over at 11pm.\n          For night owls - 15% of Netflix viewing occurs between midnight and 6am - documentaries are popular.\n          In that period there is a 24% surge in the viewing of documentaries such as Making a Murderer and Planet Earth.\n          Netflix says its business model, which enables viewers to binge-watch entire series in one go, counter to the traditional TV model, has resulted in marked changes in the kind of shows being watched.\n          'For years our lives had to fit around television, now it's the other way round,' said Cindy Holland, the vice-president of original content at Netflix.\n          'We've given consumers control and it's interesting to see the behaviours that emerge when viewers aren't tied to a schedule.'\n          Netflix said the trend suggests that the traditional TV viewing pattern - of breakfast news shows followed by a lighter schedule during the day and lights off by midnight - no longer applies.\n          'Gone are the days of every household waking up to the same breakfast TV programming on their screens,' the company said.\n          'When viewing schedules are set by people and not programmers, lunchtime becomes no bingeing exception.'\n          Netflix analysed six months of streaming data from the 22 countries, including the UK, Argentina, Brazil, India, New Zealand and the US."),
#  ('Loneliness May Make Quitting Smoking Even Tougher',
#   "Being lonely may make it harder to quit smoking, a new British study suggests.\n          Using genetic and survey data from hundreds of thousands of people, researchers found that loneliness makes it more likely that someone will smoke.\n          This type of analysis is called Mendelian randomization.\n          'This method has never been applied to this question before and so the results are novel, but also tentative,' said co-lead author Robyn Wootton, a senior research associate at the University of Bristol in the United Kingdom.\n          'We found evidence to suggest that loneliness leads to increased smoking, with people more likely to start smoking, to smoke more cigarettes and to be less likely to quit,' Wootton said in a university news release.\n          These data mesh with an observation that during the coronavirus pandemic, more British people are smoking.\n          Senior study author Jorien Treur said, 'Our finding that smoking may also lead to more loneliness is tentative, but it is in line with other recent studies that identified smoking as a risk factor for poor mental health.\n          A potential mechanism for this relationship is that nicotine from cigarette smoke interferes with neurotransmitters such as dopamine in the brain.'\n          Treur is a visiting research associate from Amsterdam UMC.\n          The researchers also looked for a connection between loneliness and drinking but found none.\n          Still, if loneliness causes people to smoke, it is important to alert smoking cessation services so they can add this factor as they help people to quit, the study authors said.\n          The report was published June 16 in the journal Addiction.")]

# %% [markdown]
# Alright now lets just count the words in the raw text for each of the news articles. We'll perform a little preprocessing to make things a little cleaner. Basically just coverting all the text to lowercase and stripping away all the whitespace.

# %%
from collections import defaultdict
import pandas as pd

def get_word_counts(text):
    article_counts = defaultdict(int)
    for word in text.lower().split():
        article_counts[word] += 1
    return article_counts

for a in articles:
    print(get_word_counts(a[1]))
# Out:
# defaultdict(<class 'int'>, {'scientists': 1, 'may': 2, 'have': 3, 'gained': 1, 'an': 3, 'important': 3, 'insight': 1, 'into': 1, 'the': 24, 'age-old': 1, 'mystery': 1, 'of': 20, 'why': 2, 'consciousness': 4, 'fades': 1, 'as': 1, 'we': 1, 'nod': 1, 'off': 1, 'to': 7, 'sleep.': 2, 'lines': 1, 'communication': 3, 'between': 2, 'various': 1, 'parts': 1, 'cerebral': 1, 'cortex': 7, '-': 4, 'which': 3, 'buzz': 1, 'with': 4, 'activity': 4, 'during': 7, 'wakefulness': 1, 'break': 1, 'down': 1, 'slumber,': 1, 'researchers': 2, 'report': 3, 'today': 1, 'in': 6, 'science.': 1, 'early': 1, 'neuroscientists': 2, 'assumed': 1, 'that': 10, 'wanes': 1, 'sleep': 3, 'because': 1, 'simply': 1, 'shuts': 1, 'off.': 1, 'but': 1, 'electroencephalography': 1, '(eeg)': 1, 'and': 7, 'other': 2, 'modern': 1, 'methods': 1, 'since': 1, 'ruled': 1, 'out': 1, 'explanation,': 1, 'showing': 1, 'electrical': 3, 'chatter': 1, 'metabolism': 1, 'neurons': 1, 'continues': 1, 'unabated': 1, 'left': 2, 'a': 8, 'puzzle:': 1, 'if': 1, 'brain': 1, 'is': 2, 'still': 1, 'active,': 1, 'does': 1, 'wane?': 1, 'giulio': 1, 'tononi': 4, 'university': 1, 'wisconsin,': 1, 'madison,': 1, 'suspected': 1, 'breakdown': 1, 'might': 2, 'be': 3, 'reason.': 1, 'has': 1, 'spent': 1, 'years': 1, 'developing': 1, 'theory': 1, 'equates': 1, 'integration': 2, 'information.': 1, 'regions': 2, 'one': 1, 'sign': 1, 'this': 1, 'consciousness,': 1, 'says.': 2, 'test': 1, 'idea,': 1, 'he': 3, 'his': 1, 'team': 1, 'recorded': 1, 'brains': 1, 'six': 1, 'sleepy': 1, 'volunteers': 1, 'using': 1, 'high': 1, 'density': 1, 'eeg.': 1, 'before': 1, 'subjects': 2, 'nodded': 1, 'off,': 1, 'stimulated': 1, 'small': 1, 'patch': 1, 'right': 2, 'frontal': 2, 'transcranial': 1, 'magnetic': 2, 'stimulation': 1, '(tms),': 1, 'method': 1, 'uses': 1, 'pulses': 1, 'induce': 1, 'current': 1, 'inside': 1, 'head.': 1, 'when': 2, 'were': 1, 'awake,': 1, 'tms': 2, 'elicited': 2, 'waves': 1, 'neural': 3, 'spread': 1, 'through': 1, 'neighboring': 1, 'areas': 2, 'parietal': 1, 'corresponding': 1, 'on': 2, 'side': 1, 'brain.': 1, 'non-rapid': 1, 'eye': 1, 'movement': 1, '(non-rem)': 1, 'sleep,': 2, 'same': 1, 'stimulus': 1, 'only': 1, 'at': 2, 'site': 1, 'stimulation.': 1, 'says': 2, 'findings': 1, 'suggest': 1, 'different': 1, 'do': 1, 'indeed': 1, 'stop': 1, 'talking': 1, 'each': 1, 'non-rem': 1, 'stage': 1, 'people': 2, 'often': 2, 'little': 1, 'or': 1, 'no': 1, 'conscious': 1, 'experience': 1, 'waking.': 1, 'follow-up,': 1, 'says,': 1, 'will': 1, 'repeat': 1, 'experiments': 1, 'late-night': 1, 'rem': 1, 'consciouslike': 1, 'experiences': 1, 'form': 1, 'dreams.': 1, "'we": 1, 'would': 1, 'predict': 1, 'pattern': 1, 'much': 1, 'more': 1, 'similar': 1, "wakefulness,'": 1, 'research': 1, "'definitely": 1, 'tells': 1, 'us': 1, 'something': 1, 'about': 1, 'implications': 1, 'for': 1, 'understanding': 1, 'correlates': 1, "consciousness,'": 1, 'christof': 1, 'koch,': 1, 'cognitive': 1, 'neuroscientist': 1, 'california': 1, 'institute': 1, 'technology': 1, 'pasadena.': 1})
# defaultdict(<class 'int'>, {'half': 1, 'a': 6, 'million': 1, 'years': 2, 'ago,': 1, 'several': 1, 'different': 2, 'members': 1, 'of': 9, 'our': 2, 'genus,': 2, 'homo,': 1, 'had': 1, 'spread': 1, 'throughout': 1, 'europe': 2, 'and': 2, 'asia,': 1, 'where': 1, 'some': 2, 'would': 1, 'eventually': 2, 'evolve': 1, 'into': 2, 'neandertals.': 3, 'but': 1, 'which': 2, 'ones': 2, 'has': 2, 'been': 1, 'the': 8, 'subject': 1, 'intense': 1, 'debate.': 1, 'newly': 1, 'discovered': 1, 'partial': 1, 'skull': 4, 'is': 2, 'offering': 1, 'another': 1, 'clue': 1, 'to': 5, 'help': 2, 'solve': 1, 'mystery': 1, 'ancestry': 1, 'found': 1, 'in': 7, '2014': 1, 'gruta': 1, 'da': 1, 'aroeira': 1, 'cave': 1, 'central': 1, 'portugal': 1, 'with': 1, 'ancient': 1, 'stone': 1, 'hand': 1, 'axes,': 1, '(3d': 1, 'reconstruction': 1, 'pictured)': 1, 'firmly': 1, 'dated': 1, '400,000': 1, 'old': 1, 'an': 1, 'archaic': 1, 'member': 1, 'according': 1, 'study': 1, 'published': 1, 'today': 1, 'proceedings': 1, 'national': 1, 'academy': 1, 'sciences.': 1, 'shows': 1, 'new': 2, 'mix': 1, 'features': 2, 'not': 1, 'seen': 1, 'before': 1, 'fossil': 1, 'humans-it': 1, 'traits': 2, 'that': 2, 'link': 1, 'it': 1, 'neandertals,': 1, 'such': 1, 'as': 3, 'fused': 1, 'brow': 1, 'ridge,': 1, 'well': 1, 'primitive': 1, 'resemble': 1, 'other': 1, 'extinct': 1, 'fossils': 2, 'europe.': 1, 'this': 1, 'combination': 1, 'on': 1, 'well-dated': 1, 'may': 1, 'researchers': 1, 'sort': 1, 'out': 1, 'how': 1, 'are': 1, 'related': 1, 'each': 1, 'other-and': 1, 'evolved': 1})
# defaultdict(<class 'int'>, {'people': 3, 'who': 5, 'live': 4, 'close': 3, 'to': 19, 'the': 26, 'sea': 2, 'have': 3, 'better': 3, 'mental': 7, 'health': 12, 'than': 5, 'those': 7, 'further': 1, 'away,': 1, 'regardless': 1, 'of': 9, 'their': 4, 'household': 1, 'income,': 1, 'a': 5, 'new': 1, 'study': 1, 'suggests.': 1, 'according': 1, 'scientists,': 1, 'living': 4, 'near': 2, 'could': 3, 'support': 1, 'in': 12, "england's": 1, 'poorest': 1, 'communities.': 1, 'researchers': 2, 'from': 8, 'university': 2, 'exeter': 1, 'used': 2, 'survey': 2, 'data': 2, '25,963': 1, 'respondents': 1, 'investigations': 1, 'into': 3, 'wellbeing': 2, 'effects': 1, 'being': 1, 'by': 1, 'coast.': 2, 'after': 1, 'taking': 1, 'other': 1, 'related': 1, 'factors': 1, 'account,': 1, 'they': 1, 'found': 1, 'that': 4, 'large': 1, 'towns': 3, 'and': 12, 'cities': 3, 'coastline': 1, 'is': 3, 'linked': 1, 'with': 1, 'for': 4, 'lowest': 1, 'earning': 2, 'households.': 1, 'research': 4, 'suggests': 1, 'less': 4, 'kilometre': 2, 'coast': 4, 'are': 3, 'around': 3, '22': 1, 'per': 2, 'cent': 2, 'likely': 3, 'symptoms': 2, 'disorder': 1, '50km': 2, 'or': 1, 'more': 3, 'away.': 2, 'low': 2, 'income': 1, 'households': 2, '40': 1, 'symptoms,': 1, 'compared': 2, 'same': 1, 'amount': 1, 'one': 1, 'six': 1, 'adults': 1, 'england': 2, 'suffer': 1, 'disorders': 1, 'such': 1, 'as': 1, 'anxiety': 1, 'depression,': 1, 'these': 2, 'far': 1, 'poorer': 2, 'backgrounds.': 1, 'published': 1, 'place': 1, 'journal,': 1, 'findings': 2, 'suggest': 1, 'access': 3, 'help': 2, 'reduce': 1, 'inequalities': 1, 'sea.': 1, "people's": 1, 'proximity': 1, 'say': 1, 'add': 1, 'growing': 1, 'evidence': 1, 'blue': 2, 'spaces-particularly': 1, 'coastal': 3, 'environments-might': 1, 'improve': 1, 'wellbeing.': 1, 'dr': 2, 'jo': 1, 'garrett,': 1, 'led': 1, 'study,': 1, 'said:': 2, "'our": 1, 'suggests,': 1, 'first': 1, 'time,': 1, 'experience': 1, 'fewer': 1, 'disorders.': 1, 'when': 1, 'it': 1, 'comes': 1, 'health,': 1, 'this': 1, "'protective'": 1, 'zone': 1, 'play': 1, 'useful': 1, 'role': 1, 'helping': 1, 'level': 1, 'playing': 1, 'field': 1, 'between': 1, 'on': 1, 'high': 1, "income.'": 1, 'mathew': 1, 'white,': 1, 'environmental': 1, 'psychologist': 1, 'at': 1, 'exeter,': 1, "'this": 1, 'kind': 1, 'vital': 1, 'convincing': 1, 'governments': 1, 'protect,': 1, 'create': 1, 'encourage': 1, 'use': 1, 'spaces.': 1, "'we": 1, 'need': 1, 'policy': 1, 'makers': 1, 'understand': 1, 'how': 1, 'maximise': 1, 'benefits': 1, "'blue'": 1, 'spaces': 1, 'ensure': 1, 'fair': 1, 'inclusive': 1, 'everyone,': 1, 'while': 1, 'not': 1, 'damaging': 1, 'our': 1, 'fragile': 1, "environments.'": 1})
# defaultdict(<class 'int'>, {'the': 48, 'number': 1, 'of': 24, 'years': 1, 'someone': 2, 'spends': 1, 'behind': 1, 'bars': 1, 'can': 3, 'hinge': 1, 'on': 8, 'whether': 4, 'they': 11, 'were': 6, 'clearly': 1, 'aware': 1, 'that': 12, 'committing': 1, 'a': 23, 'crime.': 2, 'but': 4, 'how': 4, 'is': 5, 'judge': 1, 'or': 3, 'jury': 1, 'to': 13, 'know': 2, 'for': 7, 'sure?': 1, 'new': 1, 'study': 7, 'suggests': 1, 'brain': 9, 'scans': 1, 'distinguish': 1, 'between': 4, 'hardcore': 1, 'criminal': 2, 'intent': 2, 'and': 12, 'simple': 1, 'reckless': 2, 'behavior,': 1, 'approach': 1, 'far': 2, 'from': 3, 'being': 1, 'ready': 1, 'courtroom.': 1, 'unusual': 1, 'because': 2, 'it': 4, 'looks': 1, 'directly': 1, 'at': 9, 'brains': 4, 'people': 8, 'while': 1, 'are': 3, 'engaged': 2, 'in': 15, 'illicit': 1, 'activity,': 1, 'says': 3, 'liane': 1, 'young,': 1, 'boston': 1, 'college': 2, 'psychologist': 2, 'who': 3, 'was': 5, 'not': 3, 'involved': 1, 'work.': 1, 'earlier': 1, 'research,': 2, 'including': 1, 'work': 1, 'by': 2, 'her,': 1, 'has': 2, 'instead': 1, 'generally': 1, 'looked': 1, 'only': 4, 'observing': 1, 'immoral': 1, 'activity.': 1, 'researchers': 1, 'led': 1, 'read': 1, 'montague,': 2, 'neuroscientist': 1, 'virginia': 1, 'tech': 1, 'carilion': 1, 'research': 1, 'insitute': 1, 'roanoke': 1, 'university': 2, 'london,': 1, 'used': 2, 'functional': 1, 'magnetic': 1, 'resonance': 1, 'imaging': 2, '(fmri),': 1, 'which': 2, 'measure': 1, 'activity': 2, 'based': 2, 'blood': 1, 'flow.': 1, 'analyzed': 1, '40': 2, 'people-a': 1, 'mix': 1, 'men': 1, 'women': 1, 'mostly': 1, 'their': 1, '20s': 1, '30s-as': 1, 'went': 1, 'through': 2, 'scenarios': 1, 'simulated': 1, 'trying': 1, 'smuggle': 1, 'something': 2, 'security': 4, 'checkpoint.': 1, 'some': 4, 'cases,': 2, 'knew': 4, 'certain': 3, 'had': 3, 'contraband': 3, 'suitcase.': 1, 'other': 2, 'chose': 1, 'two': 2, 'five': 1, 'suitcases,': 1, 'with': 7, 'one': 1, 'containing': 1, '(and': 1, 'thus': 1, "weren't": 1, 'sure': 2, 'carrying': 1, 'contraband).': 1, 'risk': 3, 'getting': 1, 'caught': 1, 'also': 1, 'varied': 1, 'many': 2, '10': 1, 'checkpoints': 2, 'guard': 2, 'stationed': 1, 'there.': 1, 'results': 3, 'showed': 2, 'distinctive': 2, 'patterns': 3, 'when': 4, 'person': 1, 'suitcase': 2, 'there': 5, 'chance': 1, 'it,': 1, 'team': 2, 'reports': 1, 'today': 1, 'proceedings': 1, 'national': 1, 'academy': 1, 'sciences.': 1, 'an': 1, 'unexpected': 1, 'twist.': 1, 'those': 1, 'differing': 1, 'up': 2, 'first': 1, 'shown': 1, 'guarded,': 1, 'then': 1, 'offered': 1, 'suitcases.': 1, 'case,': 1, 'computer': 1, 'analysis': 1, 'fmri': 1, 'images': 1, 'correctly': 1, 'classified': 1, 'as': 7, 'knowing': 1, '71%': 1, '80%': 1, 'time.': 1, 'montague': 2, "isn't": 1, 'why': 1, 'hinged': 1, 'order': 1, 'scenario': 2, 'unfolded.': 1, "it's": 3, 'possible': 1, 'threshold': 1, 'amount': 1, 'information': 2, 'needed': 1, 'before': 2, 'thought': 1, 'process': 2, 'connected': 1, 'recklessness': 1, 'kicked': 1, 'in,': 1, 'he': 4, 'says.': 3, 'laboratory,': 1, 'says,': 2, 'perhaps': 1, 'about': 1, 'both': 1, 'grabbing': 1, "'hot'": 1, 'encountering': 1, "'had": 1, 'be': 5, 'all': 2, 'board': 1, 'we': 2, 'could': 1, 'see': 2, 'this': 4, "difference.'": 1, "'i": 1, 'proof': 1, 'principle': 1, 'raises': 1, 'more': 3, 'questions': 1, 'than': 1, "answers,'": 1, 'notes': 2, 'his': 1, 'repeated': 1, 'experiment': 1, 'several': 1, 'times': 1, 'same': 1, 'results.': 1, 'lawyers': 1, 'working': 1, 'recoiled': 1, 'idea': 1, 'depended': 1, 'sequencing': 1, 'events,': 1, 'risky': 1, 'behavior': 3, 'no': 1, 'matter': 1, 'order.': 1, "'i'm": 1, 'scientist,': 1, 'so': 2, 'i': 1, 'like,': 1, "'this": 1, 'most': 1, 'interesting': 2, 'part': 1, 'what': 2, "we've": 1, 'found.': 1, "don't": 1, 'do': 3, "this,''": 1, 'another': 1, 'researcher': 1, 'questioned': 1, 'differences': 1, 'found': 1, 'really': 2, 'revealed': 1, 'meaningful': 1, 'difference': 1, 'mental': 1, 'states.': 1, 'ruben': 1, 'gur,': 1, 'director': 1, 'laboratory': 1, " ...
# defaultdict(<class 'int'>, {'a': 9, 'computer': 1, 'was': 2, 'better': 1, 'than': 5, 'human': 1, 'dermatologists': 5, 'at': 2, 'detecting': 1, 'skin': 5, 'cancer': 1, 'in': 10, 'study': 1, 'that': 2, 'pitted': 1, 'people': 1, 'against': 2, 'machines': 1, 'the': 20, 'quest': 1, 'for': 4, 'better,': 1, 'faster': 1, 'diagnostics,': 1, 'researchers': 1, 'said': 3, 'on': 2, 'tuesday.': 1, 'team': 3, 'from': 5, 'germany,': 1, 'united': 1, 'states': 1, 'and': 9, 'france': 1, 'taught': 1, 'an': 2, 'artificial': 1, 'intelligence': 1, 'system': 1, 'to': 3, 'distinguish': 1, 'dangerous': 1, 'lesions': 2, 'benign': 3, 'ones,': 1, 'showing': 1, 'it': 4, 'more': 3, '100,000': 1, 'images.': 1, 'machine': 1, '-': 2, 'deep': 1, 'learning': 1, 'convolutional': 1, 'neural': 1, 'network': 1, 'or': 2, 'cnn': 2, 'then': 1, 'tested': 1, '58': 1, '17': 1, 'countries,': 1, 'shown': 1, 'photos': 1, 'of': 12, 'malignant': 2, 'melanomas': 1, 'moles.': 1, 'just': 1, 'over': 1, 'half': 1, 'were': 4, 'expert': 1, 'level': 1, 'with': 3, 'five': 2, 'years': 2, 'experience,': 2, '19%': 1, 'had': 2, 'between': 1, 'two': 2, "years'": 1, '29%': 1, 'beginners': 1, 'less': 2, 'under': 1, 'their': 2, 'belt.': 1, "'most": 1, 'outperformed': 1, 'by': 1, 'cnn,': 1, 'research': 1, 'wrote': 2, 'paper': 1, 'published': 2, 'journal': 1, 'annals': 1, 'oncology.': 1, 'average,human': 1, 'accurately': 1, 'detected': 1, '86.6%': 1, 'cancers': 1, 'images,': 1, 'compared': 1, '95%': 1, 'cnn.': 1, "'the": 1, 'missed': 1, 'fewer': 2, 'melanomas,': 1, 'meaning': 1, 'higher': 1, 'sensitivity': 1, "dermatologists,'": 1, "study's": 1, 'first': 1, 'author': 1, 'holger': 1, 'haenssle': 1, 'university': 3, 'heidelberg': 1, 'statement.': 1, 'also': 1, "'misdiagnosed": 1, 'moles': 1, 'as': 2, 'melanoma': 2, '...': 1, 'this': 1, 'would': 1, 'result': 1, 'unnecessary': 1, "surgery.'": 1, "dermatologists'": 1, 'performance': 1, 'improved': 1, 'when': 1, 'they': 2, 'given': 1, 'information': 1, 'patients': 2, 'lesions.': 1, 'ai': 2, 'may': 2, 'be': 1, 'useful': 1, 'tool': 1, 'faster,': 1, 'easier': 1, 'diagnosis': 1, 'cancer,': 1, 'allowing': 1, 'surgical': 1, 'removal': 1, 'before': 1, 'spreads.': 1, 'there': 2, 'are': 3, 'about': 1, '232,000': 1, 'new': 1, 'cases': 1, 'melanoma,': 1, '55,500': 1, 'deaths,': 1, 'world': 1, 'each': 1, 'year,': 1, 'added.': 1, 'some': 1, 'parts': 1, 'body,': 1, 'such': 1, 'fingers,': 1, 'toes': 1, 'scalp,': 1, 'difficult': 1, 'image,': 1, 'have': 1, 'difficulty': 1, 'recognising': 1, 'atypical': 1, 'ones': 1, 'themselves': 1, 'unaware': 1, 'of.': 1, 'currently,': 1, 'is': 1, 'no': 1, 'substitute': 1, 'thorough': 1, 'clinical': 1, "examination,'": 1, 'experts': 1, 'victoria': 1, 'mar': 1, 'monash': 1, 'melbourne': 1, 'peter': 1, 'soyer': 1, 'queensland': 1, 'editorial': 1, 'study.': 1})
# defaultdict(<class 'int'>, {'us': 7, 'economic': 3, 'growth': 4, 'surged': 2, 'in': 19, 'the': 37, 'first': 1, 'three': 2, 'months': 3, 'of': 16, 'year': 2, 'to': 13, '3.2%': 1, 'as': 6, 'threat': 1, 'a': 9, 'trade': 2, 'war': 2, 'with': 1, 'china': 2, 'forced': 1, 'businesses': 2, 'stockpile': 1, 'at': 4, 'fastest': 2, 'rate': 3, 'since': 5, '2015.': 1, 'figures': 2, 'from': 3, 'department': 1, 'commerce': 1, 'showed': 1, 'that': 2, 'jump': 1, 'hoarding': 1, 'raw': 2, 'materials': 1, 'and': 9, 'finished': 1, 'goods': 1, 'an': 2, 'increase': 1, 'government': 1, 'investment': 3, 'overcame': 1, 'weak': 1, 'consumer': 2, 'spending,': 2, 'drop': 1, 'housebuilding': 1, 'low': 1, 'business': 2, 'send': 1, 'gdp': 2, 'well': 2, 'ahead': 1, '2.2%': 1, 'last': 4, 'quarter': 3, '2018.': 2, 'exports,': 1, 'which': 4, 'have': 2, 'proved': 1, 'volatile': 1, 'recent': 2, 'quarters': 1, 'response': 1, 'threats': 1, 'between': 1, 'china,': 1, 'imports': 1, 'declined': 1, 'add': 1, '1.03': 1, 'percentage': 1, 'points': 1, 'after': 2, 'being': 1, 'neutral': 1, 'fourth': 1, 'quarter.': 2, 'improvement': 1, 'dispelled': 1, 'concerns': 1, 'economy': 3, 'was': 3, 'heading': 1, 'into': 1, 'recession': 1, 'early': 1, 'summer,': 1, 'some': 1, 'analysts': 3, 'had': 1, 'feared,after': 1, 'slowdown': 1, 'year.': 2, 'but': 1, 'said': 1, 'federal': 1, 'reserve,': 1, 'has': 6, 'put': 1, 'interest': 1, 'hikes': 2, 'on': 2, 'hold,': 1, 'unlikely': 1, 'view': 1, 'beginning': 1, 'boom': 1, 'reverse': 1, 'its': 2, 'current': 1, 'policy.': 1, 'january,': 1, 'central': 2, 'bank': 2, 'suspended': 1, 'three-year': 1, 'push': 1, 'tighten': 1, 'monetary': 1, 'policy,': 1, 'saying': 1, 'it': 1, 'would': 1, 'pause': 1, 'further': 1, 'this': 2, 'fed': 1, 'increased': 2, 'borrowing': 1, 'costs': 1, 'four': 1, 'times': 1, 'range': 1, '2.25': 1, '2.5%': 1, '2018,': 1, 'above': 1, 'level': 2, 'base': 1, 'rates': 1, 'for': 3, 'most': 1, 'other': 1, 'major': 2, 'economies.': 1, 'is': 1, 'more': 2, 'likely': 1, 'focus': 1, 'measure': 1, 'domestic': 1, 'demand,': 1, 'by': 4, 'only': 3, '1.3%,': 1, 'slowest': 2, 'second': 2, '2013,': 1, 'increasing': 1, '2.6%': 1, 'accounts': 1, 'than': 2, 'two-thirds': 1, 'activity,': 1, 'also': 2, 'weak,': 1, 'growing': 1, 'just': 1, '1.2%': 1, 'previous': 1, '2.5%.': 1, 'slowed': 1, 'sharply,': 1, 'rising': 1, '0.2%': 1, 'rate,': 1, 'third': 1, '2016.': 1, 'reports': 2, 'show': 1, "world's": 1, 'largest': 1, 'arrested': 1, "year's": 1, 'decline,': 1, 'though': 1, 'many': 1, 'believe': 1, 'better': 1, 'outlook': 1, 'will': 2, 'prove': 1, 'temporary': 1, 'be': 1, 'lower': 1, 'european': 1, 'manufacturing': 1, 'slumped': 1, 'japanese': 1, 'output': 2, 'slowed,': 1, 'marking': 1, 'out': 1, 'maintaining': 1, 'high': 1, 'levels': 1, 'growth.': 1, 'effect': 1, 'stockpiling': 1, 'buoyed': 1, 'activity': 1, 'uk,': 1, 'where': 1, 'uncertainty': 1, 'over': 1, 'brexit': 1, 'negotiations': 1, 'unnerved': 1, 'encouraged': 1, 'them': 1, 'hoard': 1, 'materials.': 1, 'april,': 1, 'british': 2, 'factories': 1, 'stockpiled': 1, 'pace': 1, 'records': 1, 'began': 1, '1950s': 1, 'amid': 1, 'they': 1, 'were': 1, 'increasingly': 1, 'downbeat': 1, 'about': 1, 'their': 2, 'prospects.': 1, 'survey': 1, 'confederation': 1, 'industry': 1, 'found': 1, 'expectations': 1, 'export': 1, 'orders': 1, 'next': 1, 'fell': 1, 'lowest': 1, 'mid-2009.': 1})
# defaultdict(<class 'int'>, {'microsoft': 11, 'has': 4, 'become': 1, 'the': 23, 'third': 2, 'publicly': 1, 'listed': 2, 'us': 3, 'company,': 1, 'after': 5, 'apple': 3, 'and': 11, 'amazon,': 1, 'to': 16, 'boast': 1, 'a': 6, 'market': 5, 'value': 3, 'of': 10, 'more': 2, 'than': 2, '$1tn': 3, 'bumper': 1, 'quarterly': 2, 'results': 2, 'boosted': 1, 'its': 7, 'share': 2, 'price.': 1, 'company': 1, 'beat': 2, 'sales': 1, 'profits': 1, 'expectations': 1, 'in': 13, 'three': 1, 'months': 1, '31': 1, 'march,': 1, 'thanks': 1, 'part': 1, 'cloud': 5, 'computing': 2, 'business,': 1, 'which': 1, 'signed': 1, 'up': 3, 'major': 1, 'corporate': 1, 'clients': 1, 'over': 2, 'period.': 1, 'shares': 5, 'rose': 2, 'as': 4, 'much': 1, '5%': 1, 'early': 1, 'trading': 3, 'on': 1, 'thursday,': 1, 'briefly': 1, 'pushing': 1, 'above': 1, 'for': 5, 'first': 1, 'time': 1, 'before': 1, 'dipping': 1, 'back': 2, 'below': 1, 'again': 1, 'when': 1, 'price': 2, 'gain': 1, 'eased.': 1, 'it': 5, 'was': 1, 'latest': 1, 'tech': 1, 'firm': 2, 'join': 1, 'prestigious': 1, 'club,': 1, 'rival': 1, 'then': 1, 'amazon': 2, 'topped': 1, 'mark': 1, 'last': 1, 'year.': 1, 'since': 1, 'then,': 1, 'both': 1, 'companies': 1, 'have': 1, 'fallen': 1, 'now': 1, 'biggest': 1, 'capitalisation': 1, 'any': 1, 'stock': 1, 'company.': 1, 'facebook': 2, 'were': 2, 'also': 1, 'higher,': 1, '6%,': 1, 'easily': 1, 'forecasts': 1, 'with': 3, '26%': 1, 'jump': 1, 'revenues': 2, '$15bn': 1, 'an': 1, '8%': 1, 'rise': 1, 'active': 1, 'users.': 1, 'better-than-expected': 1, 'from': 2, 'helped': 1, 'push': 1, 'tech-focused': 1, 'nasdaq': 1, 'index': 1, 'new': 3, 'york': 1, '8,118': 1, 'points': 1, 'at': 5, 'close.': 1, 'boost': 1, 'came': 1, 'reported': 1, '14%': 1, 'increase': 1, 'revenue': 1, 'quarter': 1, '$30.6bn.': 1, 'net': 1, 'income': 1, '19%': 1, '$8.8bn.': 1, 'division': 1, 'jumped': 1, '14%,': 1, 'grocery': 1, 'kroger': 1, 'walgreens': 1, 'boots': 1, 'alliance': 1, 'among': 1, 'big': 1, 'client': 1, 'wins.': 1, 'satya': 1, 'nadella,': 1, 'chief': 1, 'executive': 1, 'microsoft,': 1, 'said:': 1, "'leading": 1, 'organisations': 1, 'every': 2, 'size': 1, 'industry': 1, 'trust': 1, 'cloud.': 1, 'we': 1, 'are': 1, 'accelerating': 1, 'our': 2, 'innovation': 1, 'across': 1, 'edge': 1, 'so': 1, 'customers': 1, 'can': 1, 'build': 1, 'digital': 1, 'capability': 1, 'increasingly': 1, 'required': 1, 'compete': 2, "grow.'": 1, '3.4%': 1, '$129': 1, 'close': 2, 'york,': 1, 'giving': 1, 'about': 1, '$995bn.': 1, 'is': 4, 'worth': 1, 'around': 1, '$970bn': 1, 'behind': 1, '$940bn.': 1, 'brad': 1, 'reback': 1, 'stockbrokers': 1, 'stifel': 2, 'said': 2, 'bright': 1, 'future:': 1, "'we": 1, 'continue': 1, 'believe': 1, 'shift': 1, 'will': 1, 'be': 1, 'additive': 1, 'given': 1, 'broader': 1, 'portfolio': 1, 'products': 1, 'deeper': 1, 'functionality': 1, 'well': 1, "microsoft's": 1, 'ability': 1, 'enter': 1, 'categories': 1, 'where': 1, 'did': 1, 'not': 1, "previously.'": 1, 'raised': 1, 'target': 1, '$150': 1, '$130.': 1, 'clearly': 1, 'way': 1, 'forward': 1, 'demand': 1, 'these': 1, 'services': 1, 'expected': 1, 'remain': 1, "strong,'": 1, 'jasper': 1, 'lawler,': 1, 'head': 1, 'research': 1, 'london': 1, 'capital': 1, 'group.': 1})
# defaultdict(<class 'int'>, {'siri,': 1, "apple's": 1, 'voice-controlled': 1, 'virtual': 1, 'assistant,': 1, 'is': 4, 'not': 2, 'just': 4, 'useful': 1, 'for': 1, 'hands-free': 1, 'texting,': 1, 'dictation': 1, 'and': 9, 'pizza': 1, 'place': 1, 'recommendations': 1, '-': 1, 'it': 2, 'turns': 1, 'out': 1, 'she': 3, 'also': 1, 'a': 7, 'skilled': 1, 'rapper.': 1, 'last': 1, 'month,': 1, 'judith': 1, 'newman': 1, 'wrote': 1, 'in': 2, 'the': 10, 'new': 1, 'york': 1, 'times': 1, 'how': 3, 'siri': 3, 'had': 1, 'befriended': 1, 'her': 4, 'autistic': 1, 'son,': 1, 'now': 1, 'seems': 1, 'that': 5, "siri's": 3, 'talents': 1, 'go': 1, 'even': 1, 'further.': 1, 'london-based': 1, 'producers': 2, 'skeewiff,': 1, 'aka': 1, 'alex': 1, 'rizzo': 2, 'elliot': 1, 'ireland,': 1, 'have': 1, 'uploaded': 1, 'remix': 1, 'of': 8, 'young': 2, "mc's": 2, 'know': 2, 'features': 1, 'siri.': 1, 'flow': 1, 'reminiscent': 1, 'nicki': 1, "minaj's": 1, 'best': 1, 'work': 1, 'on': 2, 'monster;': 1, 'has': 3, 'cadence': 1, 'as': 4, 'smooth': 2, 'angel': 1, 'haze;': 1, 'potty': 1, 'mouth': 1, 'worthy': 1, 'azealia': 1, 'banks.': 1, 'well': 2, 'name-checking': 1, 'spotify': 1, 'google,': 1, 'enunciation': 1, "young's": 1, 'rapid-fire': 1, 'lyrics': 2, 'are': 1, 'near-perfect,': 1, 'rapping:': 1, "i'm": 1, 'tough': 1, 'like': 4, 'bone': 1, '/': 6, 'sly': 1, 'stallone': 1, 'rocking': 1, 'clocking': 1, 'microphone': 1, 'mirror': 1, 'hearts': 1, 'i': 4, 'strike': 1, 'terror': 1, 'rhymes': 3, 'runs': 1, 'with': 3, 'no': 1, 'errors.': 1, 'who': 1, 'worked': 1, 'said': 1, 'they': 1, 'were': 1, 'thrilled': 1, 'performance.': 1, 'told': 1, 'guardian': 1, 'collaboration': 1, 'came': 1, 'about:': 1, "she's": 1, 'set': 1, 'to': 6, 'british': 1, 'female.': 1, 'asked': 2, 'dial': 1, 'up': 1, 'one': 1, 'my': 1, 'favourite': 1, 'boasting': 1, 'hip': 1, 'hop': 1, 'tracks': 1, 'all': 1, 'time,': 1, 'how.': 1, 'when': 2, 'read': 1, 'them': 1, 'out,': 1, 'was': 3, 'real': 1, 'rofl-ing': 1, 'started.': 1, 'tears': 1, 'everything.': 1, 'something': 1, 'about': 1, 'posh': 1, 'english,': 1, 'mechanical': 1, 'accent': 1, 'busting': 1, 'irresistible.': 1, 'at': 1, 'moment': 1, 'knew': 1, 'what': 1, 'needed': 1, 'be': 1, 'done,': 1, 'rest': 1, 'recording,': 1, 'replaying': 1, 'whole': 1, 'lot': 1, "editing.'": 1, 'this': 1, 'first': 1, 'time': 1, 'taken': 1, 'mic': 1, 'though.': 1, 'previously': 1, 'covered': 1, "eminem's": 1, 'lose': 1, 'yourself': 1, '(not': 1, 'great': 1, 'effort),': 1, 'and,': 1, 'better': 1, 'effect,': 1, 'notorious': 1, "big's": 1, 'hypnotize.': 1, 'x': 1, 'factor,': 1, 'watch': 1, 'out.': 1})
# defaultdict(<class 'int'>, {'netflix': 5, 'viewers': 3, 'prefer': 1, 'a': 13, 'diet': 1, 'of': 18, 'comedy': 2, 'at': 6, 'breakfast,': 1, 'portion': 1, 'drama': 2, 'on': 2, 'their': 2, 'lunch': 1, 'break': 1, 'and': 10, 'midnight': 3, 'snack': 1, 'documentaries.': 1, 'netflix,': 1, 'which': 2, 'has': 3, 'more': 3, 'than': 3, '100': 1, 'million': 1, 'subscribers': 1, 'worldwide,': 1, 'said': 3, 'analysis': 1, 'viewing': 7, 'data': 2, 'found': 1, 'that': 4, 'users': 2, 'its': 2, 'service': 1, 'were': 1, 'keen': 1, 'to': 9, 'start': 1, 'the': 21, 'day': 2, 'with': 4, 'laugh': 1, 'by': 6, 'watching': 1, 'comedies': 2, 'such': 3, 'as': 5, ',': 1, 'fuller': 1, 'house': 1, 'and.': 1, '6am': 2, 'members': 1, 'are': 4, '34%': 1, 'likely': 1, 'watch': 1, 'any': 1, 'other': 2, 'time': 1, 'day,': 1, 'data,': 1, 'gathered': 1, 'from': 2, 'across': 1, '22': 2, 'countries,': 2, 'shows.': 1, 'sneaking': 1, 'in': 8, 'an': 1, 'episode': 1, 'lunchtime': 2, 'emerged': 1, 'popular': 1, 'pastime': 1, 'shows': 3, 'genre,': 1, 'mad': 1, 'men,': 1, 'bloodline': 1, 'or': 1, 'orange': 1, 'is': 4, 'new': 2, 'black,': 1, 'accounting': 1, 'for': 2, '47%': 1, 'all': 1, 'between': 2, 'noon': 1, '2pm.': 1, 'evening': 1, 'peppered': 1, 'range': 1, 'usual': 1, 'suspects,': 1, 'including': 2, 'breaking': 1, 'bad': 1, 'stranger': 1, 'things,': 1, 'viewership': 1, 'thriller': 1, 'genre': 1, 'increases': 1, 'quarter': 1, '9pm.': 1, 'it': 1, 'back': 1, 'just': 1, 'before': 1, 'lights': 2, 'out': 1, "it's": 3, 'always': 1, 'sunny': 1, 'philadelphia,': 1, 'master': 1, 'none': 1, 'bojack': 1, 'horseman': 1, 'taking': 1, 'over': 1, '11pm.': 1, 'night': 1, 'owls': 1, '-': 4, '15%': 1, 'occurs': 1, 'documentaries': 2, 'popular.': 1, 'period': 1, 'there': 1, '24%': 1, 'surge': 1, 'making': 1, 'murderer': 1, 'planet': 1, 'earth.': 1, 'says': 1, 'business': 1, 'model,': 2, 'enables': 1, 'binge-watch': 1, 'entire': 1, 'series': 1, 'one': 1, 'go,': 1, 'counter': 1, 'traditional': 2, 'tv': 3, 'resulted': 1, 'marked': 1, 'changes': 1, 'kind': 1, 'being': 1, 'watched.': 1, "'for": 1, 'years': 1, 'our': 1, 'lives': 1, 'had': 1, 'fit': 1, 'around': 1, 'television,': 1, 'now': 1, 'way': 1, "round,'": 1, 'cindy': 1, 'holland,': 1, 'vice-president': 1, 'original': 1, 'content': 1, 'netflix.': 1, "'we've": 1, 'given': 1, 'consumers': 1, 'control': 1, 'interesting': 1, 'see': 1, 'behaviours': 1, 'emerge': 1, 'when': 1, "aren't": 1, 'tied': 1, "schedule.'": 1, 'trend': 1, 'suggests': 1, 'pattern': 1, 'breakfast': 2, 'news': 1, 'followed': 1, 'lighter': 1, 'schedule': 1, 'during': 1, 'off': 1, 'no': 2, 'longer': 1, 'applies.': 1, "'gone": 1, 'days': 1, 'every': 1, 'household': 1, 'waking': 1, 'up': 1, 'same': 1, 'programming': 1, "screens,'": 1, 'company': 1, 'said.': 1, "'when": 1, 'schedules': 1, 'set': 1, 'people': 1, 'not': 1, 'programmers,': 1, 'becomes': 1, 'bingeing': 1, "exception.'": 1, 'analysed': 1, 'six': 1, 'months': 1, 'streaming': 1, 'uk,': 1, 'argentina,': 1, 'brazil,': 1, 'india,': 1, 'zealand': 1, 'us.': 1})
# defaultdict(<class 'int'>, {'being': 1, 'lonely': 1, 'may': 2, 'make': 1, 'it': 4, 'harder': 1, 'to': 12, 'quit': 1, 'smoking,': 3, 'a': 7, 'new': 1, 'british': 2, 'study': 3, 'suggests.': 1, 'using': 1, 'genetic': 1, 'and': 4, 'survey': 1, 'data': 2, 'from': 3, 'hundreds': 1, 'of': 4, 'thousands': 1, 'people,': 1, 'researchers': 2, 'found': 3, 'that': 7, 'loneliness': 5, 'makes': 1, 'more': 5, 'likely': 3, 'someone': 1, 'will': 1, 'smoke.': 1, 'this': 4, 'type': 1, 'analysis': 1, 'is': 6, 'called': 1, 'mendelian': 1, 'randomization.': 1, "'this": 1, 'method': 1, 'has': 1, 'never': 1, 'been': 1, 'applied': 1, 'question': 1, 'before': 1, 'so': 2, 'the': 9, 'results': 1, 'are': 2, 'novel,': 1, 'but': 3, 'also': 3, "tentative,'": 1, 'said': 2, 'co-lead': 1, 'author': 2, 'robyn': 1, 'wootton,': 1, 'senior': 2, 'research': 2, 'associate': 2, 'at': 1, 'university': 2, 'bristol': 1, 'in': 5, 'united': 1, 'kingdom.': 1, "'we": 1, 'evidence': 1, 'suggest': 1, 'leads': 1, 'increased': 1, 'with': 4, 'people': 4, 'start': 1, 'smoke': 2, 'cigarettes': 1, 'be': 1, 'less': 1, "quit,'": 1, 'wootton': 1, 'news': 1, 'release.': 1, 'these': 1, 'mesh': 1, 'an': 1, 'observation': 1, 'during': 1, 'coronavirus': 1, 'pandemic,': 1, 'smoking.': 1, 'jorien': 1, 'treur': 2, 'said,': 1, "'our": 1, 'finding': 1, 'smoking': 3, 'lead': 1, 'tentative,': 1, 'line': 1, 'other': 1, 'recent': 1, 'studies': 1, 'identified': 1, 'as': 3, 'risk': 1, 'factor': 2, 'for': 3, 'poor': 1, 'mental': 1, 'health.': 1, 'potential': 1, 'mechanism': 1, 'relationship': 1, 'nicotine': 1, 'cigarette': 1, 'interferes': 1, 'neurotransmitters': 1, 'such': 1, 'dopamine': 1, "brain.'": 1, 'visiting': 1, 'amsterdam': 1, 'umc.': 1, 'looked': 1, 'connection': 1, 'between': 1, 'drinking': 1, 'none.': 1, 'still,': 1, 'if': 1, 'causes': 1, 'smoke,': 1, 'important': 1, 'alert': 1, 'cessation': 1, 'services': 1, 'they': 2, 'can': 1, 'add': 1, 'help': 1, 'quit,': 1, 'authors': 1, 'said.': 1, 'report': 1, 'was': 1, 'published': 1, 'june': 1, '16': 1, 'journal': 1, 'addiction.': 1})

# %% [markdown]
# ### Some simple visualizations
# The dictionaries from before don't tell us a whole lot. At least not at a quick glance. To make things a little prettier, I decided to make some bar charts using pandas to visualize the counts of the words in each article.

# %%
import pandas as pd
import matplotlib.pyplot as plt

counts = [get_word_counts(article[1]) for article in articles]

fig, axs = plt.subplots(10, gridspec_kw={'hspace': 1}, figsize=(10, 50))

for i in range(0, 10):
    series = pd.Series(data=counts[i])
    series[series >= 5].plot(ax=axs[i], kind='bar', ylabel='Counts', xlabel='Words').set_title(articles[i][0])

# %% [markdown]
# ### Removing Stopwords and Punctuation
# Now, as expected, the most common words in each of these these articles are **stopwords**. For my next bit of processing, I'm is going to remove the stopwords from each of the texts. Fortunatly, Python's ```nltk``` library has a whole list of stopwords for me to pull from.
#
# In addition to this I will also be removing the punctuation from the text.

# %%
from string import punctuation

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

def remove_punctuation(text):
    for char in punctuation:
        text = text.replace(char, "")
    return text

def remove_stopwords(word_list):
    return [word for word in word_list if word not in stopwords.words('english')]

series = pd.Series(data=remove_stopwords(articles[0][1].split())).value_counts()

series[series >= 3].plot.bar()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Now this graph is only for the first piece of text, but from what I can tell it looks much better than before. The title of the article is, "Brain Disconnects During Sleep," and the most frequent words appear to be related to this. We've got cortex, activity, sleep, neural which are related to the subject matter.

# %% [markdown]
# ## The Power of Python's NLTK Library
# Now that I've messed around a little, let's get to the good stuff. Python's NLTK library provides a ton of useful tools for natural language processing. In this project, we're going to explore some of the tools NLTK offers for tokenization, lemmatization, and pos-tagging. I'm also going to use a TF-IDF vectorizer from scikit-learn to calculate the the TF-IDF scores for our tokens.

# %% [markdown]
# ### Tokenization
# To start off, I'm going to take the original texts from the news articles and pass them through nltk's ```word_tokenize``` method.

# %%
import nltk
nltk.download('punkt')

from nltk import word_tokenize

text_tokens = [word_tokenize(article[1]) for article in articles]
text_tokens[0]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Scientists',
#  'may',
#  'have',
#  'gained',
#  'an',
#  'important',
#  'insight',
#  'into',
#  'the',
#  'age-old',
#  'mystery',
#  'of',
#  'why',
#  'consciousness',
#  'fades',
#  'as',
#  'we',
#  'nod',
#  'off',
#  'to',
#  'sleep',
#  '.',
#  'Lines',
#  'of',
#  'communication',
#  'between',
#  'various',
#  'parts',
#  'of',
#  'cerebral',
#  'cortex',
#  '-',
#  'which',
#  'buzz',
#  'with',
#  'activity',
#  'during',
#  'wakefulness',
#  '-',
#  'break',
#  'down',
#  'during',
#  'slumber',
#  ',',
#  'researchers',
#  'report',
#  'today',
#  'in',
#  'Science',
#  '.',
#  'Early',
#  'neuroscientists',
#  'assumed',
#  'that',
#  'consciousness',
#  'wanes',
#  'during',
#  'sleep',
#  'because',
#  'the',
#  'cortex',
#  'simply',
#  'shuts',
#  'off',
#  '.',
#  'But',
#  'electroencephalography',
#  '(',
#  'EEG',
#  ')',
#  'and',
#  'other',
#  'modern',
#  'methods',
#  'have',
#  'since',
#  'ruled',
#  'out',
#  'that',
#  'explanation',
#  ',',
#  'showing',
#  'that',
#  'the',
#  'electrical',
#  'chatter',
#  'and',
#  'metabolism',
#  'of',
#  'neurons',
#  'in',
#  'the',
#  'cortex',
#  'continues',
#  'unabated',
#  'during',
#  'sleep',
#  '.',
#  'That',
#  'left',
#  'neuroscientists',
#  'with',
#  'a',
#  'puzzle',
#  ':',
#  'If',
#  'the',
#  'brain',
#  'is',
#  'still',
#  'active',
#  ',',
#  'why',
#  'does',
#  'consciousness',
#  'wane',
#  '?',
#  'Giulio',
#  'Tononi',
#  'of',
#  'the',
#  'University',
#  'of',
#  'Wisconsin',
#  ',',
#  'Madison',
#  ',',
#  'suspected',
#  'that',
#  'a',
#  'communication',
#  'breakdown',
#  'might',
#  'be',
#  'the',
#  'reason',
#  '.',
#  'Tononi',
#  'has',
#  'spent',
#  'years',
#  'developing',
#  'a',
#  'theory',
#  'that',
#  'equates',
#  'consciousness',
#  'with',
#  'the',
#  'integration',
#  'of',
#  'information',
#  '.',
#  'Communication',
#  'between',
#  'regions',
#  'of',
#  'the',
#  'cortex',
#  'might',
#  'be',
#  'one',
#  'sign',
#  'of',
#  'this',
#  'integration',
#  '-',
#  'and',
#  'of',
#  'consciousness',
#  ',',
#  'Tononi',
#  'says',
#  '.',
#  'To',
#  'test',
#  'that',
#  'idea',
#  ',',
#  'he',
#  'and',
#  'his',
#  'team',
#  'recorded',
#  'electrical',
#  'activity',
#  'in',
#  'the',
#  'brains',
#  'of',
#  'six',
#  'sleepy',
#  'volunteers',
#  'using',
#  'high',
#  'density',
#  'EEG',
#  '.',
#  'Before',
#  'the',
#  'subjects',
#  'nodded',
#  'off',
#  ',',
#  'the',
#  'researchers',
#  'stimulated',
#  'a',
#  'small',
#  'patch',
#  'of',
#  'right',
#  'frontal',
#  'cortex',
#  'with',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  '(',
#  'TMS',
#  ')',
#  ',',
#  'a',
#  'method',
#  'that',
#  'uses',
#  'magnetic',
#  'pulses',
#  'to',
#  'induce',
#  'an',
#  'electrical',
#  'current',
#  'inside',
#  'the',
#  'head',
#  '.',
#  'When',
#  'the',
#  'subjects',
#  'were',
#  'awake',
#  ',',
#  'TMS',
#  'elicited',
#  'waves',
#  'of',
#  'neural',
#  'activity',
#  'that',
#  'spread',
#  'through',
#  'neighboring',
#  'areas',
#  'of',
#  'right',
#  'frontal',
#  'and',
#  'parietal',
#  'cortex',
#  'and',
#  'to',
#  'corresponding',
#  'regions',
#  'on',
#  'the',
#  'left',
#  'side',
#  'of',
#  'the',
#  'brain',
#  '.',
#  'During',
#  'non-rapid',
#  'eye',
#  'movement',
#  '(',
#  'non-REM',
#  ')',
#  'sleep',
#  ',',
#  'the',
#  'same',
#  'TMS',
#  'stimulus',
#  'only',
#  'elicited',
#  'neural',
#  'activity',
#  'at',
#  'the',
#  'site',
#  'of',
#  'stimulation',
#  '.',
#  'Tononi',
#  'says',
#  'the',
#  'findings',
#  'suggest',
#  'that',
#  'different',
#  'areas',
#  'of',
#  'cortex',
#  'do',
#  'indeed',
#  'stop',
#  'talking',
#  'to',
#  'each',
#  'other',
#  'during',
#  'non-REM',
#  'sleep',
#  '-',
#  'a',
#  'stage',
#  'in',
#  'which',
#  'people',
#  'often',
#  'report',
#  'little',
#  'or',
#  'no',
#  'conscious',
#  'experience',
#  'on',
#  'waking',
#  '.',
#  'An',
#  'important',
#  'follow-up',
#  ',',
#  'he',
#  'says',
#  ',',
#  'will',
#  'be',
#  'to',
#  'repeat',
#  'the',
#  'experiments',
#  'during',
#  'late-night',
#  'REM',
#  'sleep',
#  ',',
#  'when',
#  'people',
#  'often',
#  'report',
#  'consciouslike',
#  'experiences',
#  'in',
#  'the',
#  'form',
#  'of',
#  'dreams',
#  '.',
#  "'We",
#  'would',
#  'predict',
#  'a',
#  'pattern',
#  'which',
#  'is',
#  'much',
#  'more',
#  'similar',
#  'to',
#  'wakefulness',
#  ',',
#  "'",
#  'he',
#  'says',
#  '.',
#  'The',
#  'research',
#  "'definitely",
#  'tells',
#  'us',
#  'something',
#  'about',
#  'sleep',
#  'and',
#  'may',
#  'have',
#  'important',
#  'implications',
#  'for',
#  'understanding',
#  'the',
#  'neural',
#  'correlates',
#  'of',
#  'consciousness',
#  ',',
#  "'",
#  'says',
#  'Christof',
#  'Koch',
#  ',',
#  'a',
#  'cognitive',
#  'neuroscientist',
#  'at',
#  'the',
#  'California',
#  'Institute',
#  'of',
#  'Technology',
#  'in',
#  'Pasadena',
#  '.']

# %% [markdown]
# Ahh. Now that's kinda nice. All of the words, punctuation, numbers, and other special characters have been isolated for us and put into a big list. This will make things much easier to process.

# %% [markdown]
# ### A little cleaning
# Now, lets try removing the stopwords and punctuation from this list and then try plotting the most frequent words again.
#
# To do this, I'm going to use Python's filter method and lambda expressions. The first filter filters out the stopwords, and the second filter filters out the punctuation.

# %%
new_tokens = []

for tokens in text_tokens:
    filter_stopwords = list(filter(lambda x: x not in stopwords.words('english'), tokens))
    filter_punctuation = list(filter(lambda x: x not in punctuation, filter_stopwords))

    new_tokens.append(filter_punctuation)

new_tokens[0]
# Out:
# ['Scientists',
#  'may',
#  'gained',
#  'important',
#  'insight',
#  'age-old',
#  'mystery',
#  'consciousness',
#  'fades',
#  'nod',
#  'sleep',
#  'Lines',
#  'communication',
#  'various',
#  'parts',
#  'cerebral',
#  'cortex',
#  'buzz',
#  'activity',
#  'wakefulness',
#  'break',
#  'slumber',
#  'researchers',
#  'report',
#  'today',
#  'Science',
#  'Early',
#  'neuroscientists',
#  'assumed',
#  'consciousness',
#  'wanes',
#  'sleep',
#  'cortex',
#  'simply',
#  'shuts',
#  'But',
#  'electroencephalography',
#  'EEG',
#  'modern',
#  'methods',
#  'since',
#  'ruled',
#  'explanation',
#  'showing',
#  'electrical',
#  'chatter',
#  'metabolism',
#  'neurons',
#  'cortex',
#  'continues',
#  'unabated',
#  'sleep',
#  'That',
#  'left',
#  'neuroscientists',
#  'puzzle',
#  'If',
#  'brain',
#  'still',
#  'active',
#  'consciousness',
#  'wane',
#  'Giulio',
#  'Tononi',
#  'University',
#  'Wisconsin',
#  'Madison',
#  'suspected',
#  'communication',
#  'breakdown',
#  'might',
#  'reason',
#  'Tononi',
#  'spent',
#  'years',
#  'developing',
#  'theory',
#  'equates',
#  'consciousness',
#  'integration',
#  'information',
#  'Communication',
#  'regions',
#  'cortex',
#  'might',
#  'one',
#  'sign',
#  'integration',
#  'consciousness',
#  'Tononi',
#  'says',
#  'To',
#  'test',
#  'idea',
#  'team',
#  'recorded',
#  'electrical',
#  'activity',
#  'brains',
#  'six',
#  'sleepy',
#  'volunteers',
#  'using',
#  'high',
#  'density',
#  'EEG',
#  'Before',
#  'subjects',
#  'nodded',
#  'researchers',
#  'stimulated',
#  'small',
#  'patch',
#  'right',
#  'frontal',
#  'cortex',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  'TMS',
#  'method',
#  'uses',
#  'magnetic',
#  'pulses',
#  'induce',
#  'electrical',
#  'current',
#  'inside',
#  'head',
#  'When',
#  'subjects',
#  'awake',
#  'TMS',
#  'elicited',
#  'waves',
#  'neural',
#  'activity',
#  'spread',
#  'neighboring',
#  'areas',
#  'right',
#  'frontal',
#  'parietal',
#  'cortex',
#  'corresponding',
#  'regions',
#  'left',
#  'side',
#  'brain',
#  'During',
#  'non-rapid',
#  'eye',
#  'movement',
#  'non-REM',
#  'sleep',
#  'TMS',
#  'stimulus',
#  'elicited',
#  'neural',
#  'activity',
#  'site',
#  'stimulation',
#  'Tononi',
#  'says',
#  'findings',
#  'suggest',
#  'different',
#  'areas',
#  'cortex',
#  'indeed',
#  'stop',
#  'talking',
#  'non-REM',
#  'sleep',
#  'stage',
#  'people',
#  'often',
#  'report',
#  'little',
#  'conscious',
#  'experience',
#  'waking',
#  'An',
#  'important',
#  'follow-up',
#  'says',
#  'repeat',
#  'experiments',
#  'late-night',
#  'REM',
#  'sleep',
#  'people',
#  'often',
#  'report',
#  'consciouslike',
#  'experiences',
#  'form',
#  'dreams',
#  "'We",
#  'would',
#  'predict',
#  'pattern',
#  'much',
#  'similar',
#  'wakefulness',
#  'says',
#  'The',
#  'research',
#  "'definitely",
#  'tells',
#  'us',
#  'something',
#  'sleep',
#  'may',
#  'important',
#  'implications',
#  'understanding',
#  'neural',
#  'correlates',
#  'consciousness',
#  'says',
#  'Christof',
#  'Koch',
#  'cognitive',
#  'neuroscientist',
#  'California',
#  'Institute',
#  'Technology',
#  'Pasadena']

# %% [markdown]
# The results for the first article look... okay. We've got words like **cortex**, **sleep**, and **conciousness** which are related to the article, but words like **says** and **activity** don't really tell us anything about the subject of the article.

# %%
fig, axs = plt.subplots(10, gridspec_kw={'hspace': 1}, figsize=(10, 50))

titles = [a[0] for a in articles]

for i, title in zip(range(0, 10), titles):
    series = pd.Series(data=new_tokens[i]).value_counts()
    series.head().plot(ax=axs[i], kind='bar', ylabel='Counts', xlabel='Words').set_title(title)

# %% [markdown]
# ### POS-tagging
# Next, we want to figure out each tokens *part-of-speech*. Ie whether we're dealing with a verb, a noun, an adjective, etc. Typcially the subject of some piece of text is a noun, so perhaps, if we can identify the the frequently occuring nouns in each of the texts, we could get an even better feel for what the subject of each of the articles is.To do this we'll use nltk's ```pos_tag```, a pretrained model for figuring out the POS of a word.

# %% [markdown]
# To start, I'm just going to get the POS-tags for the first article.

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')

pos_tag(new_tokens[0])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# [('Scientists', 'NNS'),
#  ('may', 'MD'),
#  ('gained', 'VB'),
#  ('important', 'JJ'),
#  ('insight', 'JJ'),
#  ('age-old', 'JJ'),
#  ('mystery', 'NN'),
#  ('consciousness', 'NN'),
#  ('fades', 'NNS'),
#  ('nod', 'RB'),
#  ('sleep', 'VBP'),
#  ('Lines', 'NNPS'),
#  ('communication', 'NN'),
#  ('various', 'JJ'),
#  ('parts', 'NNS'),
#  ('cerebral', 'JJ'),
#  ('cortex', 'NNS'),
#  ('buzz', 'NN'),
#  ('activity', 'NN'),
#  ('wakefulness', 'NN'),
#  ('break', 'NN'),
#  ('slumber', 'JJ'),
#  ('researchers', 'NNS'),
#  ('report', 'NN'),
#  ('today', 'NN'),
#  ('Science', 'NNP'),
#  ('Early', 'NNP'),
#  ('neuroscientists', 'NNS'),
#  ('assumed', 'VBD'),
#  ('consciousness', 'JJ'),
#  ('wanes', 'NNS'),
#  ('sleep', 'VBP'),
#  ('cortex', 'NN'),
#  ('simply', 'RB'),
#  ('shuts', 'VBZ'),
#  ('But', 'CC'),
#  ('electroencephalography', 'VBZ'),
#  ('EEG', 'NNP'),
#  ('modern', 'JJ'),
#  ('methods', 'NNS'),
#  ('since', 'IN'),
#  ('ruled', 'VBN'),
#  ('explanation', 'NN'),
#  ('showing', 'VBG'),
#  ('electrical', 'JJ'),
#  ('chatter', 'NN'),
#  ('metabolism', 'NN'),
#  ('neurons', 'NNS'),
#  ('cortex', 'VBP'),
#  ('continues', 'VBZ'),
#  ('unabated', 'JJ'),
#  ('sleep', 'NN'),
#  ('That', 'WDT'),
#  ('left', 'VBD'),
#  ('neuroscientists', 'NNS'),
#  ('puzzle', 'VBP'),
#  ('If', 'IN'),
#  ('brain', 'NN'),
#  ('still', 'RB'),
#  ('active', 'JJ'),
#  ('consciousness', 'NN'),
#  ('wane', 'NN'),
#  ('Giulio', 'NNP'),
#  ('Tononi', 'NNP'),
#  ('University', 'NNP'),
#  ('Wisconsin', 'NNP'),
#  ('Madison', 'NNP'),
#  ('suspected', 'VBD'),
#  ('communication', 'NN'),
#  ('breakdown', 'NN'),
#  ('might', 'MD'),
#  ('reason', 'NN'),
#  ('Tononi', 'NNP'),
#  ('spent', 'NN'),
#  ('years', 'NNS'),
#  ('developing', 'VBG'),
#  ('theory', 'NN'),
#  ('equates', 'NNS'),
#  ('consciousness', 'JJ'),
#  ('integration', 'NN'),
#  ('information', 'NN'),
#  ('Communication', 'NNP'),
#  ('regions', 'NNS'),
#  ('cortex', 'NN'),
#  ('might', 'MD'),
#  ('one', 'CD'),
#  ('sign', 'NN'),
#  ('integration', 'NN'),
#  ('consciousness', 'NN'),
#  ('Tononi', 'NNP'),
#  ('says', 'VBZ'),
#  ('To', 'TO'),
#  ('test', 'VB'),
#  ('idea', 'NN'),
#  ('team', 'NN'),
#  ('recorded', 'VBD'),
#  ('electrical', 'JJ'),
#  ('activity', 'NN'),
#  ('brains', 'NNS'),
#  ('six', 'CD'),
#  ('sleepy', 'JJ'),
#  ('volunteers', 'NNS'),
#  ('using', 'VBG'),
#  ('high', 'JJ'),
#  ('density', 'NN'),
#  ('EEG', 'NNP'),
#  ('Before', 'IN'),
#  ('subjects', 'NNS'),
#  ('nodded', 'JJ'),
#  ('researchers', 'NNS'),
#  ('stimulated', 'VBD'),
#  ('small', 'JJ'),
#  ('patch', 'NN'),
#  ('right', 'JJ'),
#  ('frontal', 'JJ'),
#  ('cortex', 'NN'),
#  ('transcranial', 'JJ'),
#  ('magnetic', 'JJ'),
#  ('stimulation', 'NN'),
#  ('TMS', 'NNP'),
#  ('method', 'NN'),
#  ('uses', 'VBZ'),
#  ('magnetic', 'JJ'),
#  ('pulses', 'NNS'),
#  ('induce', 'VBP'),
#  ('electrical', 'JJ'),
#  ('current', 'JJ'),
#  ('inside', 'IN'),
#  ('head', 'NN'),
#  ('When', 'WRB'),
#  ('subjects', 'NNS'),
#  ('awake', 'VBP'),
#  ('TMS', 'NNP'),
#  ('elicited', 'VBD'),
#  ('waves', 'NNS'),
#  ('neural', 'JJ'),
#  ('activity', 'NN'),
#  ('spread', 'NN'),
#  ('neighboring', 'VBG'),
#  ('areas', 'NNS'),
#  ('right', 'JJ'),
#  ('frontal', 'JJ'),
#  ('parietal', 'JJ'),
#  ('cortex', 'NN'),
#  ('corresponding', 'VBG'),
#  ('regions', 'NNS'),
#  ('left', 'VBD'),
#  ('side', 'JJ'),
#  ('brain', 'NN'),
#  ('During', 'IN'),
#  ('non-rapid', 'JJ'),
#  ('eye', 'NN'),
#  ('movement', 'NN'),
#  ('non-REM', 'JJ'),
#  ('sleep', 'NN'),
#  ('TMS', 'NNP'),
#  ('stimulus', 'NN'),
#  ('elicited', 'VBD'),
#  ('neural', 'JJ'),
#  ('activity', 'NN'),
#  ('site', 'NN'),
#  ('stimulation', 'NN'),
#  ('Tononi', 'NNP'),
#  ('says', 'VBZ'),
#  ('findings', 'NNS'),
#  ('suggest', 'VBP'),
#  ('different', 'JJ'),
#  ('areas', 'NNS'),
#  ('cortex', 'VBP'),
#  ('indeed', 'RB'),
#  ('stop', 'JJ'),
#  ('talking', 'VBG'),
#  ('non-REM', 'JJ'),
#  ('sleep', 'JJ'),
#  ('stage', 'NN'),
#  ('people', 'NNS'),
#  ('often', 'RB'),
#  ('report', 'VBP'),
#  ('little', 'JJ'),
#  ('conscious', 'JJ'),
#  ('experience', 'NN'),
#  ('waking', 'VBG'),
#  ('An', 'DT'),
#  ('important', 'JJ'),
#  ('follow-up', 'NN'),
#  ('says', 'VBZ'),
#  ('repeat', 'NN'),
#  ('experiments', 'NNS'),
#  ('late-night', 'JJ'),
#  ('REM', 'NNP'),
#  ('sleep', 'NN'),
#  ('people', 'NNS'),
#  ('often', 'RB'),
#  ('report', 'VBP'),
#  ('consciouslike', 'JJ'),
#  ('experiences', 'NNS'),
#  ('form', 'VBP'),
#  ('dreams', 'NNS'),
#  ("'We", 'POS'),
#  ('would', 'MD'),
#  ('predict', 'VB'),
#  ('pattern', 'RB'),
#  ('much', 'JJ'),
#  ('similar', 'JJ'),
#  ('wakefulness', 'NN'),
#  ('says', 'VBZ'),
#  ('The', 'DT'),
#  ('research', 'NN'),
#  ("'definitely", 'RB'),
#  ('tells', 'VBZ'),
#  ('us', 'PRP'),
#  ('something', 'NN'),
#  ('sleep', 'NN'),
#  ('may', 'MD'),
#  ('important', 'JJ'),
#  ('implications', 'NNS'),
#  ('understanding', 'VBG'),
#  ('neural', 'JJ'),
#  ('correlates', 'NNS'),
#  ('consciousness', 'VBP'),
#  ('says', 'VBZ'),
#  ('Christof', 'NNP'),
#  ('Koch', 'NNP'),
#  ('cognitive', 'JJ'),
#  ('neuroscientist', 'NN'),
#  ('California', 'NNP'),
#  ('Institute', 'NNP'),
#  ('Technology', 'NNP'),
#  ('Pasadena', 'NNP')]

# %% [markdown]
# These are the POS-tags for all the tokens in the first article. There's three main categories we are concerned with, namely nouns, verbs, and adjectives. Some of the other misc tags, such as 'WW' and 'IN' don't really help us.
#
# From here, we'll get the rest of the tags for the tokens from the other articles with their POS-tags and save them in the variable ```tagged_tokens```.

# %%
tagged_tokens = [pos_tag(tokens) for tokens in new_tokens]
tagged_tokens
# Out:
# [[('Scientists', 'NNS'),
#   ('may', 'MD'),
#   ('gained', 'VB'),
#   ('important', 'JJ'),
#   ('insight', 'JJ'),
#   ('age-old', 'JJ'),
#   ('mystery', 'NN'),
#   ('consciousness', 'NN'),
#   ('fades', 'NNS'),
#   ('nod', 'RB'),
#   ('sleep', 'VBP'),
#   ('Lines', 'NNPS'),
#   ('communication', 'NN'),
#   ('various', 'JJ'),
#   ('parts', 'NNS'),
#   ('cerebral', 'JJ'),
#   ('cortex', 'NNS'),
#   ('buzz', 'NN'),
#   ('activity', 'NN'),
#   ('wakefulness', 'NN'),
#   ('break', 'NN'),
#   ('slumber', 'JJ'),
#   ('researchers', 'NNS'),
#   ('report', 'NN'),
#   ('today', 'NN'),
#   ('Science', 'NNP'),
#   ('Early', 'NNP'),
#   ('neuroscientists', 'NNS'),
#   ('assumed', 'VBD'),
#   ('consciousness', 'JJ'),
#   ('wanes', 'NNS'),
#   ('sleep', 'VBP'),
#   ('cortex', 'NN'),
#   ('simply', 'RB'),
#   ('shuts', 'VBZ'),
#   ('But', 'CC'),
#   ('electroencephalography', 'VBZ'),
#   ('EEG', 'NNP'),
#   ('modern', 'JJ'),
#   ('methods', 'NNS'),
#   ('since', 'IN'),
#   ('ruled', 'VBN'),
#   ('explanation', 'NN'),
#   ('showing', 'VBG'),
#   ('electrical', 'JJ'),
#   ('chatter', 'NN'),
#   ('metabolism', 'NN'),
#   ('neurons', 'NNS'),
#   ('cortex', 'VBP'),
#   ('continues', 'VBZ'),
#   ('unabated', 'JJ'),
#   ('sleep', 'NN'),
#   ('That', 'WDT'),
#   ('left', 'VBD'),
#   ('neuroscientists', 'NNS'),
#   ('puzzle', 'VBP'),
#   ('If', 'IN'),
#   ('brain', 'NN'),
#   ('still', 'RB'),
#   ('active', 'JJ'),
#   ('consciousness', 'NN'),
#   ('wane', 'NN'),
#   ('Giulio', 'NNP'),
#   ('Tononi', 'NNP'),
#   ('University', 'NNP'),
#   ('Wisconsin', 'NNP'),
#   ('Madison', 'NNP'),
#   ('suspected', 'VBD'),
#   ('communication', 'NN'),
#   ('breakdown', 'NN'),
#   ('might', 'MD'),
#   ('reason', 'NN'),
#   ('Tononi', 'NNP'),
#   ('spent', 'NN'),
#   ('years', 'NNS'),
#   ('developing', 'VBG'),
#   ('theory', 'NN'),
#   ('equates', 'NNS'),
#   ('consciousness', 'JJ'),
#   ('integration', 'NN'),
#   ('information', 'NN'),
#   ('Communication', 'NNP'),
#   ('regions', 'NNS'),
#   ('cortex', 'NN'),
#   ('might', 'MD'),
#   ('one', 'CD'),
#   ('sign', 'NN'),
#   ('integration', 'NN'),
#   ('consciousness', 'NN'),
#   ('Tononi', 'NNP'),
#   ('says', 'VBZ'),
#   ('To', 'TO'),
#   ('test', 'VB'),
#   ('idea', 'NN'),
#   ('team', 'NN'),
#   ('recorded', 'VBD'),
#   ('electrical', 'JJ'),
#   ('activity', 'NN'),
#   ('brains', 'NNS'),
#   ('six', 'CD'),
#   ('sleepy', 'JJ'),
#   ('volunteers', 'NNS'),
#   ('using', 'VBG'),
#   ('high', 'JJ'),
#   ('density', 'NN'),
#   ('EEG', 'NNP'),
#   ('Before', 'IN'),
#   ('subjects', 'NNS'),
#   ('nodded', 'JJ'),
#   ('researchers', 'NNS'),
#   ('stimulated', 'VBD'),
#   ('small', 'JJ'),
#   ('patch', 'NN'),
#   ('right', 'JJ'),
#   ('frontal', 'JJ'),
#   ('cortex', 'NN'),
#   ('transcranial', 'JJ'),
#   ('magnetic', 'JJ'),
#   ('stimulation', 'NN'),
#   ('TMS', 'NNP'),
#   ('method', 'NN'),
#   ('uses', 'VBZ'),
#   ('magnetic', 'JJ'),
#   ('pulses', 'NNS'),
#   ('induce', 'VBP'),
#   ('electrical', 'JJ'),
#   ('current', 'JJ'),
#   ('inside', 'IN'),
#   ('head', 'NN'),
#   ('When', 'WRB'),
#   ('subjects', 'NNS'),
#   ('awake', 'VBP'),
#   ('TMS', 'NNP'),
#   ('elicited', 'VBD'),
#   ('waves', 'NNS'),
#   ('neural', 'JJ'),
#   ('activity', 'NN'),
#   ('spread', 'NN'),
#   ('neighboring', 'VBG'),
#   ('areas', 'NNS'),
#   ('right', 'JJ'),
#   ('frontal', 'JJ'),
#   ('parietal', 'JJ'),
#   ('cortex', 'NN'),
#   ('corresponding', 'VBG'),
#   ('regions', 'NNS'),
#   ('left', 'VBD'),
#   ('side', 'JJ'),
#   ('brain', 'NN'),
#   ('During', 'IN'),
#   ('non-rapid', 'JJ'),
#   ('eye', 'NN'),
#   ('movement', 'NN'),
#   ('non-REM', 'JJ'),
#   ('sleep', 'NN'),
#   ('TMS', 'NNP'),
#   ('stimulus', 'NN'),
#   ('elicited', 'VBD'),
#   ('neural', 'JJ'),
#   ('activity', 'NN'),
#   ('site', 'NN'),
#   ('stimulation', 'NN'),
#   ('Tononi', 'NNP'),
#   ('says', 'VBZ'),
#   ('findings', 'NNS'),
#   ('suggest', 'VBP'),
#   ('different', 'JJ'),
#   ('areas', 'NNS'),
#   ('cortex', 'VBP'),
#   ('indeed', 'RB'),
#   ('stop', 'JJ'),
#   ('talking', 'VBG'),
#   ('non-REM', 'JJ'),
#   ('sleep', 'JJ'),
#   ('stage', 'NN'),
#   ('people', 'NNS'),
#   ('often', 'RB'),
#   ('report', 'VBP'),
#   ('little', 'JJ'),
#   ('conscious', 'JJ'),
#   ('experience', 'NN'),
#   ('waking', 'VBG'),
#   ('An', 'DT'),
#   ('important', 'JJ'),
#   ('follow-up', 'NN'),
#   ('says', 'VBZ'),
#   ('repeat', 'NN'),
#   ('experiments', 'NNS'),
#   ('late-night', 'JJ'),
#   ('REM', 'NNP'),
#   ('sleep', 'NN'),
#   ('people', 'NNS'),
#   ('often', 'RB'),
#   ('report', 'VBP'),
#   ('consciouslike', 'JJ'),
#   ('experiences', 'NNS'),
#   ('form', 'VBP'),
#   ('dreams', 'NNS'),
#   ("'We", 'POS'),
#   ('would', 'MD'),
#   ('predict', 'VB'),
#   ('pattern', 'RB'),
#   ('much', 'JJ'),
#   ('similar', 'JJ'),
#   ('wakefulness', 'NN'),
#   ('says', 'VBZ'),
#   ('The', 'DT'),
#   ('research', 'NN'),
#   ("'definitely", 'RB'),
#   ('tells', 'VBZ'),
#   ('us', 'PRP'),
#   ('something', 'NN'),
#   ('sleep', 'NN'),
#   ('may', 'MD'),
#   ('important', 'JJ'),
#   ('implications', 'NNS'),
#   ('understanding', 'VBG'),
#   ('neural', 'JJ'),
#   ('correlates', 'NNS'),
#   ('consciousness', 'VBP'),
#   ('says', 'VBZ'),
#   ('Christof', 'NNP'),
#   ('Koch', 'NNP'),
#   ('cognitive', 'JJ'),
#   ('neuroscientist', 'NN'),
#   ('California', 'NNP'),
#   ('Institute', 'NNP'),
#   ('Technology', 'NNP'),
#   ('Pasadena', 'NNP')],
#  [('Half', 'DT'),
#   ('million', 'CD'),
#   ('years', 'NNS'),
#   ('ago', 'RB'),
#   ('several', 'JJ'),
#   ('different', 'JJ'),
#   ('members', 'NNS'),
#   ('genus', 'VBP'),
#   ('Homo', 'NNP'),
#   ('spread', 'NN'),
#   ('throughout', 'IN'),
#   ('Europe', 'NNP'),
#   ('Asia', 'NNP'),
#   ('would', 'MD'),
#   ('eventually', 'RB'),
#   ('evolve', 'VB'),
#   ('Neandertals', 'NNS'),
#   ('But', 'CC'),
#   ('ones', 'NNS'),
#   ('subject', 'JJ'),
#   ('intense', 'JJ'),
#   ('debate', 'NN'),
#   ('A', 'NNP'),
#   ('newly', 'RB'),
#   ('discovered', 'VBN'),
#   ('partial', 'JJ'),
#   ('skull', 'NN'),
#   ('offering', 'NN'),
#   ('another', 'DT'),
#   ('clue', 'NN'),
#   ('help', 'NN'),
#   ('solve', 'VB'),
#   ('mystery', 'NN'),
#   ('ancestry', 'NN'),
#   ('Neandertals', 'NNP'),
#   ('Found', 'NNP'),
#   ('2014', 'CD'),
#   ('Gruta', 'NNP'),
#   ('da', 'NN'),
#   ('Aroeira', 'NNP'),
#   ('cave', 'VBP'),
#   ('central', 'JJ'),
#   ('Portugal', 'NNP'),
#   ('ancient', 'NN'),
#   ('stone', 'NN'),
#   ('hand', 'NN'),
#   ('axes', 'NNS'),
#   ('skull', 'VBP'),
#   ('3D', 'CD'),
#   ('reconstruction', 'NN'),
#   ('pictured', 'VBD'),
#   ('firmly', 'RB'),
#   ('dated', 'VBN'),
#   ('400,000', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   ('archaic', 'JJ'),
#   ('member', 'NN'),
#   ('genus', 'NN'),
#   ('according', 'VBG'),
#   ('study', 'NN'),
#   ('published', 'VBN'),
#   ('today', 'NN'),
#   ('Proceedings', 'NNP'),
#   ('National', 'NNP'),
#   ('Academy', 'NNP'),
#   ('Sciences', 'NNPS'),
#   ('The', 'DT'),
#   ('skull', 'NN'),
#   ('shows', 'VBZ'),
#   ('new', 'JJ'),
#   ('mix', 'NN'),
#   ('features', 'NNS'),
#   ('seen', 'VBN'),
#   ('fossil', 'JJ'),
#   ('humans-it', 'JJ'),
#   ('traits', 'NNS'),
#   ('link', 'VBP'),
#   ('Neandertals', 'NNS'),
#   ('fused', 'VBD'),
#   ('brow', 'NN'),
#   ('ridge', 'NN'),
#   ('well', 'RB'),
#   ('primitive', 'JJ'),
#   ('traits', 'NNS'),
#   ('resemble', 'JJ'),
#   ('extinct', 'JJ'),
#   ('fossils', 'NNS'),
#   ('Europe', 'NNP'),
#   ('This', 'DT'),
#   ('new', 'JJ'),
#   ('combination', 'NN'),
#   ('features', 'VBZ'),
#   ('well-dated', 'JJ'),
#   ('skull', 'NN'),
#   ('may', 'MD'),
#   ('help', 'VB'),
#   ('researchers', 'NNS'),
#   ('sort', 'VB'),
#   ('different', 'JJ'),
#   ('fossils', 'NNS'),
#   ('Europe', 'NNP'),
#   ('related', 'VBD'),
#   ('other-and', 'JJ'),
#   ('ones', 'NNS'),
#   ('eventually', 'RB'),
#   ('evolved', 'VBD'),
#   ('Neandertals', 'NNS')],
#  [('People', 'NNS'),
#   ('live', 'VBP'),
#   ('close', 'JJ'),
#   ('sea', 'NN'),
#   ('better', 'RBR'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('live', 'VBP'),
#   ('away', 'RB'),
#   ('regardless', 'RB'),
#   ('household', 'JJ'),
#   ('income', 'NN'),
#   ('new', 'JJ'),
#   ('study', 'NN'),
#   ('suggests', 'VBZ'),
#   ('According', 'VBG'),
#   ('scientists', 'NNS'),
#   ('living', 'VBG'),
#   ('near', 'IN'),
#   ('sea', 'NN'),
#   ('could', 'MD'),
#   ('support', 'VB'),
#   ('better', 'JJR'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('England', 'NNP'),
#   ("'s", 'POS'),
#   ('poorest', 'JJS'),
#   ('communities', 'NNS'),
#   ('Researchers', 'NNP'),
#   ('University', 'NNP'),
#   ('Exeter', 'NNP'),
#   ('used', 'VBD'),
#   ('survey', 'NN'),
#   ('data', 'NNS'),
#   ('25,963', 'CD'),
#   ('respondents', 'NNS'),
#   ('investigations', 'NNS'),
#   ('wellbeing', 'VBG'),
#   ('effects', 'NNS'),
#   ('coast', 'NN'),
#   ('After', 'IN'),
#   ('taking', 'VBG'),
#   ('related', 'JJ'),
#   ('factors', 'NNS'),
#   ('account', 'VBP'),
#   ('found', 'VBN'),
#   ('living', 'VBG'),
#   ('large', 'JJ'),
#   ('towns', 'NNS'),
#   ('cities', 'NNS'),
#   ('near', 'IN'),
#   ('coastline', 'NN'),
#   ('linked', 'VBN'),
#   ('better', 'RBR'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('lowest', 'JJS'),
#   ('earning', 'NN'),
#   ('households', 'VBZ'),
#   ('The', 'DT'),
#   ('research', 'NN'),
#   ('suggests', 'VBZ'),
#   ('live', 'VBP'),
#   ('less', 'JJR'),
#   ('kilometre', 'JJ'),
#   ('coast', 'NN'),
#   ('around', 'IN'),
#   ('22', 'CD'),
#   ('per', 'IN'),
#   ('cent', 'NN'),
#   ('less', 'RBR'),
#   ('likely', 'JJ'),
#   ('symptoms', 'NNS'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('disorder', 'NN'),
#   ('live', 'VBP'),
#   ('50km', 'CD'),
#   ('away', 'RB'),
#   ('Those', 'DT'),
#   ('low', 'JJ'),
#   ('income', 'NN'),
#   ('households', 'NNS'),
#   ('less', 'RBR'),
#   ('kilometre', 'JJ'),
#   ('coast', 'NN'),
#   ('around', 'IN'),
#   ('40', 'CD'),
#   ('per', 'IN'),
#   ('cent', 'NN'),
#   ('less', 'RBR'),
#   ('likely', 'JJ'),
#   ('symptoms', 'NNS'),
#   ('compared', 'VBN'),
#   ('earning', 'VBG'),
#   ('amount', 'NN'),
#   ('living', 'VBG'),
#   ('50km', 'CD'),
#   ('away', 'RB'),
#   ('Around', 'IN'),
#   ('one', 'CD'),
#   ('six', 'CD'),
#   ('adults', 'NNS'),
#   ('England', 'NNP'),
#   ('suffer', 'VBP'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('disorders', 'NNS'),
#   ('anxiety', 'VBP'),
#   ('depression', 'NN'),
#   ('far', 'RB'),
#   ('likely', 'JJ'),
#   ('people', 'NNS'),
#   ('poorer', 'VBP'),
#   ('backgrounds', 'NNS'),
#   ('Published', 'VBN'),
#   ('Health', 'NNP'),
#   ('Place', 'NNP'),
#   ('journal', 'JJ'),
#   ('findings', 'NNS'),
#   ('suggest', 'VBP'),
#   ('access', 'NN'),
#   ('coast', 'NN'),
#   ('could', 'MD'),
#   ('help', 'VB'),
#   ('reduce', 'VB'),
#   ('health', 'NN'),
#   ('inequalities', 'NNS'),
#   ('towns', 'VBP'),
#   ('cities', 'NNS'),
#   ('close', 'RB'),
#   ('sea', 'VBP'),
#   ('The', 'DT'),
#   ('research', 'NN'),
#   ('used', 'VBN'),
#   ('data', 'NNS'),
#   ('Health', 'NNP'),
#   ('Survey', 'NNP'),
#   ('England', 'NNP'),
#   ('compared', 'VBN'),
#   ('people', 'NNS'),
#   ("'s", 'POS'),
#   ('health', 'NN'),
#   ('proximity', 'NN'),
#   ('coast', 'NN'),
#   ('Researchers', 'NNP'),
#   ('say', 'VBP'),
#   ('findings', 'NNS'),
#   ('add', 'VBP'),
#   ('growing', 'VBG'),
#   ('evidence', 'NN'),
#   ('access', 'NN'),
#   ('blue', 'JJ'),
#   ('spaces-particularly', 'JJ'),
#   ('coastal', 'JJ'),
#   ('environments-might', 'JJ'),
#   ('improve', 'NN'),
#   ('health', 'NN'),
#   ('wellbeing', 'VBG'),
#   ('Dr', 'NNP'),
#   ('Jo', 'NNP'),
#   ('Garrett', 'NNP'),
#   ('led', 'VBD'),
#   ('study', 'NN'),
#   ('said', 'VBD'),
#   ("'Our", 'POS'),
#   ('research', 'NN'),
#   ('suggests', 'VBZ'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('people', 'NNS'),
#   ('poorer', 'VBP'),
#   ('households', 'NNS'),
#   ('living', 'VBG'),
#   ('close', 'JJ'),
#   ('coast', 'JJ'),
#   ('experience', 'NN'),
#   ('fewer', 'JJR'),
#   ('symptoms', 'NNS'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('disorders', 'NNS'),
#   ('When', 'WRB'),
#   ('comes', 'VBZ'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ("'protective", 'CD'),
#   ('zone', 'NN'),
#   ('could', 'MD'),
#   ('play', 'VB'),
#   ('useful', 'JJ'),
#   ('role', 'NN'),
#   ('helping', 'VBG'),
#   ('level', 'JJ'),
#   ('playing', 'VBG'),
#   ('field', 'NN'),
#   ('high', 'JJ'),
#   ('low', 'JJ'),
#   ('income', 'NN'),
#   ('Dr', 'NNP'),
#   ('Mathew', 'NNP'),
#   ('White', 'NNP'),
#   ('environmental', 'JJ'),
#   ('psychologist', 'NN'),
#   ('University', 'NNP'),
#   ('Exeter', 'NNP'),
#   ('said', 'VBD'),
#   ("'This", 'POS'),
#   ('kind', 'NN'),
#   ('research', 'NN'),
#   ('blue', 'NN'),
#   ('health', 'NN'),
#   ('vital', 'JJ'),
#   ('convincing', 'NN'),
#   ('governments', 'NNS'),
#   ('protect', 'VBP'),
#   ('create', 'NN'),
#   ('encourage', 'NN'),
#   ('use', 'NN'),
#   ('coastal', 'JJ'),
#   ('spaces', 'NNS'),
#   ("'We", 'POS'),
#   ('need', 'NN'),
#   ('help', 'NN'),
#   ('policy', 'NN'),
#   ('makers', 'NNS'),
#   ('understand', 'VBP'),
#   ('maximise', 'NN'),
#   ('wellbeing', 'VBG'),
#   ('benefits', 'NNS'),
#   ("'blue", 'JJ'),
#   ('spaces', 'NNS'),
#   ('towns', 'JJ'),
#   ('cities', 'NNS'),
#   ('ensure', 'VB'),
#   ('access', 'NN'),
#   ('fair', 'JJ'),
#   ('inclusive', 'JJ'),
#   ('everyone', 'NN'),
#   ('damaging', 'VBG'),
#   ('fragile', 'JJ'),
#   ('coastal', 'JJ'),
#   ('environments', 'NNS')],
#  [('The', 'DT'),
#   ('number', 'NN'),
#   ('years', 'NNS'),
#   ('someone', 'NN'),
#   ('spends', 'VBZ'),
#   ('behind', 'IN'),
#   ('bars', 'NNS'),
#   ('hinge', 'VBP'),
#   ('whether', 'IN'),
#   ('clearly', 'RB'),
#   ('aware', 'JJ'),
#   ('committing', 'VBG'),
#   ('crime', 'NN'),
#   ('But', 'CC'),
#   ('judge', 'NN'),
#   ('jury', 'NN'),
#   ('know', 'VBP'),
#   ('sure', 'RB'),
#   ('A', 'NNP'),
#   ('new', 'JJ'),
#   ('study', 'NN'),
#   ('suggests', 'VBZ'),
#   ('brain', 'NN'),
#   ('scans', 'NNS'),
#   ('distinguish', 'JJ'),
#   ('hardcore', 'VBP'),
#   ('criminal', 'JJ'),
#   ('intent', 'NN'),
#   ('simple', 'JJ'),
#   ('reckless', 'JJ'),
#   ('behavior', 'NN'),
#   ('approach', 'NN'),
#   ('far', 'RB'),
#   ('ready', 'JJ'),
#   ('courtroom', 'NN'),
#   ('The', 'DT'),
#   ('study', 'NN'),
#   ('unusual', 'JJ'),
#   ('looks', 'VBZ'),
#   ('directly', 'RB'),
#   ('brains', 'VBZ'),
#   ('people', 'NNS'),
#   ('engaged', 'VBD'),
#   ('illicit', 'JJ'),
#   ('activity', 'NN'),
#   ('says', 'VBZ'),
#   ('Liane', 'NNP'),
#   ('Young', 'NNP'),
#   ('Boston', 'NNP'),
#   ('College', 'NNP'),
#   ('psychologist', 'NN'),
#   ('involved', 'JJ'),
#   ('work', 'NN'),
#   ('Earlier', 'NNP'),
#   ('research', 'NN'),
#   ('including', 'VBG'),
#   ('work', 'NN'),
#   ('instead', 'RB'),
#   ('generally', 'RB'),
#   ('looked', 'JJ'),
#   ('brains', 'NNS'),
#   ('people', 'NNS'),
#   ('observing', 'VBG'),
#   ('immoral', 'JJ'),
#   ('activity', 'NN'),
#   ('Researchers', 'NNP'),
#   ('led', 'VBD'),
#   ('Read', 'NNP'),
#   ('Montague', 'NNP'),
#   ('neuroscientist', 'JJ'),
#   ('Virginia', 'NNP'),
#   ('Tech', 'NNP'),
#   ('Carilion', 'NNP'),
#   ('Research', 'NNP'),
#   ('Insitute', 'NNP'),
#   ('Roanoke', 'NNP'),
#   ('University', 'NNP'),
#   ('College', 'NNP'),
#   ('London', 'NNP'),
#   ('used', 'VBD'),
#   ('functional', 'JJ'),
#   ('magnetic', 'JJ'),
#   ('resonance', 'NN'),
#   ('imaging', 'NN'),
#   ('fMRI', 'JJ'),
#   ('measure', 'NN'),
#   ('brain', 'NN'),
#   ('activity', 'NN'),
#   ('based', 'VBN'),
#   ('blood', 'NN'),
#   ('flow', 'NN'),
#   ('They', 'PRP'),
#   ('analyzed', 'VBD'),
#   ('brains', 'NNS'),
#   ('40', 'CD'),
#   ('people-a', 'JJ'),
#   ('mix', 'NN'),
#   ('men', 'NNS'),
#   ('women', 'NNS'),
#   ('mostly', 'RB'),
#   ('20s', 'CD'),
#   ('30s-as', 'JJ'),
#   ('went', 'VBD'),
#   ('scenarios', 'NNS'),
#   ('simulated', 'VBN'),
#   ('trying', 'VBG'),
#   ('smuggle', 'NN'),
#   ('something', 'NN'),
#   ('security', 'NN'),
#   ('checkpoint', 'NN'),
#   ('In', 'IN'),
#   ('cases', 'NNS'),
#   ('people', 'NNS'),
#   ('knew', 'VBD'),
#   ('certain', 'JJ'),
#   ('contraband', 'NN'),
#   ('suitcase', 'NN'),
#   ('In', 'IN'),
#   ('cases', 'NNS'),
#   ('chose', 'VBP'),
#   ('two', 'CD'),
#   ('five', 'CD'),
#   ('suitcases', 'NNS'),
#   ('one', 'CD'),
#   ('containing', 'VBG'),
#   ('contraband', 'NN'),
#   ('thus', 'RB'),
#   ("n't", 'RB'),
#   ('sure', 'JJ'),
#   ('carrying', 'VBG'),
#   ('contraband', 'NN'),
#   ('The', 'DT'),
#   ('risk', 'NN'),
#   ('getting', 'VBG'),
#   ('caught', 'VBN'),
#   ('also', 'RB'),
#   ('varied', 'VBD'),
#   ('based', 'VBN'),
#   ('many', 'JJ'),
#   ('10', 'CD'),
#   ('security', 'NN'),
#   ('checkpoints', 'NNS'),
#   ('guard', 'NN'),
#   ('stationed', 'VBD'),
#   ('The', 'DT'),
#   ('results', 'NNS'),
#   ('showed', 'VBD'),
#   ('distinctive', 'JJ'),
#   ('patterns', 'NNS'),
#   ('brain', 'NN'),
#   ('activity', 'NN'),
#   ('person', 'NN'),
#   ('knew', 'VBD'),
#   ('certain', 'JJ'),
#   ('suitcase', 'NN'),
#   ('contraband', 'NN'),
#   ('knew', 'VBD'),
#   ('chance', 'NN'),
#   ('team', 'NN'),
#   ('reports', 'NNS'),
#   ('today', 'NN'),
#   ('Proceedings', 'NNPS'),
#   ('National', 'NNP'),
#   ('Academy', 'NNP'),
#   ('Sciences', 'NNPS'),
#   ('But', 'CC'),
#   ('unexpected', 'JJ'),
#   ('twist', 'NN'),
#   ('Those', 'DT'),
#   ('differing', 'VBG'),
#   ('brain', 'NN'),
#   ('patterns', 'NNS'),
#   ('showed', 'VBD'),
#   ('people', 'NNS'),
#   ('first', 'RB'),
#   ('shown', 'VBN'),
#   ('many', 'JJ'),
#   ('security', 'NN'),
#   ('checkpoints', 'NNS'),
#   ('guarded', 'VBD'),
#   ('offered', 'VBN'),
#   ('suitcases', 'NNS'),
#   ('In', 'IN'),
#   ('case', 'NN'),
#   ('computer', 'NN'),
#   ('analysis', 'NN'),
#   ('fMRI', 'NN'),
#   ('images', 'NNS'),
#   ('correctly', 'RB'),
#   ('classified', 'VBD'),
#   ('people', 'NNS'),
#   ('knowing', 'VBG'),
#   ('reckless', 'JJ'),
#   ('71', 'CD'),
#   ('80', 'CD'),
#   ('time', 'NN'),
#   ('Montague', 'NNP'),
#   ("n't", 'RB'),
#   ('sure', 'JJ'),
#   ('results', 'NNS'),
#   ('hinged', 'VBD'),
#   ('order', 'NN'),
#   ('scenario', 'NN'),
#   ('unfolded', 'VBD'),
#   ('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('possible', 'JJ'),
#   ('threshold', 'JJ'),
#   ('amount', 'NN'),
#   ('information', 'NN'),
#   ('brain', 'NN'),
#   ('needed', 'VBD'),
#   ('distinctive', 'JJ'),
#   ('thought', 'NN'),
#   ('process', 'NN'),
#   ('connected', 'VBD'),
#   ('recklessness', 'NN'),
#   ('kicked', 'VBD'),
#   ('says', 'VBZ'),
#   ('In', 'IN'),
#   ('laboratory', 'NN'),
#   ('says', 'VBZ'),
#   ('perhaps', 'RB'),
#   ('information', 'NN'),
#   ('risk', 'NN'),
#   ('grabbing', 'VBG'),
#   ("'hot", 'JJ'),
#   ('suitcase', 'NN'),
#   ('encountering', 'VBG'),
#   ('security', 'NN'),
#   ('guard', 'NN'),
#   ("'had", 'NNP'),
#   ('board', 'NN'),
#   ('could', 'MD'),
#   ('see', 'VB'),
#   ('difference', 'NN'),
#   ("'I", 'CD'),
#   ('see', 'NN'),
#   ('proof', 'JJ'),
#   ('principle', 'NN'),
#   ('raises', 'VBZ'),
#   ('questions', 'NNS'),
#   ('answers', 'NNS'),
#   ('says', 'VBZ'),
#   ('Montague', 'NNP'),
#   ('notes', 'NNS'),
#   ('team', 'RB'),
#   ('repeated', 'VBD'),
#   ('experiment', 'JJ'),
#   ('several', 'JJ'),
#   ('times', 'NNS'),
#   ('results', 'NNS'),
#   ('The', 'DT'),
#   ('lawyers', 'NNS'),
#   ('working', 'VBG'),
#   ('study', 'NN'),
#   ('recoiled', 'VBD'),
#   ('idea', 'NN'),
#   ('results', 'NNS'),
#   ('depended', 'VBD'),
#   ('sequencing', 'JJ'),
#   ('events', 'NNS'),
#   ('people', 'NNS'),
#   ('engaged', 'VBD'),
#   ('risky', 'JJ'),
#   ('behavior', 'JJ'),
#   ('matter', 'NN'),
#   ('order', 'NN'),
#   ("'I", 'POS'),
#   ("'m", 'VBP'),
#   ('scientist', 'JJ'),
#   ('I', 'PRP'),
#   ('like', 'IN'),
#   ("'This", "''"),
#   ('interesting', 'JJ'),
#   ('part', 'NN'),
#   ("'ve", 'VBP'),
#   ('found', 'VBN'),
#   ('We', 'PRP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ("''", "''"),
#   ('Montague', 'NNP'),
#   ('says', 'VBZ'),
#   ('But', 'CC'),
#   ('another', 'DT'),
#   ('researcher', 'NN'),
#   ('used', 'VBN'),
#   ('brain', 'NN'),
#   ('imaging', 'VBG'),
#   ('study', 'JJ'),
#   ('criminal', 'JJ'),
#   ('behavior', 'NN'),
#   ('questioned', 'VBD'),
#   ('whether', 'IN'),
#   ('differences', 'NNS'),
#   ('found', 'VBN'),
#   ('study', 'VBP'),
#   ('really', 'RB'),
#   ('revealed', 'VBN'),
#   ('meaningful', 'JJ'),
#   ('difference', 'NN'),
#   ('two', 'CD'),
#   ('mental', 'JJ'),
#   ('states', 'NNS'),
#   ('Ruben', 'NNP'),
#   ('Gur', 'NNP'),
#   ('psychologist', 'NN'),
#   ('director', 'NN'),
#   ('Brain', 'NNP'),
#   ('Behavior', 'NNP'),
#   ('Laboratory', 'NNP'),
#   ('University', 'NNP'),
#   ('Pennsylvania', 'NNP'),
#   ("'s", 'POS'),
#   ('medical', 'JJ'),
#   ('school', 'NN'),
#   ('says', 'VBZ'),
#   ('40', 'CD'),
#   ('participants', 'NNS'),
#   ('study', 'NN'),
#   ('may', 'MD'),
#   ('able', 'JJ'),
#   ('account', 'NN'),
#   ('variables', 'NNS'),
#   ('play', 'VBP'),
#   ('brain', 'NN'),
#   ('scans', 'NNS'),
#   ("'To", 'POS'),
#   ('proves', 'NNS'),
#   ('apply', 'VBP'),
#   ('statistical', 'JJ'),
#   ('method', 'NN'),
#   ('small', 'JJ'),
#   ('samples', 'NNS'),
#   ('come', 'VBP'),
#   ('interesting', 'JJ'),
#   ('results', 'NNS'),
#   ('make', 'VBP'),
#   ('less', 'JJR'),
#   ('sense', 'NN'),
#   ('Study', 'NNP'),
#   ('author', 'NN'),
#   ('Gideon', 'NNP'),
#   ('Yaffe', 'NNP'),
#   ('philosopher', 'CC'),
#   ('Yale', 'NNP'),
#   ('Law', 'NNP'),
#   ('School', 'NNP'),
#   ('notes', 'NNS'),
#   ('limitations', 'NNS'),
#   ('research', 'NN'),
#   ('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('known', 'VBN'),
#   ('whether', 'IN'),
#   ('different', 'JJ'),
#   ('brain', 'NN'),
#   ('patterns', 'NNS'),
#   ('confined', 'VBD'),
#   ('specific', 'JJ'),
#   ('scenario', 'NN'),
#   ('would', 'MD'),
#   ('apply', 'VB'),
#   ('broadly', 'RB'),
#   ('situations', 'NNS'),
#   ('outside', 'IN'),
#   ('lab', 'NN'),
#   ('says', 'VBZ'),
#   ('And', 'CC'),
#   ('cautions', 'NNS'),
#   ("'s", 'POS'),
#   ('big', 'JJ'),
#   ('leap', 'NN'),
#   ('visions', 'NNS'),
#   ("'evil", 'POS'),
#   ('intent', 'NN'),
#   ('detectors', 'NNS'),
#   ('scanning', 'VBG'),
#   ('people', 'NNS'),
#   ("'s", 'POS'),
#   ('brains', 'NNS'),
#   ("'It", 'POS'),
#   ('hard', 'JJ'),
#   ('modest', 'JJ'),
#   ('thing', 'NN'),
#   ('feels', 'NNS'),
#   ('far', 'RB'),
#   ('away', 'RB'),
#   ('able', 'JJ'),
#   ('something', 'NN'),
#   ('grand', 'JJ'),
#   ('A', 'NNP'),
#   ('relevant', 'NN'),
#   ('scenario', 'NN'),
#   ('might', 'MD'),
#   ('looking', 'VBG'),
#   ('whether', 'IN'),
#   ('brains', 'NNS'),
#   ('people', 'NNS'),
#   ('certain', 'JJ'),
#   ('conditions', 'NNS'),
#   ('drug', 'NN'),
#   ('addiction', 'NN'),
#   ('process', 'NN'),
#   ('risk', 'NN'),
#   ('differently', 'RB'),
#   ('That', 'IN'),
#   ('research', 'NN'),
#   ('Yaffe', 'NNP'),
#   ('says', 'VBZ'),
#   ('might', 'MD'),
#   ('introduced', 'VB'),
#   ('court', 'NN'),
#   ('people', 'NNS'),
#   ('wrestle', 'VBP'),
#   ('much', 'JJ'),
#   ('someone', 'NN'),
#   ('really', 'RB'),
#   ('knew', 'VBD'),
#   ('committed', 'VBN'),
#   ('crime', 'NN')],
#  [('A', 'DT'),
#   ('computer', 'NN'),
#   ('better', 'RBR'),
#   ('human', 'JJ'),
#   ('dermatologists', 'NNS'),
#   ('detecting', 'VBG'),
#   ('skin', 'NN'),
#   ('cancer', 'NN'),
#   ('study', 'NN'),
#   ('pitted', 'VBD'),
#   ('people', 'NNS'),
#   ('machines', 'NNS'),
#   ('quest', 'RB'),
#   ('better', 'RB'),
#   ('faster', 'RBR'),
#   ('diagnostics', 'NNS'),
#   ('researchers', 'NNS'),
#   ('said', 'VBD'),
#   ('Tuesday', 'NNP'),
#   ('A', 'NNP'),
#   ('team', 'NN'),
#   ('Germany', 'NNP'),
#   ('United', 'NNP'),
#   ('States', 'NNPS'),
#   ('France', 'NNP'),
#   ('taught', 'VBD'),
#   ('artificial', 'JJ'),
#   ('intelligence', 'NN'),
#   ('system', 'NN'),
#   ('distinguish', 'JJ'),
#   ('dangerous', 'JJ'),
#   ('skin', 'NN'),
#   ('lesions', 'NNS'),
#   ('benign', 'JJ'),
#   ('ones', 'NNS'),
#   ('showing', 'VBG'),
#   ('100,000', 'CD'),
#   ('images', 'NNS'),
#   ('The', 'DT'),
#   ('machine', 'NN'),
#   ('deep', 'JJ'),
#   ('learning', 'JJ'),
#   ('convolutional', 'JJ'),
#   ('neural', 'JJ'),
#   ('network', 'NN'),
#   ('CNN', 'NNP'),
#   ('tested', 'VBD'),
#   ('58', 'CD'),
#   ('dermatologists', 'NNS'),
#   ('17', 'CD'),
#   ('countries', 'NNS'),
#   ('shown', 'VBN'),
#   ('photos', 'NNS'),
#   ('malignant', 'JJ'),
#   ('melanomas', 'NN'),
#   ('benign', 'NN'),
#   ('moles', 'NNS'),
#   ('Just', 'NNP'),
#   ('half', 'NN'),
#   ('dermatologists', 'NNS'),
#   ('expert', 'VBP'),
#   ('level', 'JJ'),
#   ('five', 'CD'),
#   ('years', 'NNS'),
#   ('experience', 'RB'),
#   ('19', 'CD'),
#   ('two', 'CD'),
#   ('five', 'CD'),
#   ('years', 'NNS'),
#   ('experience', 'RB'),
#   ('29', 'CD'),
#   ('beginners', 'NNS'),
#   ('less', 'RBR'),
#   ('two', 'CD'),
#   ('years', 'NNS'),
#   ('belt', 'VBD'),
#   ("'Most", 'JJS'),
#   ('dermatologists', 'NNS'),
#   ('outperformed', 'VBD'),
#   ('CNN', 'NNP'),
#   ('research', 'NN'),
#   ('team', 'NN'),
#   ('wrote', 'VBD'),
#   ('paper', 'NN'),
#   ('published', 'VBN'),
#   ('journal', 'JJ'),
#   ('Annals', 'NNP'),
#   ('Oncology', 'NNP'),
#   ('On', 'IN'),
#   ('average', 'JJ'),
#   ('human', 'JJ'),
#   ('dermatologists', 'VBZ'),
#   ('accurately', 'RB'),
#   ('detected', 'JJ'),
#   ('86.6', 'CD'),
#   ('skin', 'NN'),
#   ('cancers', 'NNS'),
#   ('images', 'NNS'),
#   ('compared', 'VBN'),
#   ('95', 'CD'),
#   ('CNN', 'NNP'),
#   ("'The", 'POS'),
#   ('CNN', 'NNP'),
#   ('missed', 'VBD'),
#   ('fewer', 'JJR'),
#   ('melanomas', 'NN'),
#   ('meaning', 'NN'),
#   ('higher', 'JJR'),
#   ('sensitivity', 'NN'),
#   ('dermatologists', 'VBZ'),
#   ('study', 'NN'),
#   ("'s", 'POS'),
#   ('first', 'JJ'),
#   ('author', 'NN'),
#   ('Holger', 'NNP'),
#   ('Haenssle', 'NNP'),
#   ('University', 'NNP'),
#   ('Heidelberg', 'NNP'),
#   ('said', 'VBD'),
#   ('statement', 'NN'),
#   ('It', 'PRP'),
#   ('also', 'RB'),
#   ("'misdiagnosed", 'VBD'),
#   ('fewer', 'JJR'),
#   ('benign', 'NN'),
#   ('moles', 'NNS'),
#   ('malignant', 'JJ'),
#   ('melanoma', 'NN'),
#   ('...', ':'),
#   ('would', 'MD'),
#   ('result', 'VB'),
#   ('less', 'JJR'),
#   ('unnecessary', 'JJ'),
#   ('surgery', 'NN'),
#   ('The', 'DT'),
#   ('dermatologists', 'NNS'),
#   ('performance', 'NN'),
#   ('improved', 'VBD'),
#   ('given', 'VBN'),
#   ('information', 'NN'),
#   ('patients', 'NNS'),
#   ('skin', 'JJ'),
#   ('lesions', 'NNS'),
#   ('The', 'DT'),
#   ('team', 'NN'),
#   ('said', 'VBD'),
#   ('AI', 'NNP'),
#   ('may', 'MD'),
#   ('useful', 'JJ'),
#   ('tool', 'NN'),
#   ('faster', 'RBR'),
#   ('easier', 'JJR'),
#   ('diagnosis', 'NN'),
#   ('skin', 'NN'),
#   ('cancer', 'NN'),
#   ('allowing', 'VBG'),
#   ('surgical', 'JJ'),
#   ('removal', 'NN'),
#   ('spreads', 'NNS'),
#   ('There', 'EX'),
#   ('232,000', 'CD'),
#   ('new', 'JJ'),
#   ('cases', 'NNS'),
#   ('melanoma', 'VBP'),
#   ('55,500', 'CD'),
#   ('deaths', 'NNS'),
#   ('world', 'NN'),
#   ('year', 'NN'),
#   ('added', 'VBD'),
#   ('Melanoma', 'NNP'),
#   ('parts', 'NNS'),
#   ('body', 'NN'),
#   ('fingers', 'NNS'),
#   ('toes', 'VBP'),
#   ('scalp', 'RB'),
#   ('difficult', 'JJ'),
#   ('image', 'NN'),
#   ('AI', 'NNP'),
#   ('may', 'MD'),
#   ('difficulty', 'VB'),
#   ('recognising', 'VBG'),
#   ('atypical', 'JJ'),
#   ('lesions', 'NNS'),
#   ('ones', 'NNS'),
#   ('patients', 'NNS'),
#   ('unaware', 'JJ'),
#   ('Currently', 'NNP'),
#   ('substitute', 'VBP'),
#   ('thorough', 'JJ'),
#   ('clinical', 'JJ'),
#   ('examination', 'NN'),
#   ('experts', 'NNS'),
#   ('Victoria', 'NNP'),
#   ('Mar', 'NNP'),
#   ('Monash', 'NNP'),
#   ('University', 'NNP'),
#   ('Melbourne', 'NNP'),
#   ('Peter', 'NNP'),
#   ('Soyer', 'NNP'),
#   ('University', 'NNP'),
#   ('Queensland', 'NNP'),
#   ('wrote', 'VBD'),
#   ('editorial', 'NN'),
#   ('published', 'VBN'),
#   ('study', 'NN')],
#  [('US', 'JJ'),
#   ('economic', 'JJ'),
#   ('growth', 'NN'),
#   ('surged', 'VBD'),
#   ('first', 'RB'),
#   ('three', 'CD'),
#   ('months', 'NNS'),
#   ('year', 'NN'),
#   ('3.2', 'CD'),
#   ('threat', 'NN'),
#   ('trade', 'NN'),
#   ('war', 'NN'),
#   ('China', 'NNP'),
#   ('forced', 'VBD'),
#   ('businesses', 'NNS'),
#   ('stockpile', 'JJ'),
#   ('fastest', 'JJS'),
#   ('rate', 'NN'),
#   ('since', 'IN'),
#   ('2015', 'CD'),
#   ('Figures', 'NNP'),
#   ('Department', 'NNP'),
#   ('Commerce', 'NNP'),
#   ('showed', 'VBD'),
#   ('jump', 'NN'),
#   ('hoarding', 'VBG'),
#   ('raw', 'JJ'),
#   ('materials', 'NNS'),
#   ('finished', 'VBD'),
#   ('goods', 'NNS'),
#   ('increase', 'VB'),
#   ('government', 'NN'),
#   ('investment', 'NN'),
#   ('overcame', 'NN'),
#   ('weak', 'JJ'),
#   ('consumer', 'NN'),
#   ('spending', 'NN'),
#   ('drop', 'NN'),
#   ('housebuilding', 'VBG'),
#   ('low', 'JJ'),
#   ('business', 'NN'),
#   ('investment', 'NN'),
#   ('send', 'NN'),
#   ('GDP', 'NNP'),
#   ('growth', 'NN'),
#   ('well', 'RB'),
#   ('ahead', 'RB'),
#   ('2.2', 'CD'),
#   ('last', 'JJ'),
#   ('quarter', 'NN'),
#   ('2018', 'CD'),
#   ('Exports', 'NNP'),
#   ('proved', 'VBD'),
#   ('volatile', 'JJ'),
#   ('recent', 'JJ'),
#   ('quarters', 'NNS'),
#   ('response', 'NN'),
#   ('threats', 'NNS'),
#   ('trade', 'VBP'),
#   ('war', 'NN'),
#   ('US', 'NNP'),
#   ('China', 'NNP'),
#   ('surged', 'VBD'),
#   ('imports', 'NNS'),
#   ('declined', 'VBD'),
#   ('add', 'RB'),
#   ('1.03', 'CD'),
#   ('percentage', 'NN'),
#   ('points', 'NNS'),
#   ('GDP', 'NNP'),
#   ('neutral', 'JJ'),
#   ('fourth', 'JJ'),
#   ('quarter', 'NN'),
#   ('The', 'DT'),
#   ('improvement', 'NN'),
#   ('dispelled', 'VBD'),
#   ('concerns', 'NNS'),
#   ('US', 'NNP'),
#   ('economy', 'NN'),
#   ('heading', 'VBG'),
#   ('recession', 'NN'),
#   ('early', 'RB'),
#   ('summer', 'NN'),
#   ('analysts', 'NNS'),
#   ('feared', 'VBD'),
#   ('slowdown', 'NN'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('But', 'CC'),
#   ('analysts', 'NNS'),
#   ('said', 'VBD'),
#   ('Federal', 'NNP'),
#   ('Reserve', 'NNP'),
#   ('put', 'VBD'),
#   ('interest', 'NN'),
#   ('rate', 'NN'),
#   ('hikes', 'NNS'),
#   ('hold', 'VBP'),
#   ('unlikely', 'JJ'),
#   ('view', 'NN'),
#   ('figures', 'NNS'),
#   ('beginning', 'VBG'),
#   ('economic', 'JJ'),
#   ('boom', 'NN'),
#   ('reverse', 'NN'),
#   ('current', 'JJ'),
#   ('policy', 'NN'),
#   ('In', 'IN'),
#   ('January', 'NNP'),
#   ('US', 'NNP'),
#   ('central', 'JJ'),
#   ('bank', 'NN'),
#   ('suspended', 'VBD'),
#   ('three-year', 'JJ'),
#   ('push', 'NN'),
#   ('tighten', 'JJ'),
#   ('monetary', 'JJ'),
#   ('policy', 'NN'),
#   ('saying', 'VBG'),
#   ('would', 'MD'),
#   ('pause', 'VB'),
#   ('rate', 'NN'),
#   ('hikes', 'NNS'),
#   ('year', 'NN'),
#   ('The', 'DT'),
#   ('Fed', 'NNP'),
#   ('increased', 'VBD'),
#   ('borrowing', 'NN'),
#   ('costs', 'NNS'),
#   ('four', 'CD'),
#   ('times', 'NNS'),
#   ('range', 'VBP'),
#   ('2.25', 'CD'),
#   ('2.5', 'CD'),
#   ('2018', 'CD'),
#   ('well', 'RB'),
#   ('level', 'JJ'),
#   ('base', 'NN'),
#   ('rates', 'NNS'),
#   ('major', 'JJ'),
#   ('economies', 'NNS'),
#   ('The', 'DT'),
#   ('central', 'JJ'),
#   ('bank', 'NN'),
#   ('likely', 'JJ'),
#   ('focus', 'JJ'),
#   ('measure', 'NN'),
#   ('domestic', 'JJ'),
#   ('demand', 'NN'),
#   ('increased', 'VBD'),
#   ('1.3', 'CD'),
#   ('slowest', 'JJS'),
#   ('since', 'IN'),
#   ('second', 'JJ'),
#   ('quarter', 'NN'),
#   ('2013', 'CD'),
#   ('increasing', 'VBG'),
#   ('2.6', 'CD'),
#   ('last', 'JJ'),
#   ('quarter', 'NN'),
#   ('Growth', 'NNP'),
#   ('consumer', 'NN'),
#   ('spending', 'NN'),
#   ('accounts', 'NNS'),
#   ('two-thirds', 'NNS'),
#   ('US', 'NNP'),
#   ('economic', 'JJ'),
#   ('activity', 'NN'),
#   ('also', 'RB'),
#   ('weak', 'JJ'),
#   ('growing', 'VBG'),
#   ('1.2', 'CD'),
#   ('previous', 'JJ'),
#   ('2.5', 'CD'),
#   ('Business', 'NNP'),
#   ('investment', 'NN'),
#   ('slowed', 'VBD'),
#   ('sharply', 'RB'),
#   ('rising', 'VBG'),
#   ('0.2', 'CD'),
#   ('rate', 'NN'),
#   ('slowest', 'NN'),
#   ('since', 'IN'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   ('2016', 'CD'),
#   ('Reports', 'NNP'),
#   ('China', 'NNP'),
#   ('show', 'VBP'),
#   ('world', 'NN'),
#   ("'s", 'POS'),
#   ('second', 'JJ'),
#   ('largest', 'JJS'),
#   ('economy', 'NN'),
#   ('arrested', 'VBN'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ("'s", 'POS'),
#   ('decline', 'NN'),
#   ('though', 'IN'),
#   ('many', 'JJ'),
#   ('analysts', 'NNS'),
#   ('believe', 'VBP'),
#   ('better', 'JJR'),
#   ('outlook', 'NN'),
#   ('prove', 'VBP'),
#   ('temporary', 'JJ'),
#   ('growth', 'NN'),
#   ('lower', 'RBR'),
#   ('year', 'NN'),
#   ('2018', 'CD'),
#   ('European', 'JJ'),
#   ('manufacturing', 'NN'),
#   ('slumped', 'VBD'),
#   ('recent', 'JJ'),
#   ('months', 'NNS'),
#   ('Japanese', 'JJ'),
#   ('output', 'NN'),
#   ('slowed', 'VBD'),
#   ('marking', 'VBG'),
#   ('US', 'NNP'),
#   ('major', 'JJ'),
#   ('economy', 'NN'),
#   ('maintaining', 'VBG'),
#   ('high', 'JJ'),
#   ('levels', 'NNS'),
#   ('output', 'NN'),
#   ('growth', 'NN'),
#   ('The', 'DT'),
#   ('effect', 'NN'),
#   ('stockpiling', 'VBG'),
#   ('US', 'NNP'),
#   ('also', 'RB'),
#   ('buoyed', 'VBD'),
#   ('activity', 'NN'),
#   ('UK', 'NNP'),
#   ('uncertainty', 'NN'),
#   ('Brexit', 'NNP'),
#   ('negotiations', 'NNS'),
#   ('unnerved', 'VBD'),
#   ('businesses', 'NNS'),
#   ('encouraged', 'VBD'),
#   ('hoard', 'JJ'),
#   ('raw', 'JJ'),
#   ('materials', 'NNS'),
#   ('In', 'IN'),
#   ('April', 'NNP'),
#   ('British', 'NNP'),
#   ('factories', 'NNS'),
#   ('stockpiled', 'VBD'),
#   ('fastest', 'JJS'),
#   ('pace', 'NN'),
#   ('since', 'IN'),
#   ('records', 'NNS'),
#   ('began', 'VBD'),
#   ('1950s', 'CD'),
#   ('amid', 'IN'),
#   ('reports', 'NNS'),
#   ('increasingly', 'RB'),
#   ('downbeat', 'VBP'),
#   ('prospects', 'NNS'),
#   ('A', 'NNP'),
#   ('survey', 'NN'),
#   ('Confederation', 'NNP'),
#   ('British', 'NNP'),
#   ('Industry', 'NNP'),
#   ('found', 'VBD'),
#   ('expectations', 'NNS'),
#   ('export', 'NN'),
#   ('orders', 'NNS'),
#   ('next', 'IN'),
#   ('three', 'CD'),
#   ('months', 'NNS'),
#   ('fell', 'VBD'),
#   ('lowest', 'JJS'),
#   ('level', 'NN'),
#   ('since', 'IN'),
#   ('mid-2009', 'NN')],
#  [('Microsoft', 'NNP'),
#   ('become', 'JJ'),
#   ('third', 'JJ'),
#   ('publicly', 'RB'),
#   ('listed', 'VBN'),
#   ('US', 'NNP'),
#   ('company', 'NN'),
#   ('Apple', 'NNP'),
#   ('Amazon', 'NNP'),
#   ('boast', 'NN'),
#   ('market', 'NN'),
#   ('value', 'NN'),
#   ('1tn', 'CD'),
#   ('bumper', 'JJR'),
#   ('quarterly', 'JJ'),
#   ('results', 'NNS'),
#   ('boosted', 'VBD'),
#   ('share', 'NN'),
#   ('price', 'NN'),
#   ('The', 'DT'),
#   ('company', 'NN'),
#   ('beat', 'VBD'),
#   ('sales', 'NNS'),
#   ('profits', 'NNS'),
#   ('expectations', 'NNS'),
#   ('three', 'CD'),
#   ('months', 'NNS'),
#   ('31', 'CD'),
#   ('March', 'NNP'),
#   ('thanks', 'NNS'),
#   ('part', 'NN'),
#   ('cloud', 'VBP'),
#   ('computing', 'VBG'),
#   ('business', 'NN'),
#   ('signed', 'VBD'),
#   ('major', 'JJ'),
#   ('corporate', 'JJ'),
#   ('clients', 'NNS'),
#   ('period', 'NN'),
#   ('Microsoft', 'NNP'),
#   ('shares', 'NNS'),
#   ('rose', 'VBD'),
#   ('much', 'RB'),
#   ('5', 'CD'),
#   ('early', 'JJ'),
#   ('trading', 'NN'),
#   ('Thursday', 'NNP'),
#   ('briefly', 'VBZ'),
#   ('pushing', 'VBG'),
#   ('market', 'NN'),
#   ('value', 'NN'),
#   ('1tn', 'CD'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('dipping', 'VBG'),
#   ('back', 'RB'),
#   ('shares', 'NNS'),
#   ('price', 'NN'),
#   ('gain', 'NN'),
#   ('eased', 'VBD'),
#   ('It', 'PRP'),
#   ('latest', 'JJS'),
#   ('tech', 'JJ'),
#   ('firm', 'NN'),
#   ('join', 'NN'),
#   ('prestigious', 'JJ'),
#   ('club', 'NN'),
#   ('rival', 'NN'),
#   ('Apple', 'NNP'),
#   ('Amazon', 'NNP'),
#   ('topped', 'VBD'),
#   ('1tn', 'CD'),
#   ('mark', 'NN'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('Since', 'IN'),
#   ('shares', 'NNS'),
#   ('companies', 'NNS'),
#   ('fallen', 'VBN'),
#   ('back', 'RB'),
#   ('Microsoft', 'NNP'),
#   ('biggest', 'JJS'),
#   ('market', 'NN'),
#   ('capitalisation', 'NN'),
#   ('US', 'NNP'),
#   ('stock', 'NN'),
#   ('market', 'NN'),
#   ('listed', 'VBD'),
#   ('company', 'NN'),
#   ('Shares', 'NNP'),
#   ('Facebook', 'NNP'),
#   ('also', 'RB'),
#   ('trading', 'VBG'),
#   ('higher', 'JJR'),
#   ('6', 'CD'),
#   ('easily', 'RB'),
#   ('beat', 'JJ'),
#   ('forecasts', 'NNS'),
#   ('26', 'CD'),
#   ('jump', 'NNS'),
#   ('quarterly', 'RB'),
#   ('revenues', 'NNS'),
#   ('15bn', 'CD'),
#   ('8', 'CD'),
#   ('rise', 'NN'),
#   ('active', 'JJ'),
#   ('users', 'NNS'),
#   ('The', 'DT'),
#   ('better-than-expected', 'JJ'),
#   ('results', 'NNS'),
#   ('Microsoft', 'NNP'),
#   ('Facebook', 'NNP'),
#   ('helped', 'VBD'),
#   ('push', 'VB'),
#   ('tech-focused', 'JJ'),
#   ('Nasdaq', 'NNP'),
#   ('share', 'NN'),
#   ('index', 'NN'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('8,118', 'CD'),
#   ('points', 'NNS'),
#   ('close', 'RB'),
#   ('The', 'DT'),
#   ('boost', 'NN'),
#   ('Microsoft', 'NNP'),
#   ('came', 'VBD'),
#   ('reported', 'VBD'),
#   ('14', 'CD'),
#   ('increase', 'NN'),
#   ('revenue', 'NN'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   ('30.6bn', 'CD'),
#   ('Net', 'JJ'),
#   ('income', 'NN'),
#   ('rose', 'VBD'),
#   ('19', 'CD'),
#   ('8.8bn', 'CD'),
#   ('Revenues', 'NNS'),
#   ('cloud', 'VBP'),
#   ('computing', 'VBG'),
#   ('division', 'NN'),
#   ('jumped', 'VBD'),
#   ('14', 'CD'),
#   ('US', 'NNP'),
#   ('grocery', 'NN'),
#   ('firm', 'NN'),
#   ('Kroger', 'NNP'),
#   ('Walgreens', 'NNP'),
#   ('Boots', 'NNP'),
#   ('Alliance', 'NNP'),
#   ('among', 'IN'),
#   ('big', 'JJ'),
#   ('client', 'NN'),
#   ('wins', 'VBZ'),
#   ('Satya', 'NNP'),
#   ('Nadella', 'NNP'),
#   ('chief', 'JJ'),
#   ('executive', 'NN'),
#   ('Microsoft', 'NNP'),
#   ('said', 'VBD'),
#   ("'Leading", 'VBG'),
#   ('organisations', 'NNS'),
#   ('every', 'DT'),
#   ('size', 'NN'),
#   ('every', 'DT'),
#   ('industry', 'NN'),
#   ('trust', 'NN'),
#   ('Microsoft', 'NNP'),
#   ('cloud', 'NN'),
#   ('We', 'PRP'),
#   ('accelerating', 'VBG'),
#   ('innovation', 'NN'),
#   ('across', 'IN'),
#   ('cloud', 'NN'),
#   ('edge', 'NN'),
#   ('customers', 'NNS'),
#   ('build', 'VBP'),
#   ('digital', 'JJ'),
#   ('capability', 'NN'),
#   ('increasingly', 'RB'),
#   ('required', 'JJ'),
#   ('compete', 'NN'),
#   ('grow', 'VB'),
#   ('Shares', 'NNP'),
#   ('Microsoft', 'NNP'),
#   ('3.4', 'CD'),
#   ('129', 'CD'),
#   ('close', 'RB'),
#   ('trading', 'VBG'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('giving', 'VBG'),
#   ('market', 'NN'),
#   ('value', 'NN'),
#   ('995bn', 'CD'),
#   ('Apple', 'NNP'),
#   ('worth', 'NN'),
#   ('around', 'RB'),
#   ('970bn', 'CD'),
#   ('Amazon', 'NNP'),
#   ('close', 'RB'),
#   ('behind', 'IN'),
#   ('940bn', 'CD'),
#   ('Brad', 'NNP'),
#   ('Reback', 'NNP'),
#   ('stockbrokers', 'NNS'),
#   ('Stifel', 'NNP'),
#   ('said', 'VBD'),
#   ('Microsoft', 'NNP'),
#   ('bright', 'JJ'),
#   ('future', 'NN'),
#   ("'We", 'POS'),
#   ('continue', 'NN'),
#   ('believe', 'VBP'),
#   ('shift', 'NN'),
#   ('cloud', 'VBP'),
#   ('additive', 'JJ'),
#   ('Microsoft', 'NNP'),
#   ('given', 'VBN'),
#   ('broader', 'JJR'),
#   ('portfolio', 'NN'),
#   ('products', 'NNS'),
#   ('deeper', 'JJR'),
#   ('functionality', 'NN'),
#   ('well', 'RB'),
#   ('Microsoft', 'NNP'),
#   ("'s", 'POS'),
#   ('ability', 'NN'),
#   ('enter', 'RB'),
#   ('new', 'JJ'),
#   ('categories', 'NNS'),
#   ('compete', 'VBP'),
#   ('previously', 'RB'),
#   ('Stifel', 'NNP'),
#   ('raised', 'VBD'),
#   ('price', 'NN'),
#   ('target', 'NN'),
#   ('Microsoft', 'NNP'),
#   ('150', 'CD'),
#   ('130', 'CD'),
#   ('Cloud', 'NNPS'),
#   ('clearly', 'RB'),
#   ('way', 'NN'),
#   ('forward', 'RB'),
#   ('Microsoft', 'NNP'),
#   ('demand', 'NN'),
#   ('services', 'NNS'),
#   ('expected', 'VBD'),
#   ('remain', 'VBP'),
#   ('strong', 'JJ'),
#   ('said', 'VBD'),
#   ('Jasper', 'NNP'),
#   ('Lawler', 'NNP'),
#   ('head', 'NN'),
#   ('research', 'NN'),
#   ('London', 'NNP'),
#   ('Capital', 'NNP'),
#   ('Group', 'NNP')],
#  [('Siri', 'NNP'),
#   ('Apple', 'NNP'),
#   ("'s", 'POS'),
#   ('voice-controlled', 'JJ'),
#   ('virtual', 'JJ'),
#   ('assistant', 'NN'),
#   ('useful', 'JJ'),
#   ('hands-free', 'JJ'),
#   ('texting', 'VBG'),
#   ('dictation', 'NN'),
#   ('pizza', 'NN'),
#   ('place', 'NN'),
#   ('recommendations', 'NNS'),
#   ('turns', 'VBZ'),
#   ('also', 'RB'),
#   ('skilled', 'VBN'),
#   ('rapper', 'NN'),
#   ('Last', 'JJ'),
#   ('month', 'NN'),
#   ('Judith', 'NNP'),
#   ('Newman', 'NNP'),
#   ('wrote', 'VBD'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Times', 'NNP'),
#   ('Siri', 'NNP'),
#   ('befriended', 'VBD'),
#   ('autistic', 'JJ'),
#   ('son', 'NN'),
#   ('seems', 'VBZ'),
#   ('Siri', 'NNP'),
#   ("'s", 'POS'),
#   ('talents', 'NNS'),
#   ('go', 'VB'),
#   ('even', 'RB'),
#   ('London-based', 'JJ'),
#   ('producers', 'NNS'),
#   ('Skeewiff', 'NNP'),
#   ('aka', 'NN'),
#   ('Alex', 'NNP'),
#   ('Rizzo', 'NNP'),
#   ('Elliot', 'NNP'),
#   ('Ireland', 'NNP'),
#   ('uploaded', 'VBD'),
#   ('remix', 'NN'),
#   ('Young', 'NNP'),
#   ('MC', 'NNP'),
#   ("'s", 'POS'),
#   ('Know', 'NNP'),
#   ('How', 'NNP'),
#   ('features', 'VBZ'),
#   ('Siri', 'NNP'),
#   ('Siri', 'NNP'),
#   ("'s", 'POS'),
#   ('flow', 'JJ'),
#   ('reminiscent', 'NN'),
#   ('Nicki', 'NNP'),
#   ('Minaj', 'NNP'),
#   ("'s", 'POS'),
#   ('best', 'JJS'),
#   ('work', 'NN'),
#   ('Monster', 'NNP'),
#   ('cadence', 'NN'),
#   ('smooth', 'VBD'),
#   ('Angel', 'NNP'),
#   ('Haze', 'NNP'),
#   ('potty', 'VBZ'),
#   ('mouth', 'FW'),
#   ('worthy', 'JJ'),
#   ('Azealia', 'NNP'),
#   ('Banks', 'NNPS'),
#   ('As', 'NNP'),
#   ('well', 'RB'),
#   ('name-checking', 'JJ'),
#   ('Spotify', 'NNP'),
#   ('Google', 'NNP'),
#   ('Siri', 'NNP'),
#   ("'s", 'POS'),
#   ('enunciation', 'NN'),
#   ('Young', 'NNP'),
#   ("'s", 'POS'),
#   ('rapid-fire', 'JJ'),
#   ('lyrics', 'NNS'),
#   ('near-perfect', 'JJ'),
#   ('rapping', 'VBG'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('tough', 'JJ'),
#   ('like', 'IN'),
#   ('bone', 'NN'),
#   ('sly', 'RB'),
#   ('like', 'IN'),
#   ('Stallone', 'NNP'),
#   ('rocking', 'VBG'),
#   ('clocking', 'VBG'),
#   ('microphone', 'NN'),
#   ('smooth', 'NN'),
#   ('like', 'IN'),
#   ('mirror', 'NN'),
#   ('hearts', 'NNS'),
#   ('I', 'PRP'),
#   ('strike', 'VBP'),
#   ('terror', 'JJ'),
#   ('rhymes', 'NNS'),
#   ('like', 'IN'),
#   ('runs', 'NNS'),
#   ('rhymes', 'NNS'),
#   ('errors', 'VBP'),
#   ('The', 'DT'),
#   ('producers', 'NNS'),
#   ('worked', 'VBD'),
#   ('Siri', 'NNP'),
#   ('said', 'VBD'),
#   ('thrilled', 'JJ'),
#   ('performance', 'NN'),
#   ('Rizzo', 'NNP'),
#   ('told', 'VBD'),
#   ('Guardian', 'JJ'),
#   ('collaboration', 'NN'),
#   ('came', 'VBD'),
#   ('She', 'PRP'),
#   ("'s", 'VBZ'),
#   ('set', 'VBN'),
#   ('British', 'JJ'),
#   ('Female', 'NNP'),
#   ('I', 'PRP'),
#   ('asked', 'VBD'),
#   ('dial', 'JJ'),
#   ('lyrics', 'NNS'),
#   ('one', 'CD'),
#   ('favourite', 'NN'),
#   ('boasting', 'VBG'),
#   ('hip', 'NN'),
#   ('hop', 'NN'),
#   ('tracks', 'NNS'),
#   ('time', 'NN'),
#   ('Young', 'NNP'),
#   ('MC', 'NNP'),
#   ("'s", 'POS'),
#   ('Know', 'NNP'),
#   ('How', 'NNP'),
#   ('When', 'WRB'),
#   ('I', 'PRP'),
#   ('asked', 'VBD'),
#   ('read', 'RB'),
#   ('well', 'RB'),
#   ('real', 'JJ'),
#   ('ROFL-ing', 'NNP'),
#   ('started', 'VBD'),
#   ('Tears', 'NNP'),
#   ('everything', 'NN'),
#   ('Something', 'NNP'),
#   ('posh', 'JJ'),
#   ('English', 'NNP'),
#   ('mechanical', 'JJ'),
#   ('accent', 'NN'),
#   ('busting', 'VBG'),
#   ('rhymes', 'NNS'),
#   ('irresistible', 'JJ'),
#   ('At', 'IN'),
#   ('moment', 'NN'),
#   ('I', 'PRP'),
#   ('knew', 'VBD'),
#   ('needed', 'VBN'),
#   ('done', 'VBN'),
#   ('rest', 'NN'),
#   ('recording', 'VBG'),
#   ('replaying', 'VBG'),
#   ('whole', 'JJ'),
#   ('lot', 'NN'),
#   ('editing', 'VBG'),
#   ('This', 'DT'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('Siri', 'NNP'),
#   ('taken', 'VBN'),
#   ('mic', 'JJ'),
#   ('though', 'IN'),
#   ('She', 'PRP'),
#   ('previously', 'RB'),
#   ('covered', 'VBD'),
#   ('Eminem', 'NNP'),
#   ("'s", 'POS'),
#   ('Lose', 'NNP'),
#   ('Yourself', 'NNP'),
#   ('great', 'JJ'),
#   ('effort', 'NN'),
#   ('better', 'RBR'),
#   ('effect', 'NN'),
#   ('Notorious', 'NNP'),
#   ('BIG', 'NNP'),
#   ("'s", 'POS'),
#   ('Hypnotize', 'NNP'),
#   ('X', 'NNP'),
#   ('Factor', 'NNP'),
#   ('watch', 'NN')],
#  [('Netflix', 'NNP'),
#   ('viewers', 'NNS'),
#   ('prefer', 'VBP'),
#   ('diet', 'JJ'),
#   ('comedy', 'NN'),
#   ('breakfast', 'NN'),
#   ('portion', 'NN'),
#   ('drama', 'NN'),
#   ('lunch', 'NN'),
#   ('break', 'NN'),
#   ('midnight', 'NN'),
#   ('snack', 'NN'),
#   ('documentaries', 'NNS'),
#   ('Netflix', 'NNP'),
#   ('100', 'CD'),
#   ('million', 'CD'),
#   ('subscribers', 'NNS'),
#   ('worldwide', 'VBP'),
#   ('said', 'VBD'),
#   ('analysis', 'NN'),
#   ('viewing', 'NN'),
#   ('data', 'NNS'),
#   ('found', 'VBD'),
#   ('users', 'NNS'),
#   ('service', 'NN'),
#   ('keen', 'JJ'),
#   ('start', 'JJ'),
#   ('day', 'NN'),
#   ('laugh', 'IN'),
#   ('watching', 'VBG'),
#   ('comedies', 'NNS'),
#   ('Fuller', 'NNP'),
#   ('House', 'NNP'),
#   ('At', 'IN'),
#   ('6am', 'CD'),
#   ('members', 'NNS'),
#   ('34', 'CD'),
#   ('likely', 'JJ'),
#   ('watch', 'NN'),
#   ('comedy', 'NN'),
#   ('time', 'NN'),
#   ('day', 'NN'),
#   ('data', 'NNS'),
#   ('gathered', 'VBD'),
#   ('users', 'NNS'),
#   ('across', 'IN'),
#   ('22', 'CD'),
#   ('countries', 'NNS'),
#   ('shows', 'VBZ'),
#   ('Sneaking', 'VBG'),
#   ('episode', 'JJ'),
#   ('drama', 'NN'),
#   ('lunchtime', 'NN'),
#   ('emerged', 'VBD'),
#   ('popular', 'JJ'),
#   ('pastime', 'NN'),
#   ('shows', 'NNS'),
#   ('genre', 'VBP'),
#   ('Mad', 'NNP'),
#   ('Men', 'NNP'),
#   ('Bloodline', 'NNP'),
#   ('Orange', 'NNP'),
#   ('New', 'NNP'),
#   ('Black', 'NNP'),
#   ('accounting', 'NN'),
#   ('47', 'CD'),
#   ('viewing', 'VBG'),
#   ('noon', 'RB'),
#   ('2pm', 'CD'),
#   ('Evening', 'VBG'),
#   ('viewing', 'NN'),
#   ('peppered', 'VBD'),
#   ('range', 'JJ'),
#   ('usual', 'JJ'),
#   ('suspects', 'NNS'),
#   ('including', 'VBG'),
#   ('Breaking', 'NNP'),
#   ('Bad', 'NNP'),
#   ('Stranger', 'NNP'),
#   ('Things', 'NNP'),
#   ('viewership', 'NN'),
#   ('thriller', 'NN'),
#   ('genre', 'NN'),
#   ('increases', 'VBZ'),
#   ('quarter', 'NN'),
#   ('9pm', 'CD'),
#   ('It', 'PRP'),
#   ('back', 'RB'),
#   ('comedies', 'VBZ'),
#   ('lights', 'NNS'),
#   ('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('Always', 'NNP'),
#   ('Sunny', 'NNP'),
#   ('Philadelphia', 'NNP'),
#   ('Master', 'NNP'),
#   ('None', 'NNP'),
#   ('BoJack', 'NNP'),
#   ('Horseman', 'NNP'),
#   ('taking', 'VBG'),
#   ('11pm', 'CD'),
#   ('For', 'IN'),
#   ('night', 'NN'),
#   ('owls', 'VBZ'),
#   ('15', 'CD'),
#   ('Netflix', 'NNP'),
#   ('viewing', 'NN'),
#   ('occurs', 'VBZ'),
#   ('midnight', 'RB'),
#   ('6am', 'CD'),
#   ('documentaries', 'NNS'),
#   ('popular', 'JJ'),
#   ('In', 'IN'),
#   ('period', 'NN'),
#   ('24', 'CD'),
#   ('surge', 'NN'),
#   ('viewing', 'VBG'),
#   ('documentaries', 'NNS'),
#   ('Making', 'VBG'),
#   ('Murderer', 'NNP'),
#   ('Planet', 'NNP'),
#   ('Earth', 'NNP'),
#   ('Netflix', 'NNP'),
#   ('says', 'VBZ'),
#   ('business', 'NN'),
#   ('model', 'NN'),
#   ('enables', 'VBZ'),
#   ('viewers', 'NNS'),
#   ('binge-watch', 'JJ'),
#   ('entire', 'JJ'),
#   ('series', 'NN'),
#   ('one', 'CD'),
#   ('go', 'VBP'),
#   ('counter', 'JJ'),
#   ('traditional', 'JJ'),
#   ('TV', 'NN'),
#   ('model', 'NN'),
#   ('resulted', 'VBD'),
#   ('marked', 'JJ'),
#   ('changes', 'NNS'),
#   ('kind', 'NN'),
#   ('shows', 'NNS'),
#   ('watched', 'VBD'),
#   ("'For", 'CD'),
#   ('years', 'NNS'),
#   ('lives', 'VBZ'),
#   ('fit', 'VBP'),
#   ('around', 'IN'),
#   ('television', 'NN'),
#   ("'s", 'POS'),
#   ('way', 'NN'),
#   ('round', 'NN'),
#   ('said', 'VBD'),
#   ('Cindy', 'NNP'),
#   ('Holland', 'NNP'),
#   ('vice-president', 'JJ'),
#   ('original', 'JJ'),
#   ('content', 'NN'),
#   ('Netflix', 'NNP'),
#   ("'We", 'POS'),
#   ("'ve", 'VBP'),
#   ('given', 'VBN'),
#   ('consumers', 'NNS'),
#   ('control', 'VBP'),
#   ("'s", 'POS'),
#   ('interesting', 'JJ'),
#   ('see', 'NN'),
#   ('behaviours', 'NNS'),
#   ('emerge', 'VBP'),
#   ('viewers', 'NNS'),
#   ("n't", 'RB'),
#   ('tied', 'VBD'),
#   ('schedule', 'JJ'),
#   ('Netflix', 'NNP'),
#   ('said', 'VBD'),
#   ('trend', 'NN'),
#   ('suggests', 'VBZ'),
#   ('traditional', 'JJ'),
#   ('TV', 'NN'),
#   ('viewing', 'NN'),
#   ('pattern', 'NN'),
#   ('breakfast', 'NN'),
#   ('news', 'NN'),
#   ('shows', 'NNS'),
#   ('followed', 'VBD'),
#   ('lighter', 'JJ'),
#   ('schedule', 'NN'),
#   ('day', 'NN'),
#   ('lights', 'NNS'),
#   ('midnight', 'NN'),
#   ('longer', 'JJR'),
#   ('applies', 'NNS'),
#   ("'Gone", 'CD'),
#   ('days', 'NNS'),
#   ('every', 'DT'),
#   ('household', 'NN'),
#   ('waking', 'VBG'),
#   ('breakfast', 'JJ'),
#   ('TV', 'NN'),
#   ('programming', 'VBG'),
#   ('screens', 'NNS'),
#   ('company', 'NN'),
#   ('said', 'VBD'),
#   ("'When", 'CD'),
#   ('viewing', 'VBG'),
#   ('schedules', 'NNS'),
#   ('set', 'VBN'),
#   ('people', 'NNS'),
#   ('programmers', 'NNS'),
#   ('lunchtime', 'VBP'),
#   ('becomes', 'NNS'),
#   ('bingeing', 'VBG'),
#   ('exception', 'NN'),
#   ('Netflix', 'NNP'),
#   ('analysed', 'VBD'),
#   ('six', 'CD'),
#   ('months', 'NNS'),
#   ('streaming', 'VBG'),
#   ('data', 'NNS'),
#   ('22', 'CD'),
#   ('countries', 'NNS'),
#   ('including', 'VBG'),
#   ('UK', 'NNP'),
#   ('Argentina', 'NNP'),
#   ('Brazil', 'NNP'),
#   ('India', 'NNP'),
#   ('New', 'NNP'),
#   ('Zealand', 'NNP'),
#   ('US', 'NNP')],
#  [('Being', 'VBG'),
#   ('lonely', 'JJ'),
#   ('may', 'MD'),
#   ('make', 'VB'),
#   ('harder', 'JJR'),
#   ('quit', 'NN'),
#   ('smoking', 'VBG'),
#   ('new', 'JJ'),
#   ('British', 'JJ'),
#   ('study', 'NN'),
#   ('suggests', 'VBZ'),
#   ('Using', 'NNP'),
#   ('genetic', 'JJ'),
#   ('survey', 'NN'),
#   ('data', 'NNS'),
#   ('hundreds', 'NNS'),
#   ('thousands', 'NNS'),
#   ('people', 'NNS'),
#   ('researchers', 'NNS'),
#   ('found', 'VBD'),
#   ('loneliness', 'NN'),
#   ('makes', 'VBZ'),
#   ('likely', 'JJ'),
#   ('someone', 'NN'),
#   ('smoke', 'VBD'),
#   ('This', 'DT'),
#   ('type', 'NN'),
#   ('analysis', 'NN'),
#   ('called', 'VBN'),
#   ('Mendelian', 'JJ'),
#   ('randomization', 'NN'),
#   ("'This", 'POS'),
#   ('method', 'NN'),
#   ('never', 'RB'),
#   ('applied', 'VBN'),
#   ('question', 'NN'),
#   ('results', 'NNS'),
#   ('novel', 'NN'),
#   ('also', 'RB'),
#   ('tentative', 'JJ'),
#   ('said', 'VBD'),
#   ('co-lead', 'JJ'),
#   ('author', 'NN'),
#   ('Robyn', 'NNP'),
#   ('Wootton', 'NNP'),
#   ('senior', 'JJ'),
#   ('research', 'NN'),
#   ('associate', 'NN'),
#   ('University', 'NNP'),
#   ('Bristol', 'NNP'),
#   ('United', 'NNP'),
#   ('Kingdom', 'NNP'),
#   ("'We", 'POS'),
#   ('found', 'VBD'),
#   ('evidence', 'NN'),
#   ('suggest', 'JJS'),
#   ('loneliness', 'JJ'),
#   ('leads', 'NNS'),
#   ('increased', 'VBD'),
#   ('smoking', 'VBG'),
#   ('people', 'NNS'),
#   ('likely', 'JJ'),
#   ('start', 'JJ'),
#   ('smoking', 'VBG'),
#   ('smoke', 'NN'),
#   ('cigarettes', 'VBZ'),
#   ('less', 'RBR'),
#   ('likely', 'JJ'),
#   ('quit', 'NN'),
#   ('Wootton', 'NNP'),
#   ('said', 'VBD'),
#   ('university', 'NN'),
#   ('news', 'NN'),
#   ('release', 'NN'),
#   ('These', 'DT'),
#   ('data', 'NNS'),
#   ('mesh', 'NNS'),
#   ('observation', 'NN'),
#   ('coronavirus', 'VBP'),
#   ('pandemic', 'JJ'),
#   ('British', 'JJ'),
#   ('people', 'NNS'),
#   ('smoking', 'VBG'),
#   ('Senior', 'NNP'),
#   ('study', 'NN'),
#   ('author', 'NN'),
#   ('Jorien', 'NNP'),
#   ('Treur', 'NNP'),
#   ('said', 'VBD'),
#   ("'Our", 'CD'),
#   ('finding', 'VBG'),
#   ('smoking', 'NN'),
#   ('may', 'MD'),
#   ('also', 'RB'),
#   ('lead', 'VB'),
#   ('loneliness', 'RBR'),
#   ('tentative', 'JJ'),
#   ('line', 'NN'),
#   ('recent', 'JJ'),
#   ('studies', 'NNS'),
#   ('identified', 'VBD'),
#   ('smoking', 'VBG'),
#   ('risk', 'NN'),
#   ('factor', 'NN'),
#   ('poor', 'JJ'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('A', 'NNP'),
#   ('potential', 'JJ'),
#   ('mechanism', 'NN'),
#   ('relationship', 'NN'),
#   ('nicotine', 'JJ'),
#   ('cigarette', 'NN'),
#   ('smoke', 'NN'),
#   ('interferes', 'VBZ'),
#   ('neurotransmitters', 'NNS'),
#   ('dopamine', 'VBP'),
#   ('brain', 'NN'),
#   ('Treur', 'NNP'),
#   ('visiting', 'VBG'),
#   ('research', 'NN'),
#   ('associate', 'NN'),
#   ('Amsterdam', 'NNP'),
#   ('UMC', 'NNP'),
#   ('The', 'DT'),
#   ('researchers', 'NNS'),
#   ('also', 'RB'),
#   ('looked', 'VBD'),
#   ('connection', 'NN'),
#   ('loneliness', 'NN'),
#   ('drinking', 'NN'),
#   ('found', 'VBD'),
#   ('none', 'NN'),
#   ('Still', 'RB'),
#   ('loneliness', 'JJ'),
#   ('causes', 'NNS'),
#   ('people', 'NNS'),
#   ('smoke', 'VBP'),
#   ('important', 'JJ'),
#   ('alert', 'NN'),
#   ('smoking', 'NN'),
#   ('cessation', 'NN'),
#   ('services', 'NNS'),
#   ('add', 'VBP'),
#   ('factor', 'NN'),
#   ('help', 'NN'),
#   ('people', 'NNS'),
#   ('quit', 'VBP'),
#   ('study', 'NN'),
#   ('authors', 'NNS'),
#   ('said', 'VBD'),
#   ('The', 'DT'),
#   ('report', 'NN'),
#   ('published', 'VBD'),
#   ('June', 'NNP'),
#   ('16', 'CD'),
#   ('journal', 'NN'),
#   ('Addiction', 'NN')]]

# %% [markdown]
# Now that we've got the tags, I want to see what the top-5 most frequently occuring nouns are in each of the articles.
#
# We'll start by experimenting with the first article, ```tagged_tokens[0]```.

# %%
# Takes a list of tuples, where each tuple contains a word and it's POS-tag
def get_noun_counts(tagged_tokens) -> defaultdict(int):
    nouns = list(filter(lambda t: t[1].startswith("NN"), tagged_tokens))
    counts = defaultdict(int)

    for noun in nouns:
        counts[noun[0]] += 1
    return counts

noun_counts = get_noun_counts(tagged_tokens[0])
noun_counts
# Out:
# defaultdict(int,
#             {'California': 1,
#              'Christof': 1,
#              'Communication': 1,
#              'EEG': 2,
#              'Early': 1,
#              'Giulio': 1,
#              'Institute': 1,
#              'Koch': 1,
#              'Lines': 1,
#              'Madison': 1,
#              'Pasadena': 1,
#              'REM': 1,
#              'Science': 1,
#              'Scientists': 1,
#              'TMS': 3,
#              'Technology': 1,
#              'Tononi': 4,
#              'University': 1,
#              'Wisconsin': 1,
#              'activity': 4,
#              'areas': 2,
#              'brain': 2,
#              'brains': 1,
#              'break': 1,
#              'breakdown': 1,
#              'buzz': 1,
#              'chatter': 1,
#              'communication': 2,
#              'consciousness': 3,
#              'correlates': 1,
#              'cortex': 5,
#              'density': 1,
#              'dreams': 1,
#              'equates': 1,
#              'experience': 1,
#              'experiences': 1,
#              'experiments': 1,
#              'explanation': 1,
#              'eye': 1,
#              'fades': 1,
#              'findings': 1,
#              'follow-up': 1,
#              'head': 1,
#              'idea': 1,
#              'implications': 1,
#              'information': 1,
#              'integration': 2,
#              'metabolism': 1,
#              'method': 1,
#              'methods': 1,
#              'movement': 1,
#              'mystery': 1,
#              'neurons': 1,
#              'neuroscientist': 1,
#              'neuroscientists': 2,
#              'parts': 1,
#              'patch': 1,
#              'people': 2,
#              'pulses': 1,
#              'reason': 1,
#              'regions': 2,
#              'repeat': 1,
#              'report': 1,
#              'research': 1,
#              'researchers': 2,
#              'sign': 1,
#              'site': 1,
#              'sleep': 4,
#              'something': 1,
#              'spent': 1,
#              'spread': 1,
#              'stage': 1,
#              'stimulation': 2,
#              'stimulus': 1,
#              'subjects': 2,
#              'team': 1,
#              'theory': 1,
#              'today': 1,
#              'volunteers': 1,
#              'wakefulness': 2,
#              'wane': 1,
#              'wanes': 1,
#              'waves': 1,
#              'years': 1})

# %%
series = pd.Series(data=noun_counts)
series[series >= 3].plot.bar()

# %% [markdown]
# So it's not the top-5 words, but we can see that these results look more promising than the previous results. Still though, if we look at the dictionary of the nouns and their counts, there is a bit of a flaw.
#
# In our ```noun_counts``` dictionary, the word ```neuroscientists``` has a frequency of 2, and the word ```neuroscientist``` has a frequency of 1. If we're trying to figure out what this article is about, we probably want to group these two words together somehow. Ie, we want to *normalize* these words.

# %% [markdown]
# ### Normalization
# Alright so, back to the ```neuroscientists``` and ```neuroscientist``` problem. We want to group these two tokens together (or count them as the same "token"). This process is called *normalization*, where we extract the stem of a word.
#
# We can do this by **stemming** or by **lemmatization**. Either method will work, but because our sample size is relatively small, I'm going to opt for lemmatization. Stemming sometimes gives us stems that aren't actually words, and thus less accurate results while lemmatization, although more expensive, always gives us an actual word.

# %% [markdown]
# Let's go back to the first article and get a new dictionary of the word counts, except this time, we will lemmatize the words according to their POS-tag.

# %%
from nltk import WordNetLemmatizer
nltk.download("wordnet")

lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tagged_tokens):
    lemmatized_tokens = []
    for token in tagged_tokens:
        if token[1].startswith("NN"):
            next = lemmatizer.lemmatize(token[0], pos='n')
        elif token[1].startswith("VB"):
            next = lemmatizer.lemmatize(token[0], pos='v')
        elif token[1].startswith("JJ"):
            next = lemmatizer.lemmatize(token[0], pos='a')
        else:
            next = token[0]
        
        lemmatized_tokens.append(next)
    return lemmatized_tokens

def get_lemmatized_noun_counts(tagged_tokens):
    nouns = list(filter(lambda t: t[1].startswith("NN"), tagged_tokens))
    counts = defaultdict(int)

    for noun in nouns:
        counts[lemmatizer.lemmatize(noun[0])] += 1
    return counts

lemmatized_nouns = get_lemmatized_noun_counts(tagged_tokens[0])
lemmatized_nouns
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['Being',
#  'lonely',
#  'may',
#  'make',
#  'hard',
#  'quit',
#  'smoke',
#  'new',
#  'British',
#  'study',
#  'suggest',
#  'Using',
#  'genetic',
#  'survey',
#  'data',
#  'hundred',
#  'thousand',
#  'people',
#  'researcher',
#  'find',
#  'loneliness',
#  'make',
#  'likely',
#  'someone',
#  'smoke',
#  'This',
#  'type',
#  'analysis',
#  'call',
#  'Mendelian',
#  'randomization',
#  "'This",
#  'method',
#  'never',
#  'apply',
#  'question',
#  'result',
#  'novel',
#  'also',
#  'tentative',
#  'say',
#  'co-lead',
#  'author',
#  'Robyn',
#  'Wootton',
#  'senior',
#  'research',
#  'associate',
#  'University',
#  'Bristol',
#  'United',
#  'Kingdom',
#  "'We",
#  'find',
#  'evidence',
#  'suggest',
#  'loneliness',
#  'lead',
#  'increase',
#  'smoke',
#  'people',
#  'likely',
#  'start',
#  'smoke',
#  'smoke',
#  'cigarettes',
#  'less',
#  'likely',
#  'quit',
#  'Wootton',
#  'say',
#  'university',
#  'news',
#  'release',
#  'These',
#  'data',
#  'mesh',
#  'observation',
#  'coronavirus',
#  'pandemic',
#  'British',
#  'people',
#  'smoke',
#  'Senior',
#  'study',
#  'author',
#  'Jorien',
#  'Treur',
#  'say',
#  "'Our",
#  'find',
#  'smoking',
#  'may',
#  'also',
#  'lead',
#  'loneliness',
#  'tentative',
#  'line',
#  'recent',
#  'study',
#  'identify',
#  'smoke',
#  'risk',
#  'factor',
#  'poor',
#  'mental',
#  'health',
#  'A',
#  'potential',
#  'mechanism',
#  'relationship',
#  'nicotine',
#  'cigarette',
#  'smoke',
#  'interfere',
#  'neurotransmitter',
#  'dopamine',
#  'brain',
#  'Treur',
#  'visit',
#  'research',
#  'associate',
#  'Amsterdam',
#  'UMC',
#  'The',
#  'researcher',
#  'also',
#  'look',
#  'connection',
#  'loneliness',
#  'drinking',
#  'find',
#  'none',
#  'Still',
#  'loneliness',
#  'cause',
#  'people',
#  'smoke',
#  'important',
#  'alert',
#  'smoking',
#  'cessation',
#  'service',
#  'add',
#  'factor',
#  'help',
#  'people',
#  'quit',
#  'study',
#  'author',
#  'say',
#  'The',
#  'report',
#  'publish',
#  'June',
#  '16',
#  'journal',
#  'Addiction']

# %% [markdown]
# As we can see, the tokens ```neuroscientist``` and ```neuroscientists``` have been grouped together. Now, let's see what our graph looks like.

# %%
series = pd.Series(data=lemmatized_nouns)
series[series >= 3].plot.bar()

# %% [markdown]
# These results are definitly an improvement. Let's see what the results look like for the rest of the articles.

# %%
counts = [get_lemmatized_noun_counts(tokens) for tokens in tagged_tokens]

fig, axs = plt.subplots(10, gridspec_kw={'hspace': 1}, figsize=(10, 50))

for i, title in zip(range(0, 10), titles):
    series = pd.Series(data=counts[i])
    series.sort_values(ascending=False).head().plot(ax=axs[i], kind='bar', ylabel='Counts', xlabel='Words').set_title(title)

# %% [markdown]
# On a quick scan, the normalized results are much better than the non-normalized results. However, there are a few outliers. Consider the last article about smoking and loneliness. The article is about *smoking*, a verb, and *loneliness* and adjective. For this project, I have restricted the words we're looking at to just the nouns, which is a problem for this corpa. We could have an article about *doing something* where the subject of the article is about an action ie. a verb.
#
# In the future, if I were to redo this project. I wouldn't want to restrict this to just looking at the nouns. I hypothesize that for some articles, including the verbs and adjectives would improve my results.

# %% [markdown]
# ### TF-IDF Scores
# For the final part of this project, I'm going to be using scikit-learns ```sklearn``` library to calculate the TF-IDF scores for each of the words across the 10 articles.

# %% [markdown]
# To start, I'm going to import sklearn and the ```TfidfVectorizer``` and create a new variable ```tfidf_matrix``` that will contain all of the word scores.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# First get the lemmatized tokens
lemmatized_tokens = [lemmatize_tokens(tokens) for tokens in tagged_tokens]

# Create and instance of the TfidfVectorizer
tfidf_vectorization = TfidfVectorizer()

# Create the tfidf matrix
tfidf_matrix = tfidf_vectorization.fit_transform([" ".join(tokens) for tokens in lemmatized_tokens]).toarray()

# %% [markdown]
# To see a full list of all of the words we're scoring we can call ```tfidf_vectorization.get_feature_names()```

# %%
tfidf_vectorization.get_feature_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '03',
#  '10',
#  '100',
#  '118',
#  '11pm',
#  '129',
#  '130',
#  '14',
#  '15',
#  '150',
#  '15bn',
#  '16',
#  '17',
#  '19',
#  '1950s',
#  '1tn',
#  '2009',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2018',
#  '20s',
#  '22',
#  '232',
#  '24',
#  '25',
#  '26',
#  '29',
#  '2pm',
#  '30',
#  '30s',
#  '31',
#  '34',
#  '3d',
#  '40',
#  '400',
#  '47',
#  '500',
#  '50km',
#  '55',
#  '58',
#  '6am',
#  '6bn',
#  '71',
#  '80',
#  '86',
#  '8bn',
#  '940bn',
#  '95',
#  '963',
#  '970bn',
#  '995bn',
#  '9pm',
#  'ability',
#  'able',
#  'academy',
#  'accelerate',
#  'accent',
#  'access',
#  'accord',
#  'according',
#  'account',
#  'accounting',
#  'accurately',
#  'across',
#  'active',
#  'activity',
#  'add',
#  'addiction',
#  'additive',
#  'adult',
#  'after',
#  'age',
#  'ago',
#  'ahead',
#  'ai',
#  'aka',
#  'alert',
#  'alex',
#  'alliance',
#  'allow',
#  'also',
#  'always',
#  'amazon',
#  'amid',
#  'among',
#  'amount',
#  'amsterdam',
#  'an',
#  'analyse',
#  'analysis',
#  'analyst',
#  'analyze',
#  'ancestry',
#  'ancient',
#  'and',
#  'angel',
#  'annals',
#  'another',
#  'answer',
#  'anxiety',
#  'apple',
#  'applies',
#  'apply',
#  'approach',
#  'april',
#  'archaic',
#  'area',
#  'argentina',
#  'aroeira',
#  'around',
#  'arrest',
#  'artificial',
#  'as',
#  'asia',
#  'ask',
#  'assistant',
#  'associate',
#  'assume',
#  'at',
#  'atypical',
#  'author',
#  'autistic',
#  'average',
#  'awake',
#  'aware',
#  'away',
#  'ax',
#  'azealia',
#  'back',
#  'background',
#  'bad',
#  'bank',
#  'banks',
#  'bar',
#  'base',
#  'based',
#  'beat',
#  'become',
#  'becomes',
#  'before',
#  'befriend',
#  'begin',
#  'beginner',
#  'behavior',
#  'behaviour',
#  'behind',
#  'being',
#  'believe',
#  'belt',
#  'benefit',
#  'benign',
#  'best',
#  'better',
#  'big',
#  'binge',
#  'black',
#  'blood',
#  'bloodline',
#  'blue',
#  'board',
#  'boast',
#  'body',
#  'bojack',
#  'bone',
#  'boom',
#  'boost',
#  'boots',
#  'borrowing',
#  'boston',
#  'brad',
#  'brain',
#  'brazil',
#  'break',
#  'breakdown',
#  'breakfast',
#  'breaking',
#  'brexit',
#  'briefly',
#  'bright',
#  'bristol',
#  'british',
#  'broad',
#  'broadly',
#  'brow',
#  'build',
#  'bumper',
#  'buoy',
#  'business',
#  'bust',
#  'but',
#  'buzz',
#  'cadence',
#  'california',
#  'call',
#  'cancer',
#  'capability',
#  'capital',
#  'capitalisation',
#  'carilion',
#  'carry',
#  'case',
#  'catch',
#  'category',
#  'cause',
#  'caution',
#  'cave',
#  'cent',
#  'central',
#  'cerebral',
#  'certain',
#  'cessation',
#  'chance',
#  'change',
#  'chatter',
#  'checking',
#  'checkpoint',
#  'chief',
#  'china',
#  'choose',
#  'christof',
#  'cigarette',
#  'cigarettes',
#  'cindy',
#  'city',
#  'classify',
#  'clearly',
#  'client',
#  'clinical',
#  'clock',
#  'close',
#  'cloud',
#  'club',
#  'clue',
#  'cnn',
#  'co',
#  'coast',
#  'coastal',
#  'coastline',
#  'cognitive',
#  'collaboration',
#  'college',
#  'combination',
#  'come',
#  'comedies',
#  'comedy',
#  'commerce',
#  'commit',
#  'communication',
#  'community',
#  'company',
#  'compare',
#  'compete',
#  'compute',
#  'computer',
#  'concern',
#  'condition',
#  'confederation',
#  'confine',
#  'connect',
#  'connection',
#  'conscious',
#  'consciouslike',
#  'consciousness',
#  'consumer',
#  'contain',
#  'content',
#  'continue',
#  'contraband',
#  'control',
#  'controlled',
#  'convincing',
#  'convolutional',
#  'coronavirus',
#  'corporate',
#  'correctly',
#  'correlate',
#  'correspond',
#  'cortex',
#  'cost',
#  'could',
#  'counter',
#  'country',
#  'court',
#  'courtroom',
#  'cover',
#  'create',
#  'crime',
#  'criminal',
#  'current',
#  'currently',
#  'customer',
#  'da',
#  'damage',
#  'dangerous',
#  'data',
#  'date',
#  'dated',
#  'day',
#  'death',
#  'debate',
#  'decline',
#  'deep',
#  'definitely',
#  'demand',
#  'density',
#  'department',
#  'depend',
#  'depression',
#  'dermatologist',
#  'dermatologists',
#  'detect',
#  'detected',
#  'detector',
#  'develop',
#  'diagnosis',
#  'diagnostics',
#  'dial',
#  'dictation',
#  'diet',
#  'differ',
#  'difference',
#  'different',
#  'differently',
#  'difficult',
#  'difficulty',
#  'digital',
#  'dip',
#  'directly',
#  'director',
#  'discover',
#  'disorder',
#  'dispel',
#  'distinctive',
#  'distinguish',
#  'division',
#  'do',
#  'documentary',
#  'domestic',
#  'dopamine',
#  'downbeat',
#  'dr',
#  'drama',
#  'dream',
#  'drinking',
#  'drop',
#  'drug',
#  'during',
#  'earlier',
#  'early',
#  'earn',
#  'earning',
#  'earth',
#  'ease',
#  'easily',
#  'easy',
#  'economic',
#  'economy',
#  'edge',
#  'edit',
#  'editorial',
#  'eeg',
#  'effect',
#  'effort',
#  'electrical',
#  'electroencephalography',
#  'elicit',
#  'elliot',
#  'emerge',
#  'eminem',
#  'enable',
#  'encounter',
#  'encourage',
#  'engage',
#  'england',
#  'english',
#  'ensure',
#  'enter',
#  'entire',
#  'enunciation',
#  'environment',
#  'environmental',
#  'environments',
#  'episode',
#  'equates',
#  'errors',
#  'europe',
#  'european',
#  'even',
#  'evening',
#  'event',
#  'eventually',
#  'every',
#  'everyone',
#  'everything',
#  'evidence',
#  'evil',
#  'evolve',
#  'examination',
#  'exception',
#  'executive',
#  'exeter',
#  'expect',
#  'expectation',
#  'expected',
#  'experience',
#  'experiment',
#  'expert',
#  'explanation',
#  'export',
#  'exports',
#  'extinct',
#  'eye',
#  'facebook',
#  'factor',
#  'factory',
#  'fade',
#  'fair',
#  'fall',
#  'far',
#  'fast',
#  'faster',
#  'favourite',
#  'fear',
#  'feature',
#  'fed',
#  'federal',
#  'feel',
#  'fell',
#  'female',
#  'few',
#  'field',
#  'figure',
#  'figures',
#  'find',
#  'finding',
#  'finger',
#  'finish',
#  'fire',
#  'firm',
#  'firmly',
#  'first',
#  'fit',
#  'five',
#  'flow',
#  'fmri',
#  'focus',
#  'focused',
#  'follow',
#  'for',
#  'force',
#  'forecast',
#  'form',
#  'forward',
#  'fossil',
#  'found',
#  'four',
#  'fourth',
#  'fragile',
#  'france',
#  'free',
#  'frontal',
#  'fuller',
#  'functional',
#  'functionality',
#  'fuse',
#  'future',
#  'gain',
#  'garrett',
#  'gather',
#  'gdp',
#  'generally',
#  'genetic',
#  'genre',
#  'genus',
#  'germany',
#  'get',
#  'gideon',
#  'giulio',
#  'give',
#  'go',
#  'gone',
#  'good',
#  'google',
#  'government',
#  'grab',
#  'grand',
#  'great',
#  'grocery',
#  'group',
#  'grow',
#  'growth',
#  'gruta',
#  'guard',
#  'guardian',
#  'gur',
#  'had',
#  'haenssle',
#  'half',
#  'hand',
#  'hands',
#  'hard',
#  'hardcore',
#  'haze',
#  'head',
#  'health',
#  'heart',
#  'heidelberg',
#  'help',
#  'high',
#  'hike',
#  'hinge',
#  'hip',
#  'hoard',
#  'hold',
#  'holger',
#  'holland',
#  'homo',
#  'hop',
#  'horseman',
#  'hot',
#  'house',
#  'housebuilding',
#  'household',
#  'households',
#  'how',
#  'human',
#  'humans',
#  'hundred',
#  'hypnotize',
#  'idea',
#  'identify',
#  'if',
#  'illicit',
#  'image',
#  'imaging',
#  'immoral',
#  'implication',
#  'import',
#  'important',
#  'improve',
#  'improvement',
#  'in',
#  'include',
#  'inclusive',
#  'income',
#  'increase',
#  'increasingly',
#  'indeed',
#  'index',
#  'india',
#  'induce',
#  'industry',
#  'inequality',
#  'information',
#  'ing',
#  'innovation',
#  'inside',
#  'insight',
#  'insitute',
#  'instead',
#  'institute',
#  'integration',
#  'intelligence',
#  'intense',
#  'intent',
#  'interest',
#  'interesting',
#  'interfere',
#  'introduce',
#  'investigation',
#  'investment',
#  'involved',
#  'ireland',
#  'irresistible',
#  'it',
#  'january',
#  'japanese',
#  'jasper',
#  'jo',
#  'join',
#  'jorien',
#  'journal',
#  'judge',
#  'judith',
#  'jump',
#  'june',
#  'jury',
#  'just',
#  'keen',
#  'kick',
#  'kilometre',
#  'kind',
#  'kingdom',
#  'know',
#  'koch',
#  'kroger',
#  'lab',
#  'laboratory',
#  'large',
#  'last',
#  'late',
#  'laugh',
#  'law',
#  'lawler',
#  'lawyer',
#  'lead',
#  'leading',
#  'leap',
#  'learning',
#  'leave',
#  'lesion',
#  'less',
#  'level',
#  'liane',
#  'light',
#  'like',
#  'likely',
#  'limitation',
#  'line',
#  'lines',
#  'link',
#  'list',
#  'little',
#  'live',
#  'london',
#  'loneliness',
#  'lonely',
#  'long',
#  'look',
#  'looked',
#  'lose',
#  'lot',
#  'low',
#  'lower',
#  'lunch',
#  'lunchtime',
#  'lyric',
#  'machine',
#  'mad',
#  'madison',
#  'magnetic',
#  'maintain',
#  'major',
#  'make',
#  'maker',
#  'making',
#  'malignant',
#  'manufacturing',
#  'many',
#  'mar',
#  'march',
#  'mark',
#  'marked',
#  'market',
#  'master',
#  'material',
#  'mathew',
#  'matter',
#  'maximise',
#  'may',
#  'mc',
#  'meaning',
#  'meaningful',
#  'measure',
#  'mechanical',
#  'mechanism',
#  'medical',
#  'melanoma',
#  'melbourne',
#  'member',
#  'men',
#  'mendelian',
#  'mental',
#  'mesh',
#  'metabolism',
#  'method',
#  'mic',
#  'microphone',
#  'microsoft',
#  'mid',
#  'midnight',
#  'might',
#  'million',
#  'minaj',
#  'mirror',
#  'misdiagnosed',
#  'miss',
#  'mix',
#  'model',
#  'modern',
#  'modest',
#  'mole',
#  'moment',
#  'monash',
#  'monetary',
#  'monster',
#  'montague',
#  'month',
#  'most',
#  'mostly',
#  'mouth',
#  'movement',
#  'much',
#  'murderer',
#  'mystery',
#  'nadella',
#  'name',
#  'nasdaq',
#  'national',
#  'neandertals',
#  'near',
#  'need',
#  'negotiation',
#  'neighbor',
#  'net',
#  'netflix',
#  'network',
#  'neural',
#  'neuron',
#  'neuroscientist',
#  'neurotransmitter',
#  'neutral',
#  'never',
#  'new',
#  'newly',
#  'newman',
#  'news',
#  'next',
#  'nicki',
#  'nicotine',
#  'night',
#  'nod',
#  'nodded',
#  'non',
#  'none',
#  'noon',
#  'note',
#  'notorious',
#  'novel',
#  'number',
#  'observation',
#  'observe',
#  'occur',
#  'offer',
#  'offering',
#  'often',
#  'old',
#  'on',
#  'oncology',
#  'one',
#  'orange',
#  'order',
#  'organisation',
#  'original',
#  'other',
#  'our',
#  'outlook',
#  'outperform',
#  'output',
#  'outside',
#  'overcame',
#  'owls',
#  'pace',
#  'pandemic',
#  'paper',
#  'parietal',
#  'part',
#  'partial',
#  'participant',
#  'particularly',
#  'pasadena',
#  'pastime',
#  'patch',
#  'patient',
#  'pattern',
#  'pause',
#  'pennsylvania',
#  'people',
#  'pepper',
#  'per',
#  'percentage',
#  'perfect',
#  'performance',
#  'perhaps',
#  'period',
#  'person',
#  'peter',
#  'philadelphia',
#  'philosopher',
#  'photo',
#  'picture',
#  'pit',
#  'pizza',
#  'place',
#  'planet',
#  'play',
#  'point',
#  'policy',
#  'poor',
#  'poorer',
#  'popular',
#  'portfolio',
#  'portion',
#  'portugal',
#  'posh',
#  'possible',
#  'potential',
#  'potty',
#  'predict',
#  'prefer',
#  'president',
#  'prestigious',
#  'previous',
#  'previously',
#  'price',
#  'primitive',
#  'principle',
#  'proceedings',
#  'process',
#  'producer',
#  'product',
#  'prof',
#  'profit',
#  'program',
#  'programmer',
#  'proof',
#  'prospect',
#  'protect',
#  'protective',
#  'prove',
#  'proximity',
#  'psychologist',
#  'publicly',
#  'publish',
#  'published',
#  'pulse',
#  'push',
#  'put',
#  'puzzle',
#  'quarter',
#  'quarterly',
#  'queensland',
#  'quest',
#  'question',
#  'quit',
#  'raise',
#  'randomization',
#  'range',
#  'rap',
#  'rapid',
#  'rapper',
#  'rate',
#  'raw',
#  'read',
#  'ready',
#  'real',
#  'really',
#  'reason',
#  'reback',
#  'recent',
#  'recession',
#  'reckless',
#  'recklessness',
#  'recognise',
#  'recoil',
#  'recommendation',
#  'reconstruction',
#  'record',
#  'reduce',
#  'regardless',
#  'region',
#  'relate',
#  'related',
#  'relationship',
#  'release',
#  'relevant',
#  'rem',
#  'remain',
#  'reminiscent',
#  'remix',
#  'removal',
#  'repeat',
#  'replay',
#  'report',
#  'reports',
#  'required',
#  'research',
#  'researcher',
#  'researchers',
#  'resemble',
#  'reserve',
#  'resonance',
#  'respondent',
#  'response',
#  'rest',
#  'result',
#  'reveal',
#  'revenue',
#  'revenues',
#  'reverse',
#  'rhyme',
#  'ridge',
#  'right',
#  'rise',
#  'risk',
#  'risky',
#  'rival',
#  'rizzo',
#  'roanoke',
#  'robyn',
#  'rock',
#  'rofl',
#  'role',
#  'round',
#  'ruben',
#  'rule',
#  'run',
#  'sale',
#  'sample',
#  'satya',
#  'say',
#  'scalp',
#  'scan',
#  'scenario',
#  'schedule',
#  'school',
#  'science',
#  'sciences',
#  'scientist',
#  'scientists',
#  'screen',
#  'sea',
#  'second',
#  'security',
#  'see',
#  'seem',
#  'send',
#  'senior',
#  'sense',
#  'sensitivity',
#  'sequencing',
#  'series',
#  'service',
#  'set',
#  'several',
#  'share',
#  'shares',
#  'sharply',
#  'she',
#  'shift',
#  'show',
#  'shut',
#  'side',
#  'sign',
#  'similar',
#  'simple',
#  'simply',
#  'simulate',
#  'since',
#  'siri',
#  'site',
#  'situation',
#  'six',
#  'size',
#  'skeewiff',
#  'skilled',
#  'skin',
#  'skull',
#  'sleep',
#  'sleepy',
#  'slow',
#  'slowdown',
#  'slowest',
#  'slumber',
#  'slump',
#  'sly',
#  'small',
#  'smoke',
#  'smoking',
#  'smooth',
#  'smuggle',
#  'snack',
#  'sneaking',
#  'solve',
#  'someone',
#  'something',
#  'son',
#  'sort',
#  'soyer',
#  'space',
#  'spaces',
#  'specific',
#  'spend',
#  'spending',
#  'spent',
#  'spotify',
#  'spread',
#  ...]

# %% [markdown]
# The scores for each token, for each piece of text are buried inside of ```tfidf_matrix```. To extract them I'm going to zip together the feature names and a row from ```tfidf_matrix``` into a dictionary. This will give us a better idea of the actual scores for each of the tokens.

# %%
dict(zip(tfidf_vectorization.get_feature_names(), tfidf_matrix[0]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# {'000': 0.0,
#  '03': 0.0,
#  '10': 0.0,
#  '100': 0.0,
#  '118': 0.0,
#  '11pm': 0.0,
#  '129': 0.0,
#  '130': 0.0,
#  '14': 0.0,
#  '15': 0.0,
#  '150': 0.0,
#  '15bn': 0.0,
#  '16': 0.0,
#  '17': 0.0,
#  '19': 0.0,
#  '1950s': 0.0,
#  '1tn': 0.0,
#  '2009': 0.0,
#  '2013': 0.0,
#  '2014': 0.0,
#  '2015': 0.0,
#  '2016': 0.0,
#  '2018': 0.0,
#  '20s': 0.0,
#  '22': 0.0,
#  '232': 0.0,
#  '24': 0.0,
#  '25': 0.0,
#  '26': 0.0,
#  '29': 0.0,
#  '2pm': 0.0,
#  '30': 0.0,
#  '30s': 0.0,
#  '31': 0.0,
#  '34': 0.0,
#  '3d': 0.0,
#  '40': 0.0,
#  '400': 0.0,
#  '47': 0.0,
#  '500': 0.0,
#  '50km': 0.0,
#  '55': 0.0,
#  '58': 0.0,
#  '6am': 0.0,
#  '6bn': 0.0,
#  '71': 0.0,
#  '80': 0.0,
#  '86': 0.0,
#  '8bn': 0.0,
#  '940bn': 0.0,
#  '95': 0.0,
#  '963': 0.0,
#  '970bn': 0.0,
#  '995bn': 0.0,
#  '9pm': 0.0,
#  'ability': 0.0,
#  'able': 0.0,
#  'academy': 0.0,
#  'accelerate': 0.0,
#  'accent': 0.0,
#  'access': 0.0,
#  'accord': 0.0,
#  'according': 0.0,
#  'account': 0.0,
#  'accounting': 0.0,
#  'accurately': 0.0,
#  'across': 0.0,
#  'active': 0.0419759147882462,
#  'activity': 0.1468958610825618,
#  'add': 0.0,
#  'addiction': 0.0,
#  'additive': 0.0,
#  'adult': 0.0,
#  'after': 0.0,
#  'age': 0.049378121887166365,
#  'ago': 0.0,
#  'ahead': 0.0,
#  'ai': 0.0,
#  'aka': 0.0,
#  'alert': 0.0,
#  'alex': 0.0,
#  'alliance': 0.0,
#  'allow': 0.0,
#  'also': 0.0,
#  'always': 0.0,
#  'amazon': 0.0,
#  'amid': 0.0,
#  'among': 0.0,
#  'amount': 0.0,
#  'amsterdam': 0.0,
#  'an': 0.049378121887166365,
#  'analyse': 0.0,
#  'analysis': 0.0,
#  'analyst': 0.0,
#  'analyze': 0.0,
#  'ancestry': 0.0,
#  'ancient': 0.0,
#  'and': 0.0,
#  'angel': 0.0,
#  'annals': 0.0,
#  'another': 0.0,
#  'answer': 0.0,
#  'anxiety': 0.0,
#  'apple': 0.0,
#  'applies': 0.0,
#  'apply': 0.0,
#  'approach': 0.0,
#  'april': 0.0,
#  'archaic': 0.0,
#  'area': 0.09875624377433273,
#  'argentina': 0.0,
#  'aroeira': 0.0,
#  'around': 0.0,
#  'arrest': 0.0,
#  'artificial': 0.0,
#  'as': 0.0,
#  'asia': 0.0,
#  'ask': 0.0,
#  'assistant': 0.0,
#  'associate': 0.0,
#  'assume': 0.049378121887166365,
#  'at': 0.0,
#  'atypical': 0.0,
#  'author': 0.0,
#  'autistic': 0.0,
#  'average': 0.0,
#  'awake': 0.049378121887166365,
#  'aware': 0.0,
#  'away': 0.0,
#  'ax': 0.0,
#  'azealia': 0.0,
#  'back': 0.0,
#  'background': 0.0,
#  'bad': 0.0,
#  'bank': 0.0,
#  'banks': 0.0,
#  'bar': 0.0,
#  'base': 0.0,
#  'based': 0.0,
#  'beat': 0.0,
#  'become': 0.0,
#  'becomes': 0.0,
#  'before': 0.049378121887166365,
#  'befriend': 0.0,
#  'begin': 0.0,
#  'beginner': 0.0,
#  'behavior': 0.0,
#  'behaviour': 0.0,
#  'behind': 0.0,
#  'being': 0.0,
#  'believe': 0.0,
#  'belt': 0.0,
#  'benefit': 0.0,
#  'benign': 0.0,
#  'best': 0.0,
#  'better': 0.0,
#  'big': 0.0,
#  'binge': 0.0,
#  'black': 0.0,
#  'blood': 0.0,
#  'bloodline': 0.0,
#  'blue': 0.0,
#  'board': 0.0,
#  'boast': 0.0,
#  'body': 0.0,
#  'bojack': 0.0,
#  'bone': 0.0,
#  'boom': 0.0,
#  'boost': 0.0,
#  'boots': 0.0,
#  'borrowing': 0.0,
#  'boston': 0.0,
#  'brad': 0.0,
#  'brain': 0.11017189581192137,
#  'brazil': 0.0,
#  'break': 0.0419759147882462,
#  'breakdown': 0.049378121887166365,
#  'breakfast': 0.0,
#  'breaking': 0.0,
#  'brexit': 0.0,
#  'briefly': 0.0,
#  'bright': 0.0,
#  'bristol': 0.0,
#  'british': 0.0,
#  'broad': 0.0,
#  'broadly': 0.0,
#  'brow': 0.0,
#  'build': 0.0,
#  'bumper': 0.0,
#  'buoy': 0.0,
#  'business': 0.0,
#  'bust': 0.0,
#  'but': 0.03265023673867596,
#  'buzz': 0.049378121887166365,
#  'cadence': 0.0,
#  'california': 0.049378121887166365,
#  'call': 0.0,
#  'cancer': 0.0,
#  'capability': 0.0,
#  'capital': 0.0,
#  'capitalisation': 0.0,
#  'carilion': 0.0,
#  'carry': 0.0,
#  'case': 0.0,
#  'catch': 0.0,
#  'category': 0.0,
#  'cause': 0.0,
#  'caution': 0.0,
#  'cave': 0.0,
#  'cent': 0.0,
#  'central': 0.0,
#  'cerebral': 0.049378121887166365,
#  'certain': 0.0,
#  'cessation': 0.0,
#  'chance': 0.0,
#  'change': 0.0,
#  'chatter': 0.049378121887166365,
#  'checking': 0.0,
#  'checkpoint': 0.0,
#  'chief': 0.0,
#  'china': 0.0,
#  'choose': 0.0,
#  'christof': 0.049378121887166365,
#  'cigarette': 0.0,
#  'cigarettes': 0.0,
#  'cindy': 0.0,
#  'city': 0.0,
#  'classify': 0.0,
#  'clearly': 0.0,
#  'client': 0.0,
#  'clinical': 0.0,
#  'clock': 0.0,
#  'close': 0.0,
#  'cloud': 0.0,
#  'club': 0.0,
#  'clue': 0.0,
#  'cnn': 0.0,
#  'co': 0.0,
#  'coast': 0.0,
#  'coastal': 0.0,
#  'coastline': 0.0,
#  'cognitive': 0.049378121887166365,
#  'collaboration': 0.0,
#  'college': 0.0,
#  'combination': 0.0,
#  'come': 0.0,
#  'comedies': 0.0,
#  'comedy': 0.0,
#  'commerce': 0.0,
#  'commit': 0.0,
#  'communication': 0.1481343656614991,
#  'community': 0.0,
#  'company': 0.0,
#  'compare': 0.0,
#  'compete': 0.0,
#  'compute': 0.0,
#  'computer': 0.0,
#  'concern': 0.0,
#  'condition': 0.0,
#  'confederation': 0.0,
#  'confine': 0.0,
#  'connect': 0.0,
#  'connection': 0.0,
#  'conscious': 0.049378121887166365,
#  'consciouslike': 0.049378121887166365,
#  'consciousness': 0.2962687313229982,
#  'consumer': 0.0,
#  'contain': 0.0,
#  'content': 0.0,
#  'continue': 0.0419759147882462,
#  'contraband': 0.0,
#  'control': 0.0,
#  'controlled': 0.0,
#  'convincing': 0.0,
#  'convolutional': 0.0,
#  'coronavirus': 0.0,
#  'corporate': 0.0,
#  'correctly': 0.0,
#  'correlate': 0.049378121887166365,
#  'correspond': 0.049378121887166365,
#  'cortex': 0.34564685321016453,
#  'cost': 0.0,
#  'could': 0.0,
#  'counter': 0.0,
#  'country': 0.0,
#  'court': 0.0,
#  'courtroom': 0.0,
#  'cover': 0.0,
#  'create': 0.0,
#  'crime': 0.0,
#  'criminal': 0.0,
#  'current': 0.0419759147882462,
#  'currently': 0.0,
#  'customer': 0.0,
#  'da': 0.0,
#  'damage': 0.0,
#  'dangerous': 0.0,
#  'data': 0.0,
#  'date': 0.0,
#  'dated': 0.0,
#  'day': 0.0,
#  'death': 0.0,
#  'debate': 0.0,
#  'decline': 0.0,
#  'deep': 0.0,
#  'definitely': 0.049378121887166365,
#  'demand': 0.0,
#  'density': 0.049378121887166365,
#  'department': 0.0,
#  'depend': 0.0,
#  'depression': 0.0,
#  'dermatologist': 0.0,
#  'dermatologists': 0.0,
#  'detect': 0.0,
#  'detected': 0.0,
#  'detector': 0.0,
#  'develop': 0.049378121887166365,
#  'diagnosis': 0.0,
#  'diagnostics': 0.0,
#  'dial': 0.0,
#  'dictation': 0.0,
#  'diet': 0.0,
#  'differ': 0.0,
#  'difference': 0.0,
#  'different': 0.03672396527064045,
#  'differently': 0.0,
#  'difficult': 0.0,
#  'difficulty': 0.0,
#  'digital': 0.0,
#  'dip': 0.0,
#  'directly': 0.0,
#  'director': 0.0,
#  'discover': 0.0,
#  'disorder': 0.0,
#  'dispel': 0.0,
#  'distinctive': 0.0,
#  'distinguish': 0.0,
#  'division': 0.0,
#  'do': 0.0,
#  'documentary': 0.0,
#  'domestic': 0.0,
#  'dopamine': 0.0,
#  'downbeat': 0.0,
#  'dr': 0.0,
#  'drama': 0.0,
#  'dream': 0.049378121887166365,
#  'drinking': 0.0,
#  'drop': 0.0,
#  'drug': 0.0,
#  'during': 0.049378121887166365,
#  'earlier': 0.0,
#  'early': 0.03672396527064045,
#  'earn': 0.0,
#  'earning': 0.0,
#  'earth': 0.0,
#  'ease': 0.0,
#  'easily': 0.0,
#  'easy': 0.0,
#  'economic': 0.0,
#  'economy': 0.0,
#  'edge': 0.0,
#  'edit': 0.0,
#  'editorial': 0.0,
#  'eeg': 0.09875624377433273,
#  'effect': 0.0,
#  'effort': 0.0,
#  'electrical': 0.1481343656614991,
#  'electroencephalography': 0.049378121887166365,
#  'elicit': 0.09875624377433273,
#  'elliot': 0.0,
#  'emerge': 0.0,
#  'eminem': 0.0,
#  'enable': 0.0,
#  'encounter': 0.0,
#  'encourage': 0.0,
#  'engage': 0.0,
#  'england': 0.0,
#  'english': 0.0,
#  'ensure': 0.0,
#  'enter': 0.0,
#  'entire': 0.0,
#  'enunciation': 0.0,
#  'environment': 0.0,
#  'environmental': 0.0,
#  'environments': 0.0,
#  'episode': 0.0,
#  'equates': 0.049378121887166365,
#  'errors': 0.0,
#  'europe': 0.0,
#  'european': 0.0,
#  'even': 0.0,
#  'evening': 0.0,
#  'event': 0.0,
#  'eventually': 0.0,
#  'every': 0.0,
#  'everyone': 0.0,
#  'everything': 0.0,
#  'evidence': 0.0,
#  'evil': 0.0,
#  'evolve': 0.0,
#  'examination': 0.0,
#  'exception': 0.0,
#  'executive': 0.0,
#  'exeter': 0.0,
#  'expect': 0.0,
#  'expectation': 0.0,
#  'expected': 0.0,
#  'experience': 0.0734479305412809,
#  'experiment': 0.0419759147882462,
#  'expert': 0.0,
#  'explanation': 0.049378121887166365,
#  'export': 0.0,
#  'exports': 0.0,
#  'extinct': 0.0,
#  'eye': 0.049378121887166365,
#  'facebook': 0.0,
#  'factor': 0.0,
#  'factory': 0.0,
#  'fade': 0.049378121887166365,
#  'fair': 0.0,
#  'fall': 0.0,
#  'far': 0.0,
#  'fast': 0.0,
#  'faster': 0.0,
#  'favourite': 0.0,
#  'fear': 0.0,
#  'feature': 0.0,
#  'fed': 0.0,
#  'federal': 0.0,
#  'feel': 0.0,
#  'fell': 0.0,
#  'female': 0.0,
#  'few': 0.0,
#  'field': 0.0,
#  'figure': 0.0,
#  'figures': 0.0,
#  'find': 0.0,
#  'finding': 0.0419759147882462,
#  'finger': 0.0,
#  'finish': 0.0,
#  'fire': 0.0,
#  'firm': 0.0,
#  'firmly': 0.0,
#  'first': 0.0,
#  'fit': 0.0,
#  'five': 0.0,
#  'flow': 0.0,
#  'fmri': 0.0,
#  'focus': 0.0,
#  'focused': 0.0,
#  'follow': 0.0419759147882462,
#  'for': 0.0,
#  'force': 0.0,
#  'forecast': 0.0,
#  'form': 0.049378121887166365,
#  'forward': 0.0,
#  'fossil': 0.0,
#  'found': 0.0,
#  'four': 0.0,
#  'fourth': 0.0,
#  'fragile': 0.0,
#  'france': 0.0,
#  'free': 0.0,
#  'frontal': 0.09875624377433273,
#  'fuller': 0.0,
#  'functional': 0.0,
#  'functionality': 0.0,
#  'fuse': 0.0,
#  'future': 0.0,
#  'gain': 0.0419759147882462,
#  'garrett': 0.0,
#  'gather': 0.0,
#  'gdp': 0.0,
#  'generally': 0.0,
#  'genetic': 0.0,
#  'genre': 0.0,
#  'genus': 0.0,
#  'germany': 0.0,
#  'get': 0.0,
#  'gideon': 0.0,
#  'giulio': 0.049378121887166365,
#  'give': 0.0,
#  'go': 0.0,
#  'gone': 0.0,
#  'good': 0.0,
#  'google': 0.0,
#  'government': 0.0,
#  'grab': 0.0,
#  'grand': 0.0,
#  'great': 0.0,
#  'grocery': 0.0,
#  'group': 0.0,
#  'grow': 0.0,
#  'growth': 0.0,
#  'gruta': 0.0,
#  'guard': 0.0,
#  'guardian': 0.0,
#  'gur': 0.0,
#  'had': 0.0,
#  'haenssle': 0.0,
#  'half': 0.0,
#  'hand': 0.0,
#  'hands': 0.0,
#  'hard': 0.0,
#  'hardcore': 0.0,
#  'haze': 0.0,
#  'head': 0.03672396527064045,
#  'health': 0.0,
#  'heart': 0.0,
#  'heidelberg': 0.0,
#  'help': 0.0,
#  'high': 0.029321758171720298,
#  'hike': 0.0,
#  'hinge': 0.0,
#  'hip': 0.0,
#  'hoard': 0.0,
#  'hold': 0.0,
#  'holger': 0.0,
#  'holland': 0.0,
#  'homo': 0.0,
#  'hop': 0.0,
#  'horseman': 0.0,
#  'hot': 0.0,
#  'house': 0.0,
#  'housebuilding': 0.0,
#  'household': 0.0,
#  'households': 0.0,
#  'how': 0.0,
#  'human': 0.0,
#  'humans': 0.0,
#  'hundred': 0.0,
#  'hypnotize': 0.0,
#  'idea': 0.0419759147882462,
#  'identify': 0.0,
#  'if': 0.049378121887166365,
#  'illicit': 0.0,
#  'image': 0.0,
#  'imaging': 0.0,
#  'immoral': 0.0,
#  'implication': 0.049378121887166365,
#  'import': 0.0,
#  'important': 0.1259277443647386,
#  'improve': 0.0,
#  'improvement': 0.0,
#  'in': 0.0,
#  'include': 0.0,
#  'inclusive': 0.0,
#  'income': 0.0,
#  'increase': 0.0,
#  'increasingly': 0.0,
#  'indeed': 0.049378121887166365,
#  'index': 0.0,
#  'india': 0.0,
#  'induce': 0.049378121887166365,
#  'industry': 0.0,
#  'inequality': 0.0,
#  'information': 0.03672396527064045,
#  'ing': 0.0,
#  'innovation': 0.0,
#  'inside': 0.049378121887166365,
#  'insight': 0.049378121887166365,
#  'insitute': 0.0,
#  'instead': 0.0,
#  'institute': 0.049378121887166365,
#  'integration': 0.09875624377433273,
#  'intelligence': 0.0,
#  'intense': 0.0,
#  'intent': 0.0,
#  'interest': 0.0,
#  'interesting': 0.0,
#  'interfere': 0.0,
#  'introduce': 0.0,
#  'investigation': 0.0,
#  'investment': 0.0,
#  'involved': 0.0,
#  'ireland': 0.0,
#  'irresistible': 0.0,
#  'it': 0.0,
#  'january': 0.0,
#  'japanese': 0.0,
#  'jasper': 0.0,
#  'jo': 0.0,
#  'join': 0.0,
#  'jorien': 0.0,
#  'journal': 0.0,
#  'judge': 0.0,
#  'judith': 0.0,
#  'jump': 0.0,
#  'june': 0.0,
#  'jury': 0.0,
#  'just': 0.0,
#  'keen': 0.0,
#  'kick': 0.0,
#  'kilometre': 0.0,
#  'kind': 0.0,
#  'kingdom': 0.0,
#  'know': 0.0,
#  'koch': 0.049378121887166365,
#  'kroger': 0.0,
#  'lab': 0.0,
#  'laboratory': 0.0,
#  'large': 0.0,
#  'last': 0.0,
#  'late': 0.0419759147882462,
#  'laugh': 0.0,
#  'law': 0.0,
#  'lawler': 0.0,
#  'lawyer': 0.0,
#  'lead': 0.0,
#  'leading': 0.0,
#  'leap': 0.0,
#  'learning': 0.0,
#  'leave': 0.09875624377433273,
#  'lesion': 0.0,
#  'less': 0.0,
#  'level': 0.0,
#  'liane': 0.0,
#  'light': 0.0,
#  'like': 0.0,
#  'likely': 0.0,
#  'limitation': 0.0,
#  'line': 0.0,
#  'lines': 0.049378121887166365,
#  'link': 0.0,
#  'list': 0.0,
#  'little': 0.049378121887166365,
#  'live': 0.0,
#  'london': 0.0,
#  'loneliness': 0.0,
#  'lonely': 0.0,
#  'long': 0.0,
#  'look': 0.0,
#  'looked': 0.0,
#  'lose': 0.0,
#  'lot': 0.0,
#  'low': 0.0,
#  'lower': 0.0,
#  'lunch': 0.0,
#  'lunchtime': 0.0,
#  'lyric': 0.0,
#  'machine': 0.0,
#  'mad': 0.0,
#  'madison': 0.049378121887166365,
#  'magnetic': 0.0839518295764924,
#  'maintain': 0.0,
#  'major': 0.0,
#  'make': 0.0,
#  'maker': 0.0,
#  'making': 0.0,
#  'malignant': 0.0,
#  'manufacturing': 0.0,
#  'many': 0.0,
#  'mar': 0.0,
#  'march': 0.0,
#  'mark': 0.0,
#  'marked': 0.0,
#  'market': 0.0,
#  'master': 0.0,
#  'material': 0.0,
#  'mathew': 0.0,
#  'matter': 0.0,
#  'maximise': 0.0,
#  'may': 0.058643516343440595,
#  'mc': 0.0,
#  'meaning': 0.0,
#  'meaningful': 0.0,
#  'measure': 0.0,
#  'mechanical': 0.0,
#  'mechanism': 0.0,
#  'medical': 0.0,
#  'melanoma': 0.0,
#  'melbourne': 0.0,
#  'member': 0.0,
#  'men': 0.0,
#  'mendelian': 0.0,
#  'mental': 0.0,
#  'mesh': 0.0,
#  'metabolism': 0.049378121887166365,
#  'method': 0.0734479305412809,
#  'mic': 0.0,
#  'microphone': 0.0,
#  'microsoft': 0.0,
#  'mid': 0.0,
#  'midnight': 0.0,
#  'might': 0.0734479305412809,
#  'million': 0.0,
#  'minaj': 0.0,
#  'mirror': 0.0,
#  'misdiagnosed': 0.0,
#  'miss': 0.0,
#  'mix': 0.0,
#  'model': 0.0,
#  'modern': 0.049378121887166365,
#  'modest': 0.0,
#  'mole': 0.0,
#  'moment': 0.0,
#  'monash': 0.0,
#  'monetary': 0.0,
#  'monster': 0.0,
#  'montague': 0.0,
#  'month': 0.0,
#  'most': 0.0,
#  'mostly': 0.0,
#  'mouth': 0.0,
#  'movement': 0.049378121887166365,
#  'much': 0.03672396527064045,
#  'murderer': 0.0,
#  'mystery': 0.0419759147882462,
#  'nadella': 0.0,
#  'name': 0.0,
#  'nasdaq': 0.0,
#  'national': 0.0,
#  'neandertals': 0.0,
#  'near': 0.0,
#  'need': 0.0,
#  'negotiation': 0.0,
#  'neighbor': 0.049378121887166365,
#  'net': 0.0,
#  'netflix': 0.0,
#  'network': 0.0,
#  'neural': 0.1259277443647386,
#  'neuron': 0.049378121887166365,
#  'neuroscientist': 0.1259277443647386,
#  'neurotransmitter': 0.0,
#  'neutral': 0.0,
#  'never': 0.0,
#  'new': 0.0,
#  'newly': 0.0,
#  'newman': 0.0,
#  'news': 0.0,
#  'next': 0.0,
#  'nicki': 0.0,
#  'nicotine': 0.0,
#  'night': 0.0419759147882462,
#  'nod': 0.049378121887166365,
#  'nodded': 0.049378121887166365,
#  'non': 0.1481343656614991,
#  'none': 0.0,
#  'noon': 0.0,
#  'note': 0.0,
#  'notorious': 0.0,
#  'novel': 0.0,
#  'number': 0.0,
#  'observation': 0.0,
#  'observe': 0.0,
#  'occur': 0.0,
#  'offer': 0.0,
#  'offering': 0.0,
#  'often': 0.09875624377433273,
#  'old': 0.0419759147882462,
#  'on': 0.0,
#  'oncology': 0.0,
#  'one': 0.02406980865411455,
#  'orange': 0.0,
#  'order': 0.0,
#  'organisation': 0.0,
#  'original': 0.0,
#  'other': 0.0,
#  'our': 0.0,
#  'outlook': 0.0,
#  'outperform': 0.0,
#  'output': 0.0,
#  'outside': 0.0,
#  'overcame': 0.0,
#  'owls': 0.0,
#  'pace': 0.0,
#  'pandemic': 0.0,
#  'paper': 0.0,
#  'parietal': 0.049378121887166365,
#  'part': 0.03265023673867596,
#  'partial': 0.0,
#  'participant': 0.0,
#  'particularly': 0.0,
#  'pasadena': 0.049378121887166365,
#  'pastime': 0.0,
#  'patch': 0.049378121887166365,
#  'patient': 0.0,
#  'pattern': 0.03672396527064045,
#  'pause': 0.0,
#  'pennsylvania': 0.0,
#  'people': 0.05301513928360094,
#  'pepper': 0.0,
#  'per': 0.0,
#  'percentage': 0.0,
#  'perfect': 0.0,
#  'performance': 0.0,
#  'perhaps': 0.0,
#  'period': 0.0,
#  'person': 0.0,
#  'peter': 0.0,
#  'philadelphia': 0.0,
#  'philosopher': 0.0,
#  'photo': 0.0,
#  'picture': 0.0,
#  'pit': 0.0,
#  'pizza': 0.0,
#  'place': 0.0,
#  'planet': 0.0,
#  'play': 0.0,
#  'point': 0.0,
#  'policy': 0.0,
#  'poor': 0.0,
#  'poorer': 0.0,
#  'popular': 0.0,
#  'portfolio': 0.0,
#  'portion': 0.0,
#  'portugal': 0.0,
#  'posh': 0.0,
#  'possible': 0.0,
#  'potential': 0.0,
#  'potty': 0.0,
#  'predict': 0.049378121887166365,
#  'prefer': 0.0,
#  'president': 0.0,
#  'prestigious': 0.0,
#  'previous': 0.0,
#  'previously': 0.0,
#  'price': 0.0,
#  'primitive': 0.0,
#  'principle': 0.0,
#  'proceedings': 0.0,
#  'process': 0.0,
#  'producer': 0.0,
#  'product': 0.0,
#  'prof': 0.0,
#  'profit': 0.0,
#  'program': 0.0,
#  'programmer': 0.0,
#  'proof': 0.0,
#  'prospect': 0.0,
#  'protect': 0.0,
#  'protective': 0.0,
#  'prove': 0.0,
#  'proximity': 0.0,
#  'psychologist': 0.0,
#  'publicly': 0.0,
#  'publish': 0.0,
#  'published': 0.0,
#  'pulse': 0.049378121887166365,
#  'push': 0.0,
#  'put': 0.0,
#  'puzzle': 0.049378121887166365,
#  'quarter': 0.0,
#  'quarterly': 0.0,
#  'queensland': 0.0,
#  'quest': 0.0,
#  'question': 0.0,
#  'quit': 0.0,
#  'raise': 0.0,
#  'randomization': 0.0,
#  'range': 0.0,
#  'rap': 0.0,
#  'rapid': 0.0419759147882462,
#  'rapper': 0.0,
#  'rate': 0.0,
#  'raw': 0.0,
#  'read': 0.0,
#  'ready': 0.0,
#  'real': 0.0,
#  'really': 0.0,
#  'reason': 0.049378121887166365,
#  'reback': 0.0,
#  'recent': 0.0,
#  'recession': 0.0,
#  'reckless': 0.0,
#  'recklessness': 0.0,
#  'recognise': 0.0,
#  'recoil': 0.0,
#  'recommendation': 0.0,
#  'reconstruction': 0.0,
#  'record': 0.03672396527064045,
#  'reduce': 0.0,
#  'regardless': 0.0,
#  'region': 0.09875624377433273,
#  'relate': 0.0,
#  'related': 0.0,
#  'relationship': 0.0,
#  'release': 0.0,
#  'relevant': 0.0,
#  'rem': 0.1481343656614991,
#  'remain': 0.0,
#  'reminiscent': 0.0,
#  'remix': 0.0,
#  'removal': 0.0,
#  'repeat': 0.0419759147882462,
#  'replay': 0.0,
#  'report': 0.0879652745151609,
#  'reports': 0.0,
#  'required': 0.0,
#  'research': 0.02650756964180047,
#  'researcher': 0.058643516343440595,
#  'researchers': 0.0,
#  'resemble': 0.0,
#  'reserve': 0.0,
#  'resonance': 0.0,
#  'respondent': 0.0,
#  'response': 0.0,
#  'rest': 0.0,
#  'result': 0.0,
#  'reveal': 0.0,
#  'revenue': 0.0,
#  'revenues': 0.0,
#  'reverse': 0.0,
#  'rhyme': 0.0,
#  'ridge': 0.0,
#  'right': 0.09875624377433273,
#  'rise': 0.0,
#  'risk': 0.0,
#  'risky': 0.0,
#  'rival': 0.0,
#  'rizzo': 0.0,
#  'roanoke': 0.0,
#  'robyn': 0.0,
#  'rock': 0.0,
#  'rofl': 0.0,
#  'role': 0.0,
#  'round': 0.0,
#  'ruben': 0.0,
#  'rule': 0.049378121887166365,
#  'run': 0.0,
#  'sale': 0.0,
#  'sample': 0.0,
#  'satya': 0.0,
#  'say': 0.09998040061075028,
#  'scalp': 0.0,
#  'scan': 0.0,
#  'scenario': 0.0,
#  'schedule': 0.0,
#  'school': 0.0,
#  'science': 0.049378121887166365,
#  'sciences': 0.0,
#  'scientist': 0.0,
#  'scientists': 0.049378121887166365,
#  'screen': 0.0,
#  'sea': 0.0,
#  'second': 0.0,
#  'security': 0.0,
#  'see': 0.0,
#  'seem': 0.0,
#  'send': 0.0,
#  'senior': 0.0,
#  'sense': 0.0,
#  'sensitivity': 0.0,
#  'sequencing': 0.0,
#  'series': 0.0,
#  'service': 0.0,
#  'set': 0.0,
#  'several': 0.0,
#  'share': 0.0,
#  'shares': 0.0,
#  'sharply': 0.0,
#  'she': 0.0,
#  'shift': 0.0,
#  'show': 0.02650756964180047,
#  'shut': 0.049378121887166365,
#  'side': 0.049378121887166365,
#  'sign': 0.0419759147882462,
#  'similar': 0.049378121887166365,
#  'simple': 0.0,
#  'simply': 0.049378121887166365,
#  'simulate': 0.0,
#  'since': 0.03672396527064045,
#  'siri': 0.0,
#  'site': 0.049378121887166365,
#  'situation': 0.0,
#  'six': 0.03672396527064045,
#  'size': 0.0,
#  'skeewiff': 0.0,
#  'skilled': 0.0,
#  'skin': 0.0,
#  'skull': 0.0,
#  'sleep': 0.34564685321016453,
#  'sleepy': 0.049378121887166365,
#  'slow': 0.0,
#  'slowdown': 0.0,
#  'slowest': 0.0,
#  'slumber': 0.049378121887166365,
#  'slump': 0.0,
#  'sly': 0.0,
#  'small': 0.0419759147882462,
#  'smoke': 0.0,
#  'smoking': 0.0,
#  'smooth': 0.0,
#  'smuggle': 0.0,
#  'snack': 0.0,
#  'sneaking': 0.0,
#  'solve': 0.0,
#  'someone': 0.0,
#  'something': 0.03672396527064045,
#  'son': 0.0,
#  'sort': 0.0,
#  'soyer': 0.0,
#  'space': 0.0,
#  'spaces': 0.0,
#  'specific': 0.0,
#  'spend': 0.0,
#  'spending': 0.0,
#  'spent': 0.049378121887166365,
#  'spotify': 0.0,
#  'spread': 0.03672396527064045,
#  ...}

# %% [markdown]
# This still looks like a big mess, but we can see (a little more clearly) which word corresponds to which value for a given text in the matrix this way. Now I'm going to create a list of dictionaries like this for each of the our texts. I'm going to call it the ```pretty_tfidf_matrix```

# %%
pretty_tfidf_matrix = [dict(zip(tfidf_vectorization.get_feature_names(), tfidf_matrix[i])) for i in range(0, 10)]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# [{'000': 0.0,
#   '03': 0.0,
#   '10': 0.0,
#   '100': 0.0,
#   '118': 0.0,
#   '11pm': 0.0,
#   '129': 0.0,
#   '130': 0.0,
#   '14': 0.0,
#   '15': 0.0,
#   '150': 0.0,
#   '15bn': 0.0,
#   '16': 0.0,
#   '17': 0.0,
#   '19': 0.0,
#   '1950s': 0.0,
#   '1tn': 0.0,
#   '2009': 0.0,
#   '2013': 0.0,
#   '2014': 0.0,
#   '2015': 0.0,
#   '2016': 0.0,
#   '2018': 0.0,
#   '20s': 0.0,
#   '22': 0.0,
#   '232': 0.0,
#   '24': 0.0,
#   '25': 0.0,
#   '26': 0.0,
#   '29': 0.0,
#   '2pm': 0.0,
#   '30': 0.0,
#   '30s': 0.0,
#   '31': 0.0,
#   '34': 0.0,
#   '3d': 0.0,
#   '40': 0.0,
#   '400': 0.0,
#   '47': 0.0,
#   '500': 0.0,
#   '50km': 0.0,
#   '55': 0.0,
#   '58': 0.0,
#   '6am': 0.0,
#   '6bn': 0.0,
#   '71': 0.0,
#   '80': 0.0,
#   '86': 0.0,
#   '8bn': 0.0,
#   '940bn': 0.0,
#   '95': 0.0,
#   '963': 0.0,
#   '970bn': 0.0,
#   '995bn': 0.0,
#   '9pm': 0.0,
#   'ability': 0.0,
#   'able': 0.0,
#   'academy': 0.0,
#   'accelerate': 0.0,
#   'accent': 0.0,
#   'access': 0.0,
#   'accord': 0.0,
#   'according': 0.0,
#   'account': 0.0,
#   'accounting': 0.0,
#   'accurately': 0.0,
#   'across': 0.0,
#   'active': 0.0419759147882462,
#   'activity': 0.1468958610825618,
#   'add': 0.0,
#   'addiction': 0.0,
#   'additive': 0.0,
#   'adult': 0.0,
#   'after': 0.0,
#   'age': 0.049378121887166365,
#   'ago': 0.0,
#   'ahead': 0.0,
#   'ai': 0.0,
#   'aka': 0.0,
#   'alert': 0.0,
#   'alex': 0.0,
#   'alliance': 0.0,
#   'allow': 0.0,
#   'also': 0.0,
#   'always': 0.0,
#   'amazon': 0.0,
#   'amid': 0.0,
#   'among': 0.0,
#   'amount': 0.0,
#   'amsterdam': 0.0,
#   'an': 0.049378121887166365,
#   'analyse': 0.0,
#   'analysis': 0.0,
#   'analyst': 0.0,
#   'analyze': 0.0,
#   'ancestry': 0.0,
#   'ancient': 0.0,
#   'and': 0.0,
#   'angel': 0.0,
#   'annals': 0.0,
#   'another': 0.0,
#   'answer': 0.0,
#   'anxiety': 0.0,
#   'apple': 0.0,
#   'applies': 0.0,
#   'apply': 0.0,
#   'approach': 0.0,
#   'april': 0.0,
#   'archaic': 0.0,
#   'area': 0.09875624377433273,
#   'argentina': 0.0,
#   'aroeira': 0.0,
#   'around': 0.0,
#   'arrest': 0.0,
#   'artificial': 0.0,
#   'as': 0.0,
#   'asia': 0.0,
#   'ask': 0.0,
#   'assistant': 0.0,
#   'associate': 0.0,
#   'assume': 0.049378121887166365,
#   'at': 0.0,
#   'atypical': 0.0,
#   'author': 0.0,
#   'autistic': 0.0,
#   'average': 0.0,
#   'awake': 0.049378121887166365,
#   'aware': 0.0,
#   'away': 0.0,
#   'ax': 0.0,
#   'azealia': 0.0,
#   'back': 0.0,
#   'background': 0.0,
#   'bad': 0.0,
#   'bank': 0.0,
#   'banks': 0.0,
#   'bar': 0.0,
#   'base': 0.0,
#   'based': 0.0,
#   'beat': 0.0,
#   'become': 0.0,
#   'becomes': 0.0,
#   'before': 0.049378121887166365,
#   'befriend': 0.0,
#   'begin': 0.0,
#   'beginner': 0.0,
#   'behavior': 0.0,
#   'behaviour': 0.0,
#   'behind': 0.0,
#   'being': 0.0,
#   'believe': 0.0,
#   'belt': 0.0,
#   'benefit': 0.0,
#   'benign': 0.0,
#   'best': 0.0,
#   'better': 0.0,
#   'big': 0.0,
#   'binge': 0.0,
#   'black': 0.0,
#   'blood': 0.0,
#   'bloodline': 0.0,
#   'blue': 0.0,
#   'board': 0.0,
#   'boast': 0.0,
#   'body': 0.0,
#   'bojack': 0.0,
#   'bone': 0.0,
#   'boom': 0.0,
#   'boost': 0.0,
#   'boots': 0.0,
#   'borrowing': 0.0,
#   'boston': 0.0,
#   'brad': 0.0,
#   'brain': 0.11017189581192137,
#   'brazil': 0.0,
#   'break': 0.0419759147882462,
#   'breakdown': 0.049378121887166365,
#   'breakfast': 0.0,
#   'breaking': 0.0,
#   'brexit': 0.0,
#   'briefly': 0.0,
#   'bright': 0.0,
#   'bristol': 0.0,
#   'british': 0.0,
#   'broad': 0.0,
#   'broadly': 0.0,
#   'brow': 0.0,
#   'build': 0.0,
#   'bumper': 0.0,
#   'buoy': 0.0,
#   'business': 0.0,
#   'bust': 0.0,
#   'but': 0.03265023673867596,
#   'buzz': 0.049378121887166365,
#   'cadence': 0.0,
#   'california': 0.049378121887166365,
#   'call': 0.0,
#   'cancer': 0.0,
#   'capability': 0.0,
#   'capital': 0.0,
#   'capitalisation': 0.0,
#   'carilion': 0.0,
#   'carry': 0.0,
#   'case': 0.0,
#   'catch': 0.0,
#   'category': 0.0,
#   'cause': 0.0,
#   'caution': 0.0,
#   'cave': 0.0,
#   'cent': 0.0,
#   'central': 0.0,
#   'cerebral': 0.049378121887166365,
#   'certain': 0.0,
#   'cessation': 0.0,
#   'chance': 0.0,
#   'change': 0.0,
#   'chatter': 0.049378121887166365,
#   'checking': 0.0,
#   'checkpoint': 0.0,
#   'chief': 0.0,
#   'china': 0.0,
#   'choose': 0.0,
#   'christof': 0.049378121887166365,
#   'cigarette': 0.0,
#   'cigarettes': 0.0,
#   'cindy': 0.0,
#   'city': 0.0,
#   'classify': 0.0,
#   'clearly': 0.0,
#   'client': 0.0,
#   'clinical': 0.0,
#   'clock': 0.0,
#   'close': 0.0,
#   'cloud': 0.0,
#   'club': 0.0,
#   'clue': 0.0,
#   'cnn': 0.0,
#   'co': 0.0,
#   'coast': 0.0,
#   'coastal': 0.0,
#   'coastline': 0.0,
#   'cognitive': 0.049378121887166365,
#   'collaboration': 0.0,
#   'college': 0.0,
#   'combination': 0.0,
#   'come': 0.0,
#   'comedies': 0.0,
#   'comedy': 0.0,
#   'commerce': 0.0,
#   'commit': 0.0,
#   'communication': 0.1481343656614991,
#   'community': 0.0,
#   'company': 0.0,
#   'compare': 0.0,
#   'compete': 0.0,
#   'compute': 0.0,
#   'computer': 0.0,
#   'concern': 0.0,
#   'condition': 0.0,
#   'confederation': 0.0,
#   'confine': 0.0,
#   'connect': 0.0,
#   'connection': 0.0,
#   'conscious': 0.049378121887166365,
#   'consciouslike': 0.049378121887166365,
#   'consciousness': 0.2962687313229982,
#   'consumer': 0.0,
#   'contain': 0.0,
#   'content': 0.0,
#   'continue': 0.0419759147882462,
#   'contraband': 0.0,
#   'control': 0.0,
#   'controlled': 0.0,
#   'convincing': 0.0,
#   'convolutional': 0.0,
#   'coronavirus': 0.0,
#   'corporate': 0.0,
#   'correctly': 0.0,
#   'correlate': 0.049378121887166365,
#   'correspond': 0.049378121887166365,
#   'cortex': 0.34564685321016453,
#   'cost': 0.0,
#   'could': 0.0,
#   'counter': 0.0,
#   'country': 0.0,
#   'court': 0.0,
#   'courtroom': 0.0,
#   'cover': 0.0,
#   'create': 0.0,
#   'crime': 0.0,
#   'criminal': 0.0,
#   'current': 0.0419759147882462,
#   'currently': 0.0,
#   'customer': 0.0,
#   'da': 0.0,
#   'damage': 0.0,
#   'dangerous': 0.0,
#   'data': 0.0,
#   'date': 0.0,
#   'dated': 0.0,
#   'day': 0.0,
#   'death': 0.0,
#   'debate': 0.0,
#   'decline': 0.0,
#   'deep': 0.0,
#   'definitely': 0.049378121887166365,
#   'demand': 0.0,
#   'density': 0.049378121887166365,
#   'department': 0.0,
#   'depend': 0.0,
#   'depression': 0.0,
#   'dermatologist': 0.0,
#   'dermatologists': 0.0,
#   'detect': 0.0,
#   'detected': 0.0,
#   'detector': 0.0,
#   'develop': 0.049378121887166365,
#   'diagnosis': 0.0,
#   'diagnostics': 0.0,
#   'dial': 0.0,
#   'dictation': 0.0,
#   'diet': 0.0,
#   'differ': 0.0,
#   'difference': 0.0,
#   'different': 0.03672396527064045,
#   'differently': 0.0,
#   'difficult': 0.0,
#   'difficulty': 0.0,
#   'digital': 0.0,
#   'dip': 0.0,
#   'directly': 0.0,
#   'director': 0.0,
#   'discover': 0.0,
#   'disorder': 0.0,
#   'dispel': 0.0,
#   'distinctive': 0.0,
#   'distinguish': 0.0,
#   'division': 0.0,
#   'do': 0.0,
#   'documentary': 0.0,
#   'domestic': 0.0,
#   'dopamine': 0.0,
#   'downbeat': 0.0,
#   'dr': 0.0,
#   'drama': 0.0,
#   'dream': 0.049378121887166365,
#   'drinking': 0.0,
#   'drop': 0.0,
#   'drug': 0.0,
#   'during': 0.049378121887166365,
#   'earlier': 0.0,
#   'early': 0.03672396527064045,
#   'earn': 0.0,
#   'earning': 0.0,
#   'earth': 0.0,
#   'ease': 0.0,
#   'easily': 0.0,
#   'easy': 0.0,
#   'economic': 0.0,
#   'economy': 0.0,
#   'edge': 0.0,
#   'edit': 0.0,
#   'editorial': 0.0,
#   'eeg': 0.09875624377433273,
#   'effect': 0.0,
#   'effort': 0.0,
#   'electrical': 0.1481343656614991,
#   'electroencephalography': 0.049378121887166365,
#   'elicit': 0.09875624377433273,
#   'elliot': 0.0,
#   'emerge': 0.0,
#   'eminem': 0.0,
#   'enable': 0.0,
#   'encounter': 0.0,
#   'encourage': 0.0,
#   'engage': 0.0,
#   'england': 0.0,
#   'english': 0.0,
#   'ensure': 0.0,
#   'enter': 0.0,
#   'entire': 0.0,
#   'enunciation': 0.0,
#   'environment': 0.0,
#   'environmental': 0.0,
#   'environments': 0.0,
#   'episode': 0.0,
#   'equates': 0.049378121887166365,
#   'errors': 0.0,
#   'europe': 0.0,
#   'european': 0.0,
#   'even': 0.0,
#   'evening': 0.0,
#   'event': 0.0,
#   'eventually': 0.0,
#   'every': 0.0,
#   'everyone': 0.0,
#   'everything': 0.0,
#   'evidence': 0.0,
#   'evil': 0.0,
#   'evolve': 0.0,
#   'examination': 0.0,
#   'exception': 0.0,
#   'executive': 0.0,
#   'exeter': 0.0,
#   'expect': 0.0,
#   'expectation': 0.0,
#   'expected': 0.0,
#   'experience': 0.0734479305412809,
#   'experiment': 0.0419759147882462,
#   'expert': 0.0,
#   'explanation': 0.049378121887166365,
#   'export': 0.0,
#   'exports': 0.0,
#   'extinct': 0.0,
#   'eye': 0.049378121887166365,
#   'facebook': 0.0,
#   'factor': 0.0,
#   'factory': 0.0,
#   'fade': 0.049378121887166365,
#   'fair': 0.0,
#   'fall': 0.0,
#   'far': 0.0,
#   'fast': 0.0,
#   'faster': 0.0,
#   'favourite': 0.0,
#   'fear': 0.0,
#   'feature': 0.0,
#   'fed': 0.0,
#   'federal': 0.0,
#   'feel': 0.0,
#   'fell': 0.0,
#   'female': 0.0,
#   'few': 0.0,
#   'field': 0.0,
#   'figure': 0.0,
#   'figures': 0.0,
#   'find': 0.0,
#   'finding': 0.0419759147882462,
#   'finger': 0.0,
#   'finish': 0.0,
#   'fire': 0.0,
#   'firm': 0.0,
#   'firmly': 0.0,
#   'first': 0.0,
#   'fit': 0.0,
#   'five': 0.0,
#   'flow': 0.0,
#   'fmri': 0.0,
#   'focus': 0.0,
#   'focused': 0.0,
#   'follow': 0.0419759147882462,
#   'for': 0.0,
#   'force': 0.0,
#   'forecast': 0.0,
#   'form': 0.049378121887166365,
#   'forward': 0.0,
#   'fossil': 0.0,
#   'found': 0.0,
#   'four': 0.0,
#   'fourth': 0.0,
#   'fragile': 0.0,
#   'france': 0.0,
#   'free': 0.0,
#   'frontal': 0.09875624377433273,
#   'fuller': 0.0,
#   'functional': 0.0,
#   'functionality': 0.0,
#   'fuse': 0.0,
#   'future': 0.0,
#   'gain': 0.0419759147882462,
#   'garrett': 0.0,
#   'gather': 0.0,
#   'gdp': 0.0,
#   'generally': 0.0,
#   'genetic': 0.0,
#   'genre': 0.0,
#   'genus': 0.0,
#   'germany': 0.0,
#   'get': 0.0,
#   'gideon': 0.0,
#   'giulio': 0.049378121887166365,
#   'give': 0.0,
#   'go': 0.0,
#   'gone': 0.0,
#   'good': 0.0,
#   'google': 0.0,
#   'government': 0.0,
#   'grab': 0.0,
#   'grand': 0.0,
#   'great': 0.0,
#   'grocery': 0.0,
#   'group': 0.0,
#   'grow': 0.0,
#   'growth': 0.0,
#   'gruta': 0.0,
#   'guard': 0.0,
#   'guardian': 0.0,
#   'gur': 0.0,
#   'had': 0.0,
#   'haenssle': 0.0,
#   'half': 0.0,
#   'hand': 0.0,
#   'hands': 0.0,
#   'hard': 0.0,
#   'hardcore': 0.0,
#   'haze': 0.0,
#   'head': 0.03672396527064045,
#   'health': 0.0,
#   'heart': 0.0,
#   'heidelberg': 0.0,
#   'help': 0.0,
#   'high': 0.029321758171720298,
#   'hike': 0.0,
#   'hinge': 0.0,
#   'hip': 0.0,
#   'hoard': 0.0,
#   'hold': 0.0,
#   'holger': 0.0,
#   'holland': 0.0,
#   'homo': 0.0,
#   'hop': 0.0,
#   'horseman': 0.0,
#   'hot': 0.0,
#   'house': 0.0,
#   'housebuilding': 0.0,
#   'household': 0.0,
#   'households': 0.0,
#   'how': 0.0,
#   'human': 0.0,
#   'humans': 0.0,
#   'hundred': 0.0,
#   'hypnotize': 0.0,
#   'idea': 0.0419759147882462,
#   'identify': 0.0,
#   'if': 0.049378121887166365,
#   'illicit': 0.0,
#   'image': 0.0,
#   'imaging': 0.0,
#   'immoral': 0.0,
#   'implication': 0.049378121887166365,
#   'import': 0.0,
#   'important': 0.1259277443647386,
#   'improve': 0.0,
#   'improvement': 0.0,
#   'in': 0.0,
#   'include': 0.0,
#   'inclusive': 0.0,
#   'income': 0.0,
#   'increase': 0.0,
#   'increasingly': 0.0,
#   'indeed': 0.049378121887166365,
#   'index': 0.0,
#   'india': 0.0,
#   'induce': 0.049378121887166365,
#   'industry': 0.0,
#   'inequality': 0.0,
#   'information': 0.03672396527064045,
#   'ing': 0.0,
#   'innovation': 0.0,
#   'inside': 0.049378121887166365,
#   'insight': 0.049378121887166365,
#   'insitute': 0.0,
#   'instead': 0.0,
#   'institute': 0.049378121887166365,
#   'integration': 0.09875624377433273,
#   'intelligence': 0.0,
#   'intense': 0.0,
#   'intent': 0.0,
#   'interest': 0.0,
#   'interesting': 0.0,
#   'interfere': 0.0,
#   'introduce': 0.0,
#   'investigation': 0.0,
#   'investment': 0.0,
#   'involved': 0.0,
#   'ireland': 0.0,
#   'irresistible': 0.0,
#   'it': 0.0,
#   'january': 0.0,
#   'japanese': 0.0,
#   'jasper': 0.0,
#   'jo': 0.0,
#   'join': 0.0,
#   'jorien': 0.0,
#   'journal': 0.0,
#   'judge': 0.0,
#   'judith': 0.0,
#   'jump': 0.0,
#   'june': 0.0,
#   'jury': 0.0,
#   'just': 0.0,
#   'keen': 0.0,
#   'kick': 0.0,
#   'kilometre': 0.0,
#   'kind': 0.0,
#   'kingdom': 0.0,
#   'know': 0.0,
#   'koch': 0.049378121887166365,
#   'kroger': 0.0,
#   'lab': 0.0,
#   'laboratory': 0.0,
#   'large': 0.0,
#   'last': 0.0,
#   'late': 0.0419759147882462,
#   'laugh': 0.0,
#   'law': 0.0,
#   'lawler': 0.0,
#   'lawyer': 0.0,
#   'lead': 0.0,
#   'leading': 0.0,
#   'leap': 0.0,
#   'learning': 0.0,
#   'leave': 0.09875624377433273,
#   'lesion': 0.0,
#   'less': 0.0,
#   'level': 0.0,
#   'liane': 0.0,
#   'light': 0.0,
#   'like': 0.0,
#   'likely': 0.0,
#   'limitation': 0.0,
#   'line': 0.0,
#   'lines': 0.049378121887166365,
#   'link': 0.0,
#   'list': 0.0,
#   'little': 0.049378121887166365,
#   'live': 0.0,
#   'london': 0.0,
#   'loneliness': 0.0,
#   'lonely': 0.0,
#   'long': 0.0,
#   'look': 0.0,
#   'looked': 0.0,
#   'lose': 0.0,
#   'lot': 0.0,
#   'low': 0.0,
#   'lower': 0.0,
#   'lunch': 0.0,
#   'lunchtime': 0.0,
#   'lyric': 0.0,
#   'machine': 0.0,
#   'mad': 0.0,
#   'madison': 0.049378121887166365,
#   'magnetic': 0.0839518295764924,
#   'maintain': 0.0,
#   'major': 0.0,
#   'make': 0.0,
#   'maker': 0.0,
#   'making': 0.0,
#   'malignant': 0.0,
#   'manufacturing': 0.0,
#   'many': 0.0,
#   'mar': 0.0,
#   'march': 0.0,
#   'mark': 0.0,
#   'marked': 0.0,
#   'market': 0.0,
#   'master': 0.0,
#   'material': 0.0,
#   'mathew': 0.0,
#   'matter': 0.0,
#   'maximise': 0.0,
#   'may': 0.058643516343440595,
#   'mc': 0.0,
#   'meaning': 0.0,
#   'meaningful': 0.0,
#   'measure': 0.0,
#   'mechanical': 0.0,
#   'mechanism': 0.0,
#   'medical': 0.0,
#   'melanoma': 0.0,
#   'melbourne': 0.0,
#   'member': 0.0,
#   'men': 0.0,
#   'mendelian': 0.0,
#   'mental': 0.0,
#   'mesh': 0.0,
#   'metabolism': 0.049378121887166365,
#   'method': 0.0734479305412809,
#   'mic': 0.0,
#   'microphone': 0.0,
#   'microsoft': 0.0,
#   'mid': 0.0,
#   'midnight': 0.0,
#   'might': 0.0734479305412809,
#   'million': 0.0,
#   'minaj': 0.0,
#   'mirror': 0.0,
#   'misdiagnosed': 0.0,
#   'miss': 0.0,
#   'mix': 0.0,
#   'model': 0.0,
#   'modern': 0.049378121887166365,
#   'modest': 0.0,
#   'mole': 0.0,
#   'moment': 0.0,
#   'monash': 0.0,
#   'monetary': 0.0,
#   'monster': 0.0,
#   'montague': 0.0,
#   'month': 0.0,
#   'most': 0.0,
#   'mostly': 0.0,
#   'mouth': 0.0,
#   'movement': 0.049378121887166365,
#   'much': 0.03672396527064045,
#   'murderer': 0.0,
#   'mystery': 0.0419759147882462,
#   'nadella': 0.0,
#   'name': 0.0,
#   'nasdaq': 0.0,
#   'national': 0.0,
#   'neandertals': 0.0,
#   'near': 0.0,
#   'need': 0.0,
#   'negotiation': 0.0,
#   'neighbor': 0.049378121887166365,
#   'net': 0.0,
#   'netflix': 0.0,
#   'network': 0.0,
#   'neural': 0.1259277443647386,
#   'neuron': 0.049378121887166365,
#   'neuroscientist': 0.1259277443647386,
#   'neurotransmitter': 0.0,
#   'neutral': 0.0,
#   'never': 0.0,
#   'new': 0.0,
#   'newly': 0.0,
#   'newman': 0.0,
#   'news': 0.0,
#   'next': 0.0,
#   'nicki': 0.0,
#   'nicotine': 0.0,
#   'night': 0.0419759147882462,
#   'nod': 0.049378121887166365,
#   'nodded': 0.049378121887166365,
#   'non': 0.1481343656614991,
#   'none': 0.0,
#   'noon': 0.0,
#   'note': 0.0,
#   'notorious': 0.0,
#   'novel': 0.0,
#   'number': 0.0,
#   'observation': 0.0,
#   'observe': 0.0,
#   'occur': 0.0,
#   'offer': 0.0,
#   'offering': 0.0,
#   'often': 0.09875624377433273,
#   'old': 0.0419759147882462,
#   'on': 0.0,
#   'oncology': 0.0,
#   'one': 0.02406980865411455,
#   'orange': 0.0,
#   'order': 0.0,
#   'organisation': 0.0,
#   'original': 0.0,
#   'other': 0.0,
#   'our': 0.0,
#   'outlook': 0.0,
#   'outperform': 0.0,
#   'output': 0.0,
#   'outside': 0.0,
#   'overcame': 0.0,
#   'owls': 0.0,
#   'pace': 0.0,
#   'pandemic': 0.0,
#   'paper': 0.0,
#   'parietal': 0.049378121887166365,
#   'part': 0.03265023673867596,
#   'partial': 0.0,
#   'participant': 0.0,
#   'particularly': 0.0,
#   'pasadena': 0.049378121887166365,
#   'pastime': 0.0,
#   'patch': 0.049378121887166365,
#   'patient': 0.0,
#   'pattern': 0.03672396527064045,
#   'pause': 0.0,
#   'pennsylvania': 0.0,
#   'people': 0.05301513928360094,
#   'pepper': 0.0,
#   'per': 0.0,
#   'percentage': 0.0,
#   'perfect': 0.0,
#   'performance': 0.0,
#   'perhaps': 0.0,
#   'period': 0.0,
#   'person': 0.0,
#   'peter': 0.0,
#   'philadelphia': 0.0,
#   'philosopher': 0.0,
#   'photo': 0.0,
#   'picture': 0.0,
#   'pit': 0.0,
#   'pizza': 0.0,
#   'place': 0.0,
#   'planet': 0.0,
#   'play': 0.0,
#   'point': 0.0,
#   'policy': 0.0,
#   'poor': 0.0,
#   'poorer': 0.0,
#   'popular': 0.0,
#   'portfolio': 0.0,
#   'portion': 0.0,
#   'portugal': 0.0,
#   'posh': 0.0,
#   'possible': 0.0,
#   'potential': 0.0,
#   'potty': 0.0,
#   'predict': 0.049378121887166365,
#   'prefer': 0.0,
#   'president': 0.0,
#   'prestigious': 0.0,
#   'previous': 0.0,
#   'previously': 0.0,
#   'price': 0.0,
#   'primitive': 0.0,
#   'principle': 0.0,
#   'proceedings': 0.0,
#   'process': 0.0,
#   'producer': 0.0,
#   'product': 0.0,
#   'prof': 0.0,
#   'profit': 0.0,
#   'program': 0.0,
#   'programmer': 0.0,
#   'proof': 0.0,
#   'prospect': 0.0,
#   'protect': 0.0,
#   'protective': 0.0,
#   'prove': 0.0,
#   'proximity': 0.0,
#   'psychologist': 0.0,
#   'publicly': 0.0,
#   'publish': 0.0,
#   'published': 0.0,
#   'pulse': 0.049378121887166365,
#   'push': 0.0,
#   'put': 0.0,
#   'puzzle': 0.049378121887166365,
#   'quarter': 0.0,
#   'quarterly': 0.0,
#   'queensland': 0.0,
#   'quest': 0.0,
#   'question': 0.0,
#   'quit': 0.0,
#   'raise': 0.0,
#   'randomization': 0.0,
#   'range': 0.0,
#   'rap': 0.0,
#   'rapid': 0.0419759147882462,
#   'rapper': 0.0,
#   'rate': 0.0,
#   'raw': 0.0,
#   'read': 0.0,
#   'ready': 0.0,
#   'real': 0.0,
#   'really': 0.0,
#   'reason': 0.049378121887166365,
#   'reback': 0.0,
#   'recent': 0.0,
#   'recession': 0.0,
#   'reckless': 0.0,
#   'recklessness': 0.0,
#   'recognise': 0.0,
#   'recoil': 0.0,
#   'recommendation': 0.0,
#   'reconstruction': 0.0,
#   'record': 0.03672396527064045,
#   'reduce': 0.0,
#   'regardless': 0.0,
#   'region': 0.09875624377433273,
#   'relate': 0.0,
#   'related': 0.0,
#   'relationship': 0.0,
#   'release': 0.0,
#   'relevant': 0.0,
#   'rem': 0.1481343656614991,
#   'remain': 0.0,
#   'reminiscent': 0.0,
#   'remix': 0.0,
#   'removal': 0.0,
#   'repeat': 0.0419759147882462,
#   'replay': 0.0,
#   'report': 0.0879652745151609,
#   'reports': 0.0,
#   'required': 0.0,
#   'research': 0.02650756964180047,
#   'researcher': 0.058643516343440595,
#   'researchers': 0.0,
#   'resemble': 0.0,
#   'reserve': 0.0,
#   'resonance': 0.0,
#   'respondent': 0.0,
#   'response': 0.0,
#   'rest': 0.0,
#   'result': 0.0,
#   'reveal': 0.0,
#   'revenue': 0.0,
#   'revenues': 0.0,
#   'reverse': 0.0,
#   'rhyme': 0.0,
#   'ridge': 0.0,
#   'right': 0.09875624377433273,
#   'rise': 0.0,
#   'risk': 0.0,
#   'risky': 0.0,
#   'rival': 0.0,
#   'rizzo': 0.0,
#   'roanoke': 0.0,
#   'robyn': 0.0,
#   'rock': 0.0,
#   'rofl': 0.0,
#   'role': 0.0,
#   'round': 0.0,
#   'ruben': 0.0,
#   'rule': 0.049378121887166365,
#   'run': 0.0,
#   'sale': 0.0,
#   'sample': 0.0,
#   'satya': 0.0,
#   'say': 0.09998040061075028,
#   'scalp': 0.0,
#   'scan': 0.0,
#   'scenario': 0.0,
#   'schedule': 0.0,
#   'school': 0.0,
#   'science': 0.049378121887166365,
#   'sciences': 0.0,
#   'scientist': 0.0,
#   'scientists': 0.049378121887166365,
#   'screen': 0.0,
#   'sea': 0.0,
#   'second': 0.0,
#   'security': 0.0,
#   'see': 0.0,
#   'seem': 0.0,
#   'send': 0.0,
#   'senior': 0.0,
#   'sense': 0.0,
#   'sensitivity': 0.0,
#   'sequencing': 0.0,
#   'series': 0.0,
#   'service': 0.0,
#   'set': 0.0,
#   'several': 0.0,
#   'share': 0.0,
#   'shares': 0.0,
#   'sharply': 0.0,
#   'she': 0.0,
#   'shift': 0.0,
#   'show': 0.02650756964180047,
#   'shut': 0.049378121887166365,
#   'side': 0.049378121887166365,
#   'sign': 0.0419759147882462,
#   'similar': 0.049378121887166365,
#   'simple': 0.0,
#   'simply': 0.049378121887166365,
#   'simulate': 0.0,
#   'since': 0.03672396527064045,
#   'siri': 0.0,
#   'site': 0.049378121887166365,
#   'situation': 0.0,
#   'six': 0.03672396527064045,
#   'size': 0.0,
#   'skeewiff': 0.0,
#   'skilled': 0.0,
#   'skin': 0.0,
#   'skull': 0.0,
#   'sleep': 0.34564685321016453,
#   'sleepy': 0.049378121887166365,
#   'slow': 0.0,
#   'slowdown': 0.0,
#   'slowest': 0.0,
#   'slumber': 0.049378121887166365,
#   'slump': 0.0,
#   'sly': 0.0,
#   'small': 0.0419759147882462,
#   'smoke': 0.0,
#   'smoking': 0.0,
#   'smooth': 0.0,
#   'smuggle': 0.0,
#   'snack': 0.0,
#   'sneaking': 0.0,
#   'solve': 0.0,
#   'someone': 0.0,
#   'something': 0.03672396527064045,
#   'son': 0.0,
#   'sort': 0.0,
#   'soyer': 0.0,
#   'space': 0.0,
#   'spaces': 0.0,
#   'specific': 0.0,
#   'spend': 0.0,
#   'spending': 0.0,
#   'spent': 0.049378121887166365,
#   'spotify': 0.0,
#   'spread': 0.03672396527064045,
#   ...},
#  {'000': 0.07160053925435184,
#   '03': 0.0,
#   '10': 0.0,
#   '100': 0.0,
#   '118': 0.0,
#   '11pm': 0.0,
#   '129': 0.0,
#   '130': 0.0,
#   '14': 0.0,
#   '15': 0.0,
#   '150': 0.0,
#   '15bn': 0.0,
#   '16': 0.0,
#   '17': 0.0,
#   '19': 0.0,
#   '1950s': 0.0,
#   '1tn': 0.0,
#   '2009': 0.0,
#   '2013': 0.0,
#   '2014': 0.08422687563388637,
#   '2015': 0.0,
#   '2016': 0.0,
#   '2018': 0.0,
#   '20s': 0.0,
#   '22': 0.0,
#   '232': 0.0,
#   '24': 0.0,
#   '25': 0.0,
#   '26': 0.0,
#   '29': 0.0,
#   '2pm': 0.0,
#   '30': 0.0,
#   '30s': 0.0,
#   '31': 0.0,
#   '34': 0.0,
#   '3d': 0.08422687563388637,
#   '40': 0.0,
#   '400': 0.08422687563388637,
#   '47': 0.0,
#   '500': 0.0,
#   '50km': 0.0,
#   '55': 0.0,
#   '58': 0.0,
#   '6am': 0.0,
#   '6bn': 0.0,
#   '71': 0.0,
#   '80': 0.0,
#   '86': 0.0,
#   '8bn': 0.0,
#   '940bn': 0.0,
#   '95': 0.0,
#   '963': 0.0,
#   '970bn': 0.0,
#   '995bn': 0.0,
#   '9pm': 0.0,
#   'ability': 0.0,
#   'able': 0.0,
#   'academy': 0.07160053925435184,
#   'accelerate': 0.0,
#   'accent': 0.0,
#   'access': 0.0,
#   'accord': 0.08422687563388637,
#   'according': 0.0,
#   'account': 0.0,
#   'accounting': 0.0,
#   'accurately': 0.0,
#   'across': 0.0,
#   'active': 0.0,
#   'activity': 0.0,
#   'add': 0.0,
#   'addiction': 0.0,
#   'additive': 0.0,
#   'adult': 0.0,
#   'after': 0.0,
#   'age': 0.0,
#   'ago': 0.08422687563388637,
#   'ahead': 0.0,
#   'ai': 0.0,
#   'aka': 0.0,
#   'alert': 0.0,
#   'alex': 0.0,
#   'alliance': 0.0,
#   'allow': 0.0,
#   'also': 0.0,
#   'always': 0.0,
#   'amazon': 0.0,
#   'amid': 0.0,
#   'among': 0.0,
#   'amount': 0.0,
#   'amsterdam': 0.0,
#   'an': 0.0,
#   'analyse': 0.0,
#   'analysis': 0.0,
#   'analyst': 0.0,
#   'analyze': 0.0,
#   'ancestry': 0.08422687563388637,
#   'ancient': 0.08422687563388637,
#   'and': 0.07160053925435184,
#   'angel': 0.0,
#   'annals': 0.0,
#   'another': 0.07160053925435184,
#   'answer': 0.0,
#   'anxiety': 0.0,
#   'apple': 0.0,
#   'applies': 0.0,
#   'apply': 0.0,
#   'approach': 0.0,
#   'april': 0.0,
#   'archaic': 0.08422687563388637,
#   'area': 0.0,
#   'argentina': 0.0,
#   'aroeira': 0.08422687563388637,
#   'around': 0.0,
#   'arrest': 0.0,
#   'artificial': 0.0,
#   'as': 0.0,
#   'asia': 0.08422687563388637,
#   'ask': 0.0,
#   'assistant': 0.0,
#   'associate': 0.0,
#   'assume': 0.0,
#   'at': 0.0,
#   'atypical': 0.0,
#   'author': 0.0,
#   'autistic': 0.0,
#   'average': 0.0,
#   'awake': 0.0,
#   'aware': 0.0,
#   'away': 0.0,
#   'ax': 0.08422687563388637,
#   'azealia': 0.0,
#   'back': 0.0,
#   'background': 0.0,
#   'bad': 0.0,
#   'bank': 0.0,
#   'banks': 0.0,
#   'bar': 0.0,
#   'base': 0.0,
#   'based': 0.0,
#   'beat': 0.0,
#   'become': 0.0,
#   'becomes': 0.0,
#   'before': 0.0,
#   'befriend': 0.0,
#   'begin': 0.0,
#   'beginner': 0.0,
#   'behavior': 0.0,
#   'behaviour': 0.0,
#   'behind': 0.0,
#   'being': 0.0,
#   'believe': 0.0,
#   'belt': 0.0,
#   'benefit': 0.0,
#   'benign': 0.0,
#   'best': 0.0,
#   'better': 0.0,
#   'big': 0.0,
#   'binge': 0.0,
#   'black': 0.0,
#   'blood': 0.0,
#   'bloodline': 0.0,
#   'blue': 0.0,
#   'board': 0.0,
#   'boast': 0.0,
#   'body': 0.0,
#   'bojack': 0.0,
#   'bone': 0.0,
#   'boom': 0.0,
#   'boost': 0.0,
#   'boots': 0.0,
#   'borrowing': 0.0,
#   'boston': 0.0,
#   'brad': 0.0,
#   'brain': 0.0,
#   'brazil': 0.0,
#   'break': 0.0,
#   'breakdown': 0.0,
#   'breakfast': 0.0,
#   'breaking': 0.0,
#   'brexit': 0.0,
#   'briefly': 0.0,
#   'bright': 0.0,
#   'bristol': 0.0,
#   'british': 0.0,
#   'broad': 0.0,
#   'broadly': 0.0,
#   'brow': 0.08422687563388637,
#   'build': 0.0,
#   'bumper': 0.0,
#   'buoy': 0.0,
#   'business': 0.0,
#   'bust': 0.0,
#   'but': 0.0556932366826239,
#   'buzz': 0.0,
#   'cadence': 0.0,
#   'california': 0.0,
#   'call': 0.0,
#   'cancer': 0.0,
#   'capability': 0.0,
#   'capital': 0.0,
#   'capitalisation': 0.0,
#   'carilion': 0.0,
#   'carry': 0.0,
#   'case': 0.0,
#   'catch': 0.0,
#   'category': 0.0,
#   'cause': 0.0,
#   'caution': 0.0,
#   'cave': 0.08422687563388637,
#   'cent': 0.0,
#   'central': 0.07160053925435184,
#   'cerebral': 0.0,
#   'certain': 0.0,
#   'cessation': 0.0,
#   'chance': 0.0,
#   'change': 0.0,
#   'chatter': 0.0,
#   'checking': 0.0,
#   'checkpoint': 0.0,
#   'chief': 0.0,
#   'china': 0.0,
#   'choose': 0.0,
#   'christof': 0.0,
#   'cigarette': 0.0,
#   'cigarettes': 0.0,
#   'cindy': 0.0,
#   'city': 0.0,
#   'classify': 0.0,
#   'clearly': 0.0,
#   'client': 0.0,
#   'clinical': 0.0,
#   'clock': 0.0,
#   'close': 0.0,
#   'cloud': 0.0,
#   'club': 0.0,
#   'clue': 0.08422687563388637,
#   'cnn': 0.0,
#   'co': 0.0,
#   'coast': 0.0,
#   'coastal': 0.0,
#   'coastline': 0.0,
#   'cognitive': 0.0,
#   'collaboration': 0.0,
#   'college': 0.0,
#   'combination': 0.08422687563388637,
#   'come': 0.0,
#   'comedies': 0.0,
#   'comedy': 0.0,
#   'commerce': 0.0,
#   'commit': 0.0,
#   'communication': 0.0,
#   'community': 0.0,
#   'company': 0.0,
#   'compare': 0.0,
#   'compete': 0.0,
#   'compute': 0.0,
#   'computer': 0.0,
#   'concern': 0.0,
#   'condition': 0.0,
#   'confederation': 0.0,
#   'confine': 0.0,
#   'connect': 0.0,
#   'connection': 0.0,
#   'conscious': 0.0,
#   'consciouslike': 0.0,
#   'consciousness': 0.0,
#   'consumer': 0.0,
#   'contain': 0.0,
#   'content': 0.0,
#   'continue': 0.0,
#   'contraband': 0.0,
#   'control': 0.0,
#   'controlled': 0.0,
#   'convincing': 0.0,
#   'convolutional': 0.0,
#   'coronavirus': 0.0,
#   'corporate': 0.0,
#   'correctly': 0.0,
#   'correlate': 0.0,
#   'correspond': 0.0,
#   'cortex': 0.0,
#   'cost': 0.0,
#   'could': 0.0,
#   'counter': 0.0,
#   'country': 0.0,
#   'court': 0.0,
#   'courtroom': 0.0,
#   'cover': 0.0,
#   'create': 0.0,
#   'crime': 0.0,
#   'criminal': 0.0,
#   'current': 0.0,
#   'currently': 0.0,
#   'customer': 0.0,
#   'da': 0.08422687563388637,
#   'damage': 0.0,
#   'dangerous': 0.0,
#   'data': 0.0,
#   'date': 0.08422687563388637,
#   'dated': 0.08422687563388637,
#   'day': 0.0,
#   'death': 0.0,
#   'debate': 0.08422687563388637,
#   'decline': 0.0,
#   'deep': 0.0,
#   'definitely': 0.0,
#   'demand': 0.0,
#   'density': 0.0,
#   'department': 0.0,
#   'depend': 0.0,
#   'depression': 0.0,
#   'dermatologist': 0.0,
#   'dermatologists': 0.0,
#   'detect': 0.0,
#   'detected': 0.0,
#   'detector': 0.0,
#   'develop': 0.0,
#   'diagnosis': 0.0,
#   'diagnostics': 0.0,
#   'dial': 0.0,
#   'dictation': 0.0,
#   'diet': 0.0,
#   'differ': 0.0,
#   'difference': 0.0,
#   'different': 0.12528402204934086,
#   'differently': 0.0,
#   'difficult': 0.0,
#   'difficulty': 0.0,
#   'digital': 0.0,
#   'dip': 0.0,
#   'directly': 0.0,
#   'director': 0.0,
#   'discover': 0.08422687563388637,
#   'disorder': 0.0,
#   'dispel': 0.0,
#   'distinctive': 0.0,
#   'distinguish': 0.0,
#   'division': 0.0,
#   'do': 0.0,
#   'documentary': 0.0,
#   'domestic': 0.0,
#   'dopamine': 0.0,
#   'downbeat': 0.0,
#   'dr': 0.0,
#   'drama': 0.0,
#   'dream': 0.0,
#   'drinking': 0.0,
#   'drop': 0.0,
#   'drug': 0.0,
#   'during': 0.0,
#   'earlier': 0.0,
#   'early': 0.0,
#   'earn': 0.0,
#   'earning': 0.0,
#   'earth': 0.0,
#   'ease': 0.0,
#   'easily': 0.0,
#   'easy': 0.0,
#   'economic': 0.0,
#   'economy': 0.0,
#   'edge': 0.0,
#   'edit': 0.0,
#   'editorial': 0.0,
#   'eeg': 0.0,
#   'effect': 0.0,
#   'effort': 0.0,
#   'electrical': 0.0,
#   'electroencephalography': 0.0,
#   'elicit': 0.0,
#   'elliot': 0.0,
#   'emerge': 0.0,
#   'eminem': 0.0,
#   'enable': 0.0,
#   'encounter': 0.0,
#   'encourage': 0.0,
#   'engage': 0.0,
#   'england': 0.0,
#   'english': 0.0,
#   'ensure': 0.0,
#   'enter': 0.0,
#   'entire': 0.0,
#   'enunciation': 0.0,
#   'environment': 0.0,
#   'environmental': 0.0,
#   'environments': 0.0,
#   'episode': 0.0,
#   'equates': 0.0,
#   'errors': 0.0,
#   'europe': 0.2526806269016591,
#   'european': 0.0,
#   'even': 0.0,
#   'evening': 0.0,
#   'event': 0.0,
#   'eventually': 0.16845375126777273,
#   'every': 0.0,
#   'everyone': 0.0,
#   'everything': 0.0,
#   'evidence': 0.0,
#   'evil': 0.0,
#   'evolve': 0.16845375126777273,
#   'examination': 0.0,
#   'exception': 0.0,
#   'executive': 0.0,
#   'exeter': 0.0,
#   'expect': 0.0,
#   'expectation': 0.0,
#   'expected': 0.0,
#   'experience': 0.0,
#   'experiment': 0.0,
#   'expert': 0.0,
#   'explanation': 0.0,
#   'export': 0.0,
#   'exports': 0.0,
#   'extinct': 0.08422687563388637,
#   'eye': 0.0,
#   'facebook': 0.0,
#   'factor': 0.0,
#   'factory': 0.0,
#   'fade': 0.0,
#   'fair': 0.0,
#   'fall': 0.0,
#   'far': 0.0,
#   'fast': 0.0,
#   'faster': 0.0,
#   'favourite': 0.0,
#   'fear': 0.0,
#   'feature': 0.14320107850870367,
#   'fed': 0.0,
#   'federal': 0.0,
#   'feel': 0.0,
#   'fell': 0.0,
#   'female': 0.0,
#   'few': 0.0,
#   'field': 0.0,
#   'figure': 0.0,
#   'figures': 0.0,
#   'find': 0.0,
#   'finding': 0.0,
#   'finger': 0.0,
#   'finish': 0.0,
#   'fire': 0.0,
#   'firm': 0.0,
#   'firmly': 0.08422687563388637,
#   'first': 0.0,
#   'fit': 0.0,
#   'five': 0.0,
#   'flow': 0.0,
#   'fmri': 0.0,
#   'focus': 0.0,
#   'focused': 0.0,
#   'follow': 0.0,
#   'for': 0.0,
#   'force': 0.0,
#   'forecast': 0.0,
#   'form': 0.0,
#   'forward': 0.0,
#   'fossil': 0.2526806269016591,
#   'found': 0.08422687563388637,
#   'four': 0.0,
#   'fourth': 0.0,
#   'fragile': 0.0,
#   'france': 0.0,
#   'free': 0.0,
#   'frontal': 0.0,
#   'fuller': 0.0,
#   'functional': 0.0,
#   'functionality': 0.0,
#   'fuse': 0.08422687563388637,
#   'future': 0.0,
#   'gain': 0.0,
#   'garrett': 0.0,
#   'gather': 0.0,
#   'gdp': 0.0,
#   'generally': 0.0,
#   'genetic': 0.0,
#   'genre': 0.0,
#   'genus': 0.16845375126777273,
#   'germany': 0.0,
#   'get': 0.0,
#   'gideon': 0.0,
#   'giulio': 0.0,
#   'give': 0.0,
#   'go': 0.0,
#   'gone': 0.0,
#   'good': 0.0,
#   'google': 0.0,
#   'government': 0.0,
#   'grab': 0.0,
#   'grand': 0.0,
#   'great': 0.0,
#   'grocery': 0.0,
#   'group': 0.0,
#   'grow': 0.0,
#   'growth': 0.0,
#   'gruta': 0.08422687563388637,
#   'guard': 0.0,
#   'guardian': 0.0,
#   'gur': 0.0,
#   'had': 0.0,
#   'haenssle': 0.0,
#   'half': 0.07160053925435184,
#   'hand': 0.08422687563388637,
#   'hands': 0.0,
#   'hard': 0.0,
#   'hardcore': 0.0,
#   'haze': 0.0,
#   'head': 0.0,
#   'health': 0.0,
#   'heart': 0.0,
#   'heidelberg': 0.0,
#   'help': 0.1113864733652478,
#   'high': 0.0,
#   'hike': 0.0,
#   'hinge': 0.0,
#   'hip': 0.0,
#   'hoard': 0.0,
#   'hold': 0.0,
#   'holger': 0.0,
#   'holland': 0.0,
#   'homo': 0.08422687563388637,
#   'hop': 0.0,
#   'horseman': 0.0,
#   'hot': 0.0,
#   'house': 0.0,
#   'housebuilding': 0.0,
#   'household': 0.0,
#   'households': 0.0,
#   'how': 0.0,
#   'human': 0.0,
#   'humans': 0.08422687563388637,
#   'hundred': 0.0,
#   'hypnotize': 0.0,
#   'idea': 0.0,
#   'identify': 0.0,
#   'if': 0.0,
#   'illicit': 0.0,
#   'image': 0.0,
#   'imaging': 0.0,
#   'immoral': 0.0,
#   'implication': 0.0,
#   'import': 0.0,
#   'important': 0.0,
#   'improve': 0.0,
#   'improvement': 0.0,
#   'in': 0.0,
#   'include': 0.0,
#   'inclusive': 0.0,
#   'income': 0.0,
#   'increase': 0.0,
#   'increasingly': 0.0,
#   'indeed': 0.0,
#   'index': 0.0,
#   'india': 0.0,
#   'induce': 0.0,
#   'industry': 0.0,
#   'inequality': 0.0,
#   'information': 0.0,
#   'ing': 0.0,
#   'innovation': 0.0,
#   'inside': 0.0,
#   'insight': 0.0,
#   'insitute': 0.0,
#   'instead': 0.0,
#   'institute': 0.0,
#   'integration': 0.0,
#   'intelligence': 0.0,
#   'intense': 0.08422687563388637,
#   'intent': 0.0,
#   'interest': 0.0,
#   'interesting': 0.0,
#   'interfere': 0.0,
#   'introduce': 0.0,
#   'investigation': 0.0,
#   'investment': 0.0,
#   'involved': 0.0,
#   'ireland': 0.0,
#   'irresistible': 0.0,
#   'it': 0.050015674645135906,
#   'january': 0.0,
#   'japanese': 0.0,
#   'jasper': 0.0,
#   'jo': 0.0,
#   'join': 0.0,
#   'jorien': 0.0,
#   'journal': 0.0,
#   'judge': 0.0,
#   'judith': 0.0,
#   'jump': 0.0,
#   'june': 0.0,
#   'jury': 0.0,
#   'just': 0.0,
#   'keen': 0.0,
#   'kick': 0.0,
#   'kilometre': 0.0,
#   'kind': 0.0,
#   'kingdom': 0.0,
#   'know': 0.0,
#   'koch': 0.0,
#   'kroger': 0.0,
#   'lab': 0.0,
#   'laboratory': 0.0,
#   'large': 0.0,
#   'last': 0.0,
#   'late': 0.0,
#   'laugh': 0.0,
#   'law': 0.0,
#   'lawler': 0.0,
#   'lawyer': 0.0,
#   'lead': 0.0,
#   'leading': 0.0,
#   'leap': 0.0,
#   'learning': 0.0,
#   'leave': 0.0,
#   'lesion': 0.0,
#   'less': 0.0,
#   'level': 0.0,
#   'liane': 0.0,
#   'light': 0.0,
#   'like': 0.0,
#   'likely': 0.0,
#   'limitation': 0.0,
#   'line': 0.0,
#   'lines': 0.0,
#   'link': 0.07160053925435184,
#   'list': 0.0,
#   'little': 0.0,
#   'live': 0.0,
#   'london': 0.0,
#   'loneliness': 0.0,
#   'lonely': 0.0,
#   'long': 0.0,
#   'look': 0.0,
#   'looked': 0.0,
#   'lose': 0.0,
#   'lot': 0.0,
#   'low': 0.0,
#   'lower': 0.0,
#   'lunch': 0.0,
#   'lunchtime': 0.0,
#   'lyric': 0.0,
#   'machine': 0.0,
#   'mad': 0.0,
#   'madison': 0.0,
#   'magnetic': 0.0,
#   'maintain': 0.0,
#   'major': 0.0,
#   'make': 0.0,
#   'maker': 0.0,
#   'making': 0.0,
#   'malignant': 0.0,
#   'manufacturing': 0.0,
#   'many': 0.0,
#   'mar': 0.0,
#   'march': 0.0,
#   'mark': 0.0,
#   'marked': 0.0,
#   'market': 0.0,
#   'master': 0.0,
#   'material': 0.0,
#   'mathew': 0.0,
#   'matter': 0.0,
#   'maximise': 0.0,
#   'may': 0.050015674645135906,
#   'mc': 0.0,
#   'meaning': 0.0,
#   'meaningful': 0.0,
#   'measure': 0.0,
#   'mechanical': 0.0,
#   'mechanism': 0.0,
#   'medical': 0.0,
#   'melanoma': 0.0,
#   'melbourne': 0.0,
#   'member': 0.14320107850870367,
#   'men': 0.0,
#   'mendelian': 0.0,
#   'mental': 0.0,
#   'mesh': 0.0,
#   'metabolism': 0.0,
#   'method': 0.0,
#   'mic': 0.0,
#   'microphone': 0.0,
#   'microsoft': 0.0,
#   'mid': 0.0,
#   'midnight': 0.0,
#   'might': 0.0,
#   'million': 0.07160053925435184,
#   'minaj': 0.0,
#   'mirror': 0.0,
#   'misdiagnosed': 0.0,
#   'miss': 0.0,
#   'mix': 0.07160053925435184,
#   'model': 0.0,
#   'modern': 0.0,
#   'modest': 0.0,
#   'mole': 0.0,
#   'moment': 0.0,
#   'monash': 0.0,
#   'monetary': 0.0,
#   'monster': 0.0,
#   'montague': 0.0,
#   'month': 0.0,
#   'most': 0.0,
#   'mostly': 0.0,
#   'mouth': 0.0,
#   'movement': 0.0,
#   'much': 0.0,
#   'murderer': 0.0,
#   'mystery': 0.07160053925435184,
#   'nadella': 0.0,
#   'name': 0.0,
#   'nasdaq': 0.0,
#   'national': 0.07160053925435184,
#   'neandertals': 0.33690750253554547,
#   'near': 0.0,
#   'need': 0.0,
#   'negotiation': 0.0,
#   'neighbor': 0.0,
#   'net': 0.0,
#   'netflix': 0.0,
#   'network': 0.0,
#   'neural': 0.0,
#   'neuron': 0.0,
#   'neuroscientist': 0.0,
#   'neurotransmitter': 0.0,
#   'neutral': 0.0,
#   'never': 0.0,
#   'new': 0.07477867653120275,
#   'newly': 0.08422687563388637,
#   'newman': 0.0,
#   'news': 0.0,
#   'next': 0.0,
#   'nicki': 0.0,
#   'nicotine': 0.0,
#   'night': 0.0,
#   'nod': 0.0,
#   'nodded': 0.0,
#   'non': 0.0,
#   'none': 0.0,
#   'noon': 0.0,
#   'note': 0.0,
#   'notorious': 0.0,
#   'novel': 0.0,
#   'number': 0.0,
#   'observation': 0.0,
#   'observe': 0.0,
#   'occur': 0.0,
#   'offer': 0.0,
#   'offering': 0.08422687563388637,
#   'often': 0.0,
#   'old': 0.07160053925435184,
#   'on': 0.0,
#   'oncology': 0.0,
#   'one': 0.082114292830909,
#   'orange': 0.0,
#   'order': 0.0,
#   'organisation': 0.0,
#   'original': 0.0,
#   'other': 0.08422687563388637,
#   'our': 0.0,
#   'outlook': 0.0,
#   'outperform': 0.0,
#   'output': 0.0,
#   'outside': 0.0,
#   'overcame': 0.0,
#   'owls': 0.0,
#   'pace': 0.0,
#   'pandemic': 0.0,
#   'paper': 0.0,
#   'parietal': 0.0,
#   'part': 0.0,
#   'partial': 0.08422687563388637,
#   'participant': 0.0,
#   'particularly': 0.0,
#   'pasadena': 0.0,
#   'pastime': 0.0,
#   'patch': 0.0,
#   'patient': 0.0,
#   'pattern': 0.0,
#   'pause': 0.0,
#   'pennsylvania': 0.0,
#   'people': 0.0,
#   'pepper': 0.0,
#   'per': 0.0,
#   'percentage': 0.0,
#   'perfect': 0.0,
#   'performance': 0.0,
#   'perhaps': 0.0,
#   'period': 0.0,
#   'person': 0.0,
#   'peter': 0.0,
#   'philadelphia': 0.0,
#   'philosopher': 0.0,
#   'photo': 0.0,
#   'picture': 0.08422687563388637,
#   'pit': 0.0,
#   'pizza': 0.0,
#   'place': 0.0,
#   'planet': 0.0,
#   'play': 0.0,
#   'point': 0.0,
#   'policy': 0.0,
#   'poor': 0.0,
#   'poorer': 0.0,
#   'popular': 0.0,
#   'portfolio': 0.0,
#   'portion': 0.0,
#   'portugal': 0.08422687563388637,
#   'posh': 0.0,
#   'possible': 0.0,
#   'potential': 0.0,
#   'potty': 0.0,
#   'predict': 0.0,
#   'prefer': 0.0,
#   'president': 0.0,
#   'prestigious': 0.0,
#   'previous': 0.0,
#   'previously': 0.0,
#   'price': 0.0,
#   'primitive': 0.08422687563388637,
#   'principle': 0.0,
#   'proceedings': 0.07160053925435184,
#   'process': 0.0,
#   'producer': 0.0,
#   'product': 0.0,
#   'prof': 0.0,
#   'profit': 0.0,
#   'program': 0.0,
#   'programmer': 0.0,
#   'proof': 0.0,
#   'prospect': 0.0,
#   'protect': 0.0,
#   'protective': 0.0,
#   'prove': 0.0,
#   'proximity': 0.0,
#   'psychologist': 0.0,
#   'publicly': 0.0,
#   'publish': 0.06264201102467043,
#   'published': 0.0,
#   'pulse': 0.0,
#   'push': 0.0,
#   'put': 0.0,
#   'puzzle': 0.0,
#   'quarter': 0.0,
#   'quarterly': 0.0,
#   'queensland': 0.0,
#   'quest': 0.0,
#   'question': 0.0,
#   'quit': 0.0,
#   'raise': 0.0,
#   'randomization': 0.0,
#   'range': 0.0,
#   'rap': 0.0,
#   'rapid': 0.0,
#   'rapper': 0.0,
#   'rate': 0.0,
#   'raw': 0.0,
#   'read': 0.0,
#   'ready': 0.0,
#   'real': 0.0,
#   'really': 0.0,
#   'reason': 0.0,
#   'reback': 0.0,
#   'recent': 0.0,
#   'recession': 0.0,
#   'reckless': 0.0,
#   'recklessness': 0.0,
#   'recognise': 0.0,
#   'recoil': 0.0,
#   'recommendation': 0.0,
#   'reconstruction': 0.08422687563388637,
#   'record': 0.0,
#   'reduce': 0.0,
#   'regardless': 0.0,
#   'region': 0.0,
#   'relate': 0.08422687563388637,
#   'related': 0.0,
#   'relationship': 0.0,
#   'release': 0.0,
#   'relevant': 0.0,
#   'rem': 0.0,
#   'remain': 0.0,
#   'reminiscent': 0.0,
#   'remix': 0.0,
#   'removal': 0.0,
#   'repeat': 0.0,
#   'replay': 0.0,
#   'report': 0.0,
#   'reports': 0.0,
#   'required': 0.0,
#   'research': 0.0,
#   'researcher': 0.050015674645135906,
#   'researchers': 0.0,
#   'resemble': 0.08422687563388637,
#   'reserve': 0.0,
#   'resonance': 0.0,
#   'respondent': 0.0,
#   'response': 0.0,
#   'rest': 0.0,
#   'result': 0.0,
#   'reveal': 0.0,
#   'revenue': 0.0,
#   'revenues': 0.0,
#   'reverse': 0.0,
#   'rhyme': 0.0,
#   'ridge': 0.08422687563388637,
#   'right': 0.0,
#   'rise': 0.0,
#   'risk': 0.0,
#   'risky': 0.0,
#   'rival': 0.0,
#   'rizzo': 0.0,
#   'roanoke': 0.0,
#   'robyn': 0.0,
#   'rock': 0.0,
#   'rofl': 0.0,
#   'role': 0.0,
#   'round': 0.0,
#   'ruben': 0.0,
#   'rule': 0.0,
#   'run': 0.0,
#   'sale': 0.0,
#   'sample': 0.0,
#   'satya': 0.0,
#   'say': 0.0,
#   'scalp': 0.0,
#   'scan': 0.0,
#   'scenario': 0.0,
#   'schedule': 0.0,
#   'school': 0.0,
#   'science': 0.0,
#   'sciences': 0.07160053925435184,
#   'scientist': 0.0,
#   'scientists': 0.0,
#   'screen': 0.0,
#   'sea': 0.0,
#   'second': 0.0,
#   'security': 0.0,
#   'see': 0.06264201102467043,
#   'seem': 0.0,
#   'send': 0.0,
#   'senior': 0.0,
#   'sense': 0.0,
#   'sensitivity': 0.0,
#   'sequencing': 0.0,
#   'series': 0.0,
#   'service': 0.0,
#   'set': 0.0,
#   'several': 0.07160053925435184,
#   'share': 0.0,
#   'shares': 0.0,
#   'sharply': 0.0,
#   'she': 0.0,
#   'shift': 0.0,
#   'show': 0.04521536434047297,
#   'shut': 0.0,
#   'side': 0.0,
#   'sign': 0.0,
#   'similar': 0.0,
#   'simple': 0.0,
#   'simply': 0.0,
#   'simulate': 0.0,
#   'since': 0.0,
#   'siri': 0.0,
#   'site': 0.0,
#   'situation': 0.0,
#   'six': 0.0,
#   'size': 0.0,
#   'skeewiff': 0.0,
#   'skilled': 0.0,
#   'skin': 0.0,
#   'skull': 0.33690750253554547,
#   'sleep': 0.0,
#   'sleepy': 0.0,
#   'slow': 0.0,
#   'slowdown': 0.0,
#   'slowest': 0.0,
#   'slumber': 0.0,
#   'slump': 0.0,
#   'sly': 0.0,
#   'small': 0.0,
#   'smoke': 0.0,
#   'smoking': 0.0,
#   'smooth': 0.0,
#   'smuggle': 0.0,
#   'snack': 0.0,
#   'sneaking': 0.0,
#   'solve': 0.08422687563388637,
#   'someone': 0.0,
#   'something': 0.0,
#   'son': 0.0,
#   'sort': 0.08422687563388637,
#   'soyer': 0.0,
#   'space': 0.0,
#   'spaces': 0.0,
#   'specific': 0.0,
#   'spend': 0.0,
#   'spending': 0.0,
#   'spent': 0.0,
#   'spotify': 0.0,
#   'spread': 0.06264201102467043,
#   ...},
#  {'000': 0.0,
#   '03': 0.0,
#   '10': 0.0,
#   '100': 0.0,
#   '118': 0.0,
#   '11pm': 0.0,
#   '129': 0.0,
#   '130': 0.0,
#   '14': 0.0,
#   '15': 0.0,
#   '150': 0.0,
#   '15bn': 0.0,
#   '16': 0.0,
#   '17': 0.0,
#   '19': 0.0,
#   '1950s': 0.0,
#   '1tn': 0.0,
#   '2009': 0.0,
#   '2013': 0.0,
#   '2014': 0.0,
#   '2015': 0.0,
#   '2016': 0.0,
#   '2018': 0.0,
#   '20s': 0.0,
#   '22': 0.03697694624936277,
#   '232': 0.0,
#   '24': 0.0,
#   '25': 0.03697694624936277,
#   '26': 0.0,
#   '29': 0.0,
#   '2pm': 0.0,
#   '30': 0.0,
#   '30s': 0.0,
#   '31': 0.0,
#   '34': 0.0,
#   '3d': 0.0,
#   '40': 0.03697694624936277,
#   '400': 0.0,
#   '47': 0.0,
#   '500': 0.0,
#   '50km': 0.08699522896056079,
#   '55': 0.0,
#   '58': 0.0,
#   '6am': 0.0,
#   '6bn': 0.0,
#   '71': 0.0,
#   '80': 0.0,
#   '86': 0.0,
#   '8bn': 0.0,
#   '940bn': 0.0,
#   '95': 0.0,
#   '963': 0.043497614480280396,
#   '970bn': 0.0,
#   '995bn': 0.0,
#   '9pm': 0.0,
#   'ability': 0.0,
#   'able': 0.0,
#   'academy': 0.0,
#   'accelerate': 0.0,
#   'accent': 0.0,
#   'access': 0.13049284344084117,
#   'accord': 0.0,
#   'according': 0.043497614480280396,
#   'account': 0.03235045851237,
#   'accounting': 0.0,
#   'accurately': 0.0,
#   'across': 0.0,
#   'active': 0.0,
#   'activity': 0.0,
#   'add': 0.028761875828208317,
#   'addiction': 0.0,
#   'additive': 0.0,
#   'adult': 0.043497614480280396,
#   'after': 0.043497614480280396,
#   'age': 0.0,
#   'ago': 0.0,
#   'ahead': 0.0,
#   'ai': 0.0,
#   'aka': 0.0,
#   'alert': 0.0,
#   'alex': 0.0,
#   'alliance': 0.0,
#   'allow': 0.0,
#   'also': 0.0,
#   'always': 0.0,
#   'amazon': 0.0,
#   'amid': 0.0,
#   'among': 0.0,
#   'amount': 0.03697694624936277,
#   'amsterdam': 0.0,
#   'an': 0.0,
#   'analyse': 0.0,
#   'analysis': 0.0,
#   'analyst': 0.0,
#   'analyze': 0.0,
#   'ancestry': 0.0,
#   'ancient': 0.0,
#   'and': 0.0,
#   'angel': 0.0,
#   'annals': 0.0,
#   'another': 0.0,
#   'answer': 0.0,
#   'anxiety': 0.043497614480280396,
#   'apple': 0.0,
#   'applies': 0.0,
#   'apply': 0.0,
#   'approach': 0.0,
#   'april': 0.0,
#   'archaic': 0.0,
#   'area': 0.0,
#   'argentina': 0.0,
#   'aroeira': 0.0,
#   'around': 0.09705137553711,
#   'arrest': 0.0,
#   'artificial': 0.0,
#   'as': 0.0,
#   'asia': 0.0,
#   'ask': 0.0,
#   'assistant': 0.0,
#   'associate': 0.0,
#   'assume': 0.0,
#   'at': 0.0,
#   'atypical': 0.0,
#   'author': 0.0,
#   'autistic': 0.0,
#   'average': 0.0,
#   'awake': 0.0,
#   'aware': 0.0,
#   'away': 0.1109308387480883,
#   'ax': 0.0,
#   'azealia': 0.0,
#   'back': 0.0,
#   'background': 0.043497614480280396,
#   'bad': 0.0,
#   'bank': 0.0,
#   'banks': 0.0,
#   'bar': 0.0,
#   'base': 0.0,
#   'based': 0.0,
#   'beat': 0.0,
#   'become': 0.0,
#   'becomes': 0.0,
#   'before': 0.0,
#   'befriend': 0.0,
#   'begin': 0.0,
#   'beginner': 0.0,
#   'behavior': 0.0,
#   'behaviour': 0.0,
#   'behind': 0.0,
#   'being': 0.0,
#   'believe': 0.0,
#   'belt': 0.0,
#   'benefit': 0.043497614480280396,
#   'benign': 0.0,
#   'best': 0.0,
#   'better': 0.057523751656416634,
#   'big': 0.0,
#   'binge': 0.0,
#   'black': 0.0,
#   'blood': 0.0,
#   'bloodline': 0.0,
#   'blue': 0.13049284344084117,
#   'board': 0.0,
#   'boast': 0.0,
#   'body': 0.0,
#   'bojack': 0.0,
#   'bone': 0.0,
#   'boom': 0.0,
#   'boost': 0.0,
#   'boots': 0.0,
#   'borrowing': 0.0,
#   'boston': 0.0,
#   'brad': 0.0,
#   'brain': 0.0,
#   'brazil': 0.0,
#   'break': 0.0,
#   'breakdown': 0.0,
#   'breakfast': 0.0,
#   'breaking': 0.0,
#   'brexit': 0.0,
#   'briefly': 0.0,
#   'bright': 0.0,
#   'bristol': 0.0,
#   'british': 0.0,
#   'broad': 0.0,
#   'broadly': 0.0,
#   'brow': 0.0,
#   'build': 0.0,
#   'bumper': 0.0,
#   'buoy': 0.0,
#   'business': 0.0,
#   'bust': 0.0,
#   'but': 0.0,
#   'buzz': 0.0,
#   'cadence': 0.0,
#   'california': 0.0,
#   'call': 0.0,
#   'cancer': 0.0,
#   'capability': 0.0,
#   'capital': 0.0,
#   'capitalisation': 0.0,
#   'carilion': 0.0,
#   'carry': 0.0,
#   'case': 0.0,
#   'catch': 0.0,
#   'category': 0.0,
#   'cause': 0.0,
#   'caution': 0.0,
#   'cave': 0.0,
#   'cent': 0.08699522896056079,
#   'central': 0.0,
#   'cerebral': 0.0,
#   'certain': 0.0,
#   'cessation': 0.0,
#   'chance': 0.0,
#   'change': 0.0,
#   'chatter': 0.0,
#   'checking': 0.0,
#   'checkpoint': 0.0,
#   'chief': 0.0,
#   'china': 0.0,
#   'choose': 0.0,
#   'christof': 0.0,
#   'cigarette': 0.0,
#   'cigarettes': 0.0,
#   'cindy': 0.0,
#   'city': 0.13049284344084117,
#   'classify': 0.0,
#   'clearly': 0.0,
#   'client': 0.0,
#   'clinical': 0.0,
#   'clock': 0.0,
#   'close': 0.1109308387480883,
#   'cloud': 0.0,
#   'club': 0.0,
#   'clue': 0.0,
#   'cnn': 0.0,
#   'co': 0.0,
#   'coast': 0.26098568688168233,
#   'coastal': 0.13049284344084117,
#   'coastline': 0.043497614480280396,
#   'cognitive': 0.0,
#   'collaboration': 0.0,
#   'college': 0.0,
#   'combination': 0.0,
#   'come': 0.028761875828208317,
#   'comedies': 0.0,
#   'comedy': 0.0,
#   'commerce': 0.0,
#   'commit': 0.0,
#   'communication': 0.0,
#   'community': 0.043497614480280396,
#   'company': 0.0,
#   'compare': 0.07395389249872554,
#   'compete': 0.0,
#   'compute': 0.0,
#   'computer': 0.0,
#   'concern': 0.0,
#   'condition': 0.0,
#   'confederation': 0.0,
#   'confine': 0.0,
#   'connect': 0.0,
#   'connection': 0.0,
#   'conscious': 0.0,
#   'consciouslike': 0.0,
#   'consciousness': 0.0,
#   'consumer': 0.0,
#   'contain': 0.0,
#   'content': 0.0,
#   'continue': 0.0,
#   'contraband': 0.0,
#   'control': 0.0,
#   'controlled': 0.0,
#   'convincing': 0.043497614480280396,
#   'convolutional': 0.0,
#   'coronavirus': 0.0,
#   'corporate': 0.0,
#   'correctly': 0.0,
#   'correlate': 0.0,
#   'correspond': 0.0,
#   'cortex': 0.0,
#   'cost': 0.0,
#   'could': 0.1109308387480883,
#   'counter': 0.0,
#   'country': 0.0,
#   'court': 0.0,
#   'courtroom': 0.0,
#   'cover': 0.0,
#   'create': 0.043497614480280396,
#   'crime': 0.0,
#   'criminal': 0.0,
#   'current': 0.0,
#   'currently': 0.0,
#   'customer': 0.0,
#   'da': 0.0,
#   'damage': 0.043497614480280396,
#   'dangerous': 0.0,
#   'data': 0.06470091702474,
#   'date': 0.0,
#   'dated': 0.0,
#   'day': 0.0,
#   'death': 0.0,
#   'debate': 0.0,
#   'decline': 0.0,
#   'deep': 0.0,
#   'definitely': 0.0,
#   'demand': 0.0,
#   'density': 0.0,
#   'department': 0.0,
#   'depend': 0.0,
#   'depression': 0.043497614480280396,
#   'dermatologist': 0.0,
#   'dermatologists': 0.0,
#   'detect': 0.0,
#   'detected': 0.0,
#   'detector': 0.0,
#   'develop': 0.0,
#   'diagnosis': 0.0,
#   'diagnostics': 0.0,
#   'dial': 0.0,
#   'dictation': 0.0,
#   'diet': 0.0,
#   'differ': 0.0,
#   'difference': 0.0,
#   'different': 0.0,
#   'differently': 0.0,
#   'difficult': 0.0,
#   'difficulty': 0.0,
#   'digital': 0.0,
#   'dip': 0.0,
#   'directly': 0.0,
#   'director': 0.0,
#   'discover': 0.0,
#   'disorder': 0.13049284344084117,
#   'dispel': 0.0,
#   'distinctive': 0.0,
#   'distinguish': 0.0,
#   'division': 0.0,
#   'do': 0.0,
#   'documentary': 0.0,
#   'domestic': 0.0,
#   'dopamine': 0.0,
#   'downbeat': 0.0,
#   'dr': 0.08699522896056079,
#   'drama': 0.0,
#   'dream': 0.0,
#   'drinking': 0.0,
#   'drop': 0.0,
#   'drug': 0.0,
#   'during': 0.0,
#   'earlier': 0.0,
#   'early': 0.0,
#   'earn': 0.043497614480280396,
#   'earning': 0.043497614480280396,
#   'earth': 0.0,
#   'ease': 0.0,
#   'easily': 0.0,
#   'easy': 0.0,
#   'economic': 0.0,
#   'economy': 0.0,
#   'edge': 0.0,
#   'edit': 0.0,
#   'editorial': 0.0,
#   'eeg': 0.0,
#   'effect': 0.03235045851237,
#   'effort': 0.0,
#   'electrical': 0.0,
#   'electroencephalography': 0.0,
#   'elicit': 0.0,
#   'elliot': 0.0,
#   'emerge': 0.0,
#   'eminem': 0.0,
#   'enable': 0.0,
#   'encounter': 0.0,
#   'encourage': 0.03697694624936277,
#   'engage': 0.0,
#   'england': 0.13049284344084117,
#   'english': 0.0,
#   'ensure': 0.043497614480280396,
#   'enter': 0.0,
#   'entire': 0.0,
#   'enunciation': 0.0,
#   'environment': 0.043497614480280396,
#   'environmental': 0.043497614480280396,
#   'environments': 0.043497614480280396,
#   'episode': 0.0,
#   'equates': 0.0,
#   'errors': 0.0,
#   'europe': 0.0,
#   'european': 0.0,
#   'even': 0.0,
#   'evening': 0.0,
#   'event': 0.0,
#   'eventually': 0.0,
#   'every': 0.0,
#   'everyone': 0.043497614480280396,
#   'everything': 0.0,
#   'evidence': 0.03697694624936277,
#   'evil': 0.0,
#   'evolve': 0.0,
#   'examination': 0.0,
#   'exception': 0.0,
#   'executive': 0.0,
#   'exeter': 0.08699522896056079,
#   'expect': 0.0,
#   'expectation': 0.0,
#   'expected': 0.0,
#   'experience': 0.03235045851237,
#   'experiment': 0.0,
#   'expert': 0.0,
#   'explanation': 0.0,
#   'export': 0.0,
#   'exports': 0.0,
#   'extinct': 0.0,
#   'eye': 0.0,
#   'facebook': 0.0,
#   'factor': 0.03235045851237,
#   'factory': 0.0,
#   'fade': 0.0,
#   'fair': 0.043497614480280396,
#   'fall': 0.0,
#   'far': 0.03697694624936277,
#   'fast': 0.0,
#   'faster': 0.0,
#   'favourite': 0.0,
#   'fear': 0.0,
#   'feature': 0.0,
#   'fed': 0.0,
#   'federal': 0.0,
#   'feel': 0.0,
#   'fell': 0.0,
#   'female': 0.0,
#   'few': 0.03697694624936277,
#   'field': 0.043497614480280396,
#   'figure': 0.0,
#   'figures': 0.0,
#   'find': 0.025829790281452377,
#   'finding': 0.07395389249872554,
#   'finger': 0.0,
#   'finish': 0.0,
#   'fire': 0.0,
#   'firm': 0.0,
#   'firmly': 0.0,
#   'first': 0.02335074727473375,
#   'fit': 0.0,
#   'five': 0.0,
#   'flow': 0.0,
#   'fmri': 0.0,
#   'focus': 0.0,
#   'focused': 0.0,
#   'follow': 0.0,
#   'for': 0.0,
#   'force': 0.0,
#   'forecast': 0.0,
#   'form': 0.0,
#   'forward': 0.0,
#   'fossil': 0.0,
#   'found': 0.0,
#   'four': 0.0,
#   'fourth': 0.0,
#   'fragile': 0.043497614480280396,
#   'france': 0.0,
#   'free': 0.0,
#   'frontal': 0.0,
#   'fuller': 0.0,
#   'functional': 0.0,
#   'functionality': 0.0,
#   'fuse': 0.0,
#   'future': 0.0,
#   'gain': 0.0,
#   'garrett': 0.043497614480280396,
#   'gather': 0.0,
#   'gdp': 0.0,
#   'generally': 0.0,
#   'genetic': 0.0,
#   'genre': 0.0,
#   'genus': 0.0,
#   'germany': 0.0,
#   'get': 0.0,
#   'gideon': 0.0,
#   'giulio': 0.0,
#   'give': 0.0,
#   'go': 0.0,
#   'gone': 0.0,
#   'good': 0.03697694624936277,
#   'google': 0.0,
#   'government': 0.03697694624936277,
#   'grab': 0.0,
#   'grand': 0.0,
#   'great': 0.0,
#   'grocery': 0.0,
#   'group': 0.0,
#   'grow': 0.03235045851237,
#   'growth': 0.0,
#   'gruta': 0.0,
#   'guard': 0.0,
#   'guardian': 0.0,
#   'gur': 0.0,
#   'had': 0.0,
#   'haenssle': 0.0,
#   'half': 0.0,
#   'hand': 0.0,
#   'hands': 0.0,
#   'hard': 0.0,
#   'hardcore': 0.0,
#   'haze': 0.0,
#   'head': 0.0,
#   'health': 0.480700301241716,
#   'heart': 0.0,
#   'heidelberg': 0.0,
#   'help': 0.08628562748462495,
#   'high': 0.025829790281452377,
#   'hike': 0.0,
#   'hinge': 0.0,
#   'hip': 0.0,
#   'hoard': 0.0,
#   'hold': 0.0,
#   'holger': 0.0,
#   'holland': 0.0,
#   'homo': 0.0,
# ...
#   'better': 0.0,
#   'big': 0.0,
#   'binge': 0.0,
#   'black': 0.0,
#   'blood': 0.0,
#   'bloodline': 0.0,
#   'blue': 0.0,
#   'board': 0.0,
#   'boast': 0.0,
#   'body': 0.0,
#   'bojack': 0.0,
#   'bone': 0.0,
#   'boom': 0.0,
#   'boost': 0.0,
#   'boots': 0.0,
#   'borrowing': 0.0,
#   'boston': 0.0,
#   'brad': 0.0,
#   'brain': 0.046196195186831955,
#   'brazil': 0.0,
#   'break': 0.0,
#   'breakdown': 0.0,
#   'breakfast': 0.0,
#   'breaking': 0.0,
#   'brexit': 0.0,
#   'briefly': 0.0,
#   'bright': 0.0,
#   'bristol': 0.06211424446810383,
#   'british': 0.09239239037366391,
#   'broad': 0.0,
#   'broadly': 0.0,
#   'brow': 0.0,
#   'build': 0.0,
#   'bumper': 0.0,
#   'buoy': 0.0,
#   'business': 0.0,
#   'bust': 0.0,
#   'but': 0.0,
#   'buzz': 0.0,
#   'cadence': 0.0,
#   'california': 0.0,
#   'call': 0.06211424446810383,
#   'cancer': 0.0,
#   'capability': 0.0,
#   'capital': 0.0,
#   'capitalisation': 0.0,
#   'carilion': 0.0,
#   'carry': 0.0,
#   'case': 0.0,
#   'catch': 0.0,
#   'category': 0.0,
#   'cause': 0.06211424446810383,
#   'caution': 0.0,
#   'cave': 0.0,
#   'cent': 0.0,
#   'central': 0.0,
#   'cerebral': 0.0,
#   'certain': 0.0,
#   'cessation': 0.06211424446810383,
#   'chance': 0.0,
#   'change': 0.0,
#   'chatter': 0.0,
#   'checking': 0.0,
#   'checkpoint': 0.0,
#   'chief': 0.0,
#   'china': 0.0,
#   'choose': 0.0,
#   'christof': 0.0,
#   'cigarette': 0.06211424446810383,
#   'cigarettes': 0.06211424446810383,
#   'cindy': 0.0,
#   'city': 0.0,
#   'classify': 0.0,
#   'clearly': 0.0,
#   'client': 0.0,
#   'clinical': 0.0,
#   'clock': 0.0,
#   'close': 0.0,
#   'cloud': 0.0,
#   'club': 0.0,
#   'clue': 0.0,
#   'cnn': 0.0,
#   'co': 0.06211424446810383,
#   'coast': 0.0,
#   'coastal': 0.0,
#   'coastline': 0.0,
#   'cognitive': 0.0,
#   'collaboration': 0.0,
#   'college': 0.0,
#   'combination': 0.0,
#   'come': 0.0,
#   'comedies': 0.0,
#   'comedy': 0.0,
#   'commerce': 0.0,
#   'commit': 0.0,
#   'communication': 0.0,
#   'community': 0.0,
#   'company': 0.0,
#   'compare': 0.0,
#   'compete': 0.0,
#   'compute': 0.0,
#   'computer': 0.0,
#   'concern': 0.0,
#   'condition': 0.0,
#   'confederation': 0.0,
#   'confine': 0.0,
#   'connect': 0.0,
#   'connection': 0.06211424446810383,
#   'conscious': 0.0,
#   'consciouslike': 0.0,
#   'consciousness': 0.0,
#   'consumer': 0.0,
#   'contain': 0.0,
#   'content': 0.0,
#   'continue': 0.0,
#   'contraband': 0.0,
#   'control': 0.0,
#   'controlled': 0.0,
#   'convincing': 0.0,
#   'convolutional': 0.0,
#   'coronavirus': 0.06211424446810383,
#   'corporate': 0.0,
#   'correctly': 0.0,
#   'correlate': 0.0,
#   'correspond': 0.0,
#   'cortex': 0.0,
#   'cost': 0.0,
#   'could': 0.0,
#   'counter': 0.0,
#   'country': 0.0,
#   'court': 0.0,
#   'courtroom': 0.0,
#   'cover': 0.0,
#   'create': 0.0,
#   'crime': 0.0,
#   'criminal': 0.0,
#   'current': 0.0,
#   'currently': 0.0,
#   'customer': 0.0,
#   'da': 0.0,
#   'damage': 0.0,
#   'dangerous': 0.0,
#   'data': 0.09239239037366391,
#   'date': 0.0,
#   'dated': 0.0,
#   'day': 0.0,
#   'death': 0.0,
#   'debate': 0.0,
#   'decline': 0.0,
#   'deep': 0.0,
#   'definitely': 0.0,
#   'demand': 0.0,
#   'density': 0.0,
#   'department': 0.0,
#   'depend': 0.0,
#   'depression': 0.0,
#   'dermatologist': 0.0,
#   'dermatologists': 0.0,
#   'detect': 0.0,
#   'detected': 0.0,
#   'detector': 0.0,
#   'develop': 0.0,
#   'diagnosis': 0.0,
#   'diagnostics': 0.0,
#   'dial': 0.0,
#   'dictation': 0.0,
#   'diet': 0.0,
#   'differ': 0.0,
#   'difference': 0.0,
#   'different': 0.0,
#   'differently': 0.0,
#   'difficult': 0.0,
#   'difficulty': 0.0,
#   'digital': 0.0,
#   'dip': 0.0,
#   'directly': 0.0,
#   'director': 0.0,
#   'discover': 0.0,
#   'disorder': 0.0,
#   'dispel': 0.0,
#   'distinctive': 0.0,
#   'distinguish': 0.0,
#   'division': 0.0,
#   'do': 0.0,
#   'documentary': 0.0,
#   'domestic': 0.0,
#   'dopamine': 0.06211424446810383,
#   'downbeat': 0.0,
#   'dr': 0.0,
#   'drama': 0.0,
#   'dream': 0.0,
#   'drinking': 0.06211424446810383,
#   'drop': 0.0,
#   'drug': 0.0,
#   'during': 0.0,
#   'earlier': 0.0,
#   'early': 0.0,
#   'earn': 0.0,
#   'earning': 0.0,
#   'earth': 0.0,
#   'ease': 0.0,
#   'easily': 0.0,
#   'easy': 0.0,
#   'economic': 0.0,
#   'economy': 0.0,
#   'edge': 0.0,
#   'edit': 0.0,
#   'editorial': 0.0,
#   'eeg': 0.0,
#   'effect': 0.0,
#   'effort': 0.0,
#   'electrical': 0.0,
#   'electroencephalography': 0.0,
#   'elicit': 0.0,
#   'elliot': 0.0,
#   'emerge': 0.0,
#   'eminem': 0.0,
#   'enable': 0.0,
#   'encounter': 0.0,
#   'encourage': 0.0,
#   'engage': 0.0,
#   'england': 0.0,
#   'english': 0.0,
#   'ensure': 0.0,
#   'enter': 0.0,
#   'entire': 0.0,
#   'enunciation': 0.0,
#   'environment': 0.0,
#   'environmental': 0.0,
#   'environments': 0.0,
#   'episode': 0.0,
#   'equates': 0.0,
#   'errors': 0.0,
#   'europe': 0.0,
#   'european': 0.0,
#   'even': 0.0,
#   'evening': 0.0,
#   'event': 0.0,
#   'eventually': 0.0,
#   'every': 0.0,
#   'everyone': 0.0,
#   'everything': 0.0,
#   'evidence': 0.05280278255392842,
#   'evil': 0.0,
#   'evolve': 0.0,
#   'examination': 0.0,
#   'exception': 0.0,
#   'executive': 0.0,
#   'exeter': 0.0,
#   'expect': 0.0,
#   'expectation': 0.0,
#   'expected': 0.0,
#   'experience': 0.0,
#   'experiment': 0.0,
#   'expert': 0.0,
#   'explanation': 0.0,
#   'export': 0.0,
#   'exports': 0.0,
#   'extinct': 0.0,
#   'eye': 0.0,
#   'facebook': 0.0,
#   'factor': 0.09239239037366391,
#   'factory': 0.0,
#   'fade': 0.0,
#   'fair': 0.0,
#   'fall': 0.0,
#   'far': 0.0,
#   'fast': 0.0,
#   'faster': 0.0,
#   'favourite': 0.0,
#   'fear': 0.0,
#   'feature': 0.0,
#   'fed': 0.0,
#   'federal': 0.0,
#   'feel': 0.0,
#   'fell': 0.0,
#   'female': 0.0,
#   'few': 0.0,
#   'field': 0.0,
#   'figure': 0.0,
#   'figures': 0.0,
#   'find': 0.1475389330906262,
#   'finding': 0.0,
#   'finger': 0.0,
#   'finish': 0.0,
#   'fire': 0.0,
#   'firm': 0.0,
#   'firmly': 0.0,
#   'first': 0.0,
#   'fit': 0.0,
#   'five': 0.0,
#   'flow': 0.0,
#   'fmri': 0.0,
#   'focus': 0.0,
#   'focused': 0.0,
#   'follow': 0.0,
#   'for': 0.0,
#   'force': 0.0,
#   'forecast': 0.0,
#   'form': 0.0,
#   'forward': 0.0,
#   'fossil': 0.0,
#   'found': 0.0,
#   'four': 0.0,
#   'fourth': 0.0,
#   'fragile': 0.0,
#   'france': 0.0,
#   'free': 0.0,
#   'frontal': 0.0,
#   'fuller': 0.0,
#   'functional': 0.0,
#   'functionality': 0.0,
#   'fuse': 0.0,
#   'future': 0.0,
#   'gain': 0.0,
#   'garrett': 0.0,
#   'gather': 0.0,
#   'gdp': 0.0,
#   'generally': 0.0,
#   'genetic': 0.06211424446810383,
#   'genre': 0.0,
#   'genus': 0.0,
#   'germany': 0.0,
#   'get': 0.0,
#   'gideon': 0.0,
#   'giulio': 0.0,
#   'give': 0.0,
#   'go': 0.0,
#   'gone': 0.0,
#   'good': 0.0,
#   'google': 0.0,
#   'government': 0.0,
#   'grab': 0.0,
#   'grand': 0.0,
#   'great': 0.0,
#   'grocery': 0.0,
#   'group': 0.0,
#   'grow': 0.0,
#   'growth': 0.0,
#   'gruta': 0.0,
#   'guard': 0.0,
#   'guardian': 0.0,
#   'gur': 0.0,
#   'had': 0.0,
#   'haenssle': 0.0,
#   'half': 0.0,
#   'hand': 0.0,
#   'hands': 0.0,
#   'hard': 0.05280278255392842,
#   'hardcore': 0.0,
#   'haze': 0.0,
#   'head': 0.0,
#   'health': 0.05280278255392842,
#   'heart': 0.0,
#   'heidelberg': 0.0,
#   'help': 0.04107172790738895,
#   'high': 0.0,
#   'hike': 0.0,
#   'hinge': 0.0,
#   'hip': 0.0,
#   'hoard': 0.0,
#   'hold': 0.0,
#   'holger': 0.0,
#   'holland': 0.0,
#   'homo': 0.0,
#   'hop': 0.0,
#   'horseman': 0.0,
#   'hot': 0.0,
#   'house': 0.0,
#   'housebuilding': 0.0,
#   'household': 0.0,
#   'households': 0.0,
#   'how': 0.0,
#   'human': 0.0,
#   'humans': 0.0,
#   'hundred': 0.06211424446810383,
#   'hypnotize': 0.0,
#   'idea': 0.0,
#   'identify': 0.06211424446810383,
#   'if': 0.0,
#   'illicit': 0.0,
#   'image': 0.0,
#   'imaging': 0.0,
#   'immoral': 0.0,
#   'implication': 0.0,
#   'import': 0.0,
#   'important': 0.05280278255392842,
#   'improve': 0.0,
#   'improvement': 0.0,
#   'in': 0.0,
#   'include': 0.0,
#   'inclusive': 0.0,
#   'income': 0.0,
#   'increase': 0.04107172790738895,
#   'increasingly': 0.0,
#   'indeed': 0.0,
#   'index': 0.0,
#   'india': 0.0,
#   'induce': 0.0,
#   'industry': 0.0,
#   'inequality': 0.0,
#   'information': 0.0,
#   'ing': 0.0,
#   'innovation': 0.0,
#   'inside': 0.0,
#   'insight': 0.0,
#   'insitute': 0.0,
#   'instead': 0.0,
#   'institute': 0.0,
#   'integration': 0.0,
#   'intelligence': 0.0,
#   'intense': 0.0,
#   'intent': 0.0,
#   'interest': 0.0,
#   'interesting': 0.0,
#   'interfere': 0.06211424446810383,
#   'introduce': 0.0,
#   'investigation': 0.0,
#   'investment': 0.0,
#   'involved': 0.0,
#   'ireland': 0.0,
#   'irresistible': 0.0,
#   'it': 0.0,
#   'january': 0.0,
#   'japanese': 0.0,
#   'jasper': 0.0,
#   'jo': 0.0,
#   'join': 0.0,
#   'jorien': 0.06211424446810383,
#   'journal': 0.046196195186831955,
#   'judge': 0.0,
#   'judith': 0.0,
#   'jump': 0.0,
#   'june': 0.06211424446810383,
#   'jury': 0.0,
#   'just': 0.0,
#   'keen': 0.0,
#   'kick': 0.0,
#   'kilometre': 0.0,
#   'kind': 0.0,
#   'kingdom': 0.06211424446810383,
#   'know': 0.0,
#   'koch': 0.0,
#   'kroger': 0.0,
#   'lab': 0.0,
#   'laboratory': 0.0,
#   'large': 0.0,
#   'last': 0.0,
#   'late': 0.0,
#   'laugh': 0.0,
#   'law': 0.0,
#   'lawler': 0.0,
#   'lawyer': 0.0,
#   'lead': 0.13858858556049586,
#   'leading': 0.0,
#   'leap': 0.0,
#   'learning': 0.0,
#   'leave': 0.0,
#   'lesion': 0.0,
#   'less': 0.04107172790738895,
#   'level': 0.0,
#   'liane': 0.0,
#   'light': 0.0,
#   'like': 0.0,
#   'likely': 0.12321518372216685,
#   'limitation': 0.0,
#   'line': 0.06211424446810383,
#   'lines': 0.0,
#   'link': 0.0,
#   'list': 0.0,
#   'little': 0.0,
#   'live': 0.0,
#   'london': 0.0,
#   'loneliness': 0.31057122234051915,
#   'lonely': 0.06211424446810383,
#   'long': 0.0,
#   'look': 0.05280278255392842,
#   'looked': 0.0,
#   'lose': 0.0,
#   'lot': 0.0,
#   'low': 0.0,
#   'lower': 0.0,
#   'lunch': 0.0,
#   'lunchtime': 0.0,
#   'lyric': 0.0,
#   'machine': 0.0,
#   'mad': 0.0,
#   'madison': 0.0,
#   'magnetic': 0.0,
#   'maintain': 0.0,
#   'major': 0.0,
#   'make': 0.10560556510785685,
#   'maker': 0.0,
#   'making': 0.0,
#   'malignant': 0.0,
#   'manufacturing': 0.0,
#   'many': 0.0,
#   'mar': 0.0,
#   'march': 0.0,
#   'mark': 0.0,
#   'marked': 0.0,
#   'market': 0.0,
#   'master': 0.0,
#   'material': 0.0,
#   'mathew': 0.0,
#   'matter': 0.0,
#   'maximise': 0.0,
#   'may': 0.0737694665453131,
#   'mc': 0.0,
#   'meaning': 0.0,
#   'meaningful': 0.0,
#   'measure': 0.0,
#   'mechanical': 0.0,
#   'mechanism': 0.06211424446810383,
#   'medical': 0.0,
#   'melanoma': 0.0,
#   'melbourne': 0.0,
#   'member': 0.0,
#   'men': 0.0,
#   'mendelian': 0.06211424446810383,
#   'mental': 0.046196195186831955,
#   'mesh': 0.06211424446810383,
#   'metabolism': 0.0,
#   'method': 0.046196195186831955,
#   'mic': 0.0,
#   'microphone': 0.0,
#   'microsoft': 0.0,
#   'mid': 0.0,
#   'midnight': 0.0,
#   'might': 0.0,
#   'million': 0.0,
#   'minaj': 0.0,
#   'mirror': 0.0,
#   'misdiagnosed': 0.0,
#   'miss': 0.0,
#   'mix': 0.0,
#   'model': 0.0,
#   'modern': 0.0,
#   'modest': 0.0,
#   'mole': 0.0,
#   'moment': 0.0,
#   'monash': 0.0,
#   'monetary': 0.0,
#   'monster': 0.0,
#   'montague': 0.0,
#   'month': 0.0,
#   'most': 0.0,
#   'mostly': 0.0,
#   'mouth': 0.0,
#   'movement': 0.0,
#   'much': 0.0,
#   'murderer': 0.0,
#   'mystery': 0.0,
#   'nadella': 0.0,
#   'name': 0.0,
#   'nasdaq': 0.0,
#   'national': 0.0,
#   'neandertals': 0.0,
#   'near': 0.0,
#   'need': 0.0,
#   'negotiation': 0.0,
#   'neighbor': 0.0,
#   'net': 0.0,
#   'netflix': 0.0,
#   'network': 0.0,
#   'neural': 0.0,
#   'neuron': 0.0,
#   'neuroscientist': 0.0,
#   'neurotransmitter': 0.06211424446810383,
#   'neutral': 0.0,
#   'never': 0.06211424446810383,
#   'new': 0.027573271358481154,
#   'newly': 0.0,
#   'newman': 0.0,
#   'news': 0.05280278255392842,
#   'next': 0.0,
#   'nicki': 0.0,
#   'nicotine': 0.06211424446810383,
#   'night': 0.0,
#   'nod': 0.0,
#   'nodded': 0.0,
#   'non': 0.0,
#   'none': 0.05280278255392842,
#   'noon': 0.0,
#   'note': 0.0,
#   'notorious': 0.0,
#   'novel': 0.06211424446810383,
#   'number': 0.0,
#   'observation': 0.06211424446810383,
#   'observe': 0.0,
#   'occur': 0.0,
#   'offer': 0.0,
#   'offering': 0.0,
#   'often': 0.0,
#   'old': 0.0,
#   'on': 0.0,
#   'oncology': 0.0,
#   'one': 0.0,
#   'orange': 0.0,
#   'order': 0.0,
#   'organisation': 0.0,
#   'original': 0.0,
#   'other': 0.0,
#   'our': 0.05280278255392842,
#   'outlook': 0.0,
#   'outperform': 0.0,
#   'output': 0.0,
#   'outside': 0.0,
#   'overcame': 0.0,
#   'owls': 0.0,
#   'pace': 0.0,
#   'pandemic': 0.06211424446810383,
#   'paper': 0.0,
#   'parietal': 0.0,
#   'part': 0.0,
#   'partial': 0.0,
#   'participant': 0.0,
#   'particularly': 0.0,
#   'pasadena': 0.0,
#   'pastime': 0.0,
#   'patch': 0.0,
#   'patient': 0.0,
#   'pattern': 0.0,
#   'pause': 0.0,
#   'pennsylvania': 0.0,
#   'people': 0.16672339875020797,
#   'pepper': 0.0,
#   'per': 0.0,
#   'percentage': 0.0,
#   'perfect': 0.0,
#   'performance': 0.0,
#   'perhaps': 0.0,
#   'period': 0.0,
#   'person': 0.0,
#   'peter': 0.0,
#   'philadelphia': 0.0,
#   'philosopher': 0.0,
#   'photo': 0.0,
#   'picture': 0.0,
#   'pit': 0.0,
#   'pizza': 0.0,
#   'place': 0.0,
#   'planet': 0.0,
#   'play': 0.0,
#   'point': 0.0,
#   'policy': 0.0,
#   'poor': 0.05280278255392842,
#   'poorer': 0.0,
#   'popular': 0.0,
#   'portfolio': 0.0,
#   'portion': 0.0,
#   'portugal': 0.0,
#   'posh': 0.0,
#   'possible': 0.0,
#   'potential': 0.06211424446810383,
#   'potty': 0.0,
#   'predict': 0.0,
#   'prefer': 0.0,
#   'president': 0.0,
#   'prestigious': 0.0,
#   'previous': 0.0,
#   'previously': 0.0,
#   'price': 0.0,
#   'primitive': 0.0,
#   'principle': 0.0,
#   'proceedings': 0.0,
#   'process': 0.0,
#   'producer': 0.0,
#   'product': 0.0,
#   'prof': 0.0,
#   'profit': 0.0,
#   'program': 0.0,
#   'programmer': 0.0,
#   'proof': 0.0,
#   'prospect': 0.0,
#   'protect': 0.0,
#   'protective': 0.0,
#   'prove': 0.0,
#   'proximity': 0.0,
#   'psychologist': 0.0,
#   'publicly': 0.0,
#   'publish': 0.046196195186831955,
#   'published': 0.0,
#   'pulse': 0.0,
#   'push': 0.0,
#   'put': 0.0,
#   'puzzle': 0.0,
#   'quarter': 0.0,
#   'quarterly': 0.0,
#   'queensland': 0.0,
#   'quest': 0.0,
#   'question': 0.05280278255392842,
#   'quit': 0.1863427334043115,
#   'raise': 0.0,
#   'randomization': 0.06211424446810383,
#   'range': 0.0,
#   'rap': 0.0,
#   'rapid': 0.0,
#   'rapper': 0.0,
#   'rate': 0.0,
#   'raw': 0.0,
#   'read': 0.0,
#   'ready': 0.0,
#   'real': 0.0,
#   'really': 0.0,
#   'reason': 0.0,
#   'reback': 0.0,
#   'recent': 0.05280278255392842,
#   'recession': 0.0,
#   'reckless': 0.0,
#   'recklessness': 0.0,
#   'recognise': 0.0,
#   'recoil': 0.0,
#   'recommendation': 0.0,
#   'reconstruction': 0.0,
#   'record': 0.0,
#   'reduce': 0.0,
#   'regardless': 0.0,
#   'region': 0.0,
#   'relate': 0.0,
#   'related': 0.0,
#   'relationship': 0.06211424446810383,
#   'release': 0.06211424446810383,
#   'relevant': 0.0,
#   'rem': 0.0,
#   'remain': 0.0,
#   'reminiscent': 0.0,
#   'remix': 0.0,
#   'removal': 0.0,
#   'repeat': 0.0,
#   'replay': 0.0,
#   'report': 0.03688473327265655,
#   'reports': 0.0,
#   'required': 0.0,
#   'research': 0.06668935950008319,
#   'researcher': 0.0737694665453131,
#   'researchers': 0.0,
#   'resemble': 0.0,
#   'reserve': 0.0,
#   'resonance': 0.0,
#   'respondent': 0.0,
#   'response': 0.0,
#   'rest': 0.0,
#   'result': 0.03688473327265655,
#   'reveal': 0.0,
#   'revenue': 0.0,
#   'revenues': 0.0,
#   'reverse': 0.0,
#   'rhyme': 0.0,
#   'ridge': 0.0,
#   'right': 0.0,
#   'rise': 0.0,
#   'risk': 0.05280278255392842,
#   'risky': 0.0,
#   'rival': 0.0,
#   'rizzo': 0.0,
#   'roanoke': 0.0,
#   'robyn': 0.06211424446810383,
#   'rock': 0.0,
#   'rofl': 0.0,
#   'role': 0.0,
#   'round': 0.0,
#   'ruben': 0.0,
#   'rule': 0.0,
#   'run': 0.0,
#   'sale': 0.0,
#   'sample': 0.0,
#   'satya': 0.0,
#   'say': 0.1006147145044683,
#   'scalp': 0.0,
#   'scan': 0.0,
#   'scenario': 0.0,
#   'schedule': 0.0,
#   'school': 0.0,
#   'science': 0.0,
#   'sciences': 0.0,
#   'scientist': 0.0,
#   'scientists': 0.0,
#   'screen': 0.0,
#   'sea': 0.0,
#   'second': 0.0,
#   'security': 0.0,
#   'see': 0.0,
#   'seem': 0.0,
#   'send': 0.0,
#   'senior': 0.12422848893620766,
#   'sense': 0.0,
#   'sensitivity': 0.0,
#   'sequencing': 0.0,
#   'series': 0.0,
#   'service': 0.046196195186831955,
#   'set': 0.0,
#   'several': 0.0,
#   'share': 0.0,
#   'shares': 0.0,
#   'sharply': 0.0,
#   'she': 0.0,
#   'shift': 0.0,
#   'show': 0.0,
#   'shut': 0.0,
#   'side': 0.0,
#   'sign': 0.0,
#   'similar': 0.0,
#   'simple': 0.0,
#   'simply': 0.0,
#   'simulate': 0.0,
#   'since': 0.0,
#   'siri': 0.0,
#   'site': 0.0,
#   'situation': 0.0,
#   'six': 0.0,
#   'size': 0.0,
#   'skeewiff': 0.0,
#   'skilled': 0.0,
#   'skin': 0.0,
#   'skull': 0.0,
#   'sleep': 0.0,
#   'sleepy': 0.0,
#   'slow': 0.0,
#   'slowdown': 0.0,
#   'slowest': 0.0,
#   'slumber': 0.0,
#   'slump': 0.0,
#   'sly': 0.0,
#   'small': 0.0,
#   'smoke': 0.5590282002129345,
#   'smoking': 0.12422848893620766,
#   'smooth': 0.0,
#   'smuggle': 0.0,
#   'snack': 0.0,
#   'sneaking': 0.0,
#   'solve': 0.0,
#   'someone': 0.05280278255392842,
#   'something': 0.0,
#   'son': 0.0,
#   'sort': 0.0,
#   'soyer': 0.0,
#   'space': 0.0,
#   'spaces': 0.0,
#   'specific': 0.0,
#   'spend': 0.0,
#   'spending': 0.0,
#   'spent': 0.0,
#   'spotify': 0.0,
#   'spread': 0.0,
#   ...}]

# %% [markdown]
# Now, we want to get the highest scoring values from each of these dictionaries. For this, we'll just sort our dictionary using Python's built in ```sorted``` method. We'll start by just sorting the tokens for the first text. I'm going to take a slice of the top-10 tokens.

# %%
sorted(pretty_tfidf_matrix[0], key=lambda x: pretty_tfidf_matrix[0][x] ,reverse=True)[:10]
# Out:
# ['cortex',
#  'sleep',
#  'consciousness',
#  'tononi',
#  'communication',
#  'electrical',
#  'non',
#  'rem',
#  'tms',
#  'activity']

# %% [markdown]
# These results look pretty damn good, however, the results appear to be no different than getting the token counts of the nouns. Let's see what the results look like for the other texts. For this, we're going to reduce the scores to just the top-5 scores, just to make things easier to look at.

# %%
top_5_scores = [sorted(pretty_tfidf_matrix[i], key=lambda x: pretty_tfidf_matrix[i][x] ,reverse=True)[:5] for i in range(0, 10)]
top_5_scores
# Out:
# [['cortex', 'sleep', 'consciousness', 'tononi', 'communication'],
#  ['neandertals', 'skull', 'europe', 'fossil', 'eventually'],
#  ['health', 'live', 'coast', 'mental', 'access'],
#  ['brain', 'know', 'people', 'suitcase', 'study'],
#  ['dermatologist', 'melanoma', 'skin', 'cnn', 'benign'],
#  ['growth', 'rate', 'us', 'quarter', 'economy'],
#  ['microsoft', 'cloud', 'market', 'share', 'company'],
#  ['siri', 'like', 'rhyme', 'know', 'young'],
#  ['netflix', 'day', 'viewing', 'watch', 'breakfast'],
#  ['smoke', 'loneliness', 'quit', 'people', 'find']]
